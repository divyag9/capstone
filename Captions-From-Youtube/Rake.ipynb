# %%
# !pip install rake_nltk
# !python -m spacy download en_core_web_sm

# %%
from rake_nltk import Rake
import pandas as pd
import nltk

# %%
import spacy

nlp = spacy.load("en_core_web_sm")
doc = nlp("see iphone 11 pro versus pixel 4 side")

for token in doc:
    print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_,
            token.shape_, token.is_alpha, token.is_stop)
# Out:
# see see VERB VB ROOT xxx True True
# iphone iphone PROPN NNP dobj xxxx True False
# 11 11 NUM CD nummod dd False False
# pro pro X FW dep xxx True False
# versus versus X FW nsubj xxxx True False
# pixel pixel NOUN NN ccomp xxxx True False
# 4 4 NUM CD nummod d False False
# side side NOUN NN dobj xxxx True True

# %%
doc = nlp(examples[3])
POS = set()
for token in doc:
    POS.add(token.text.lower())

# %%
POS
# Out:
# {' ',
#  '$',
#  '%',
#  "'d",
#  "'ll",
#  "'m",
#  "'re",
#  "'s",
#  "'ve",
#  '(',
#  ')',
#  ',',
#  '-',
#  '.',
#  '10',
#  '1440p60',
#  '15',
#  '16',
#  '16.6-megapixel',
#  '180-degree',
#  '2017',
#  '24th',
#  '25-mile',
#  '27th',
#  '360',
#  '360-degree',
#  '4',
#  '499',
#  '5.5-megapixel',
#  '5.6k30',
#  '500',
#  '6.2-megapixel',
#  '?',
#  'a',
#  'able',
#  'about',
#  'accessible',
#  'across',
#  'action',
#  'actually',
#  'add',
#  'added',
#  'afraid',
#  'alas',
#  'alex',
#  'all',
#  'almost',
#  'also',
#  'always',
#  'am',
#  'an',
#  'and',
#  'angle',
#  'angles',
#  'anyways',
#  'app',
#  'approachable',
#  'are',
#  'around',
#  'artifact',
#  'as',
#  'at',
#  'attempt',
#  'audio',
#  'away',
#  'back',
#  'base',
#  'basement',
#  'basically',
#  'batteries',
#  'battery',
#  'be',
#  'beasts',
#  'because',
#  'become',
#  'bed',
#  'been',
#  'before',
#  'being',
#  'believe',
#  'best',
#  'between',
#  'big',
#  'bit',
#  'blow',
# ...

# %%
import spacy

nlp = spacy.load("en_core_web_sm")
doc = nlp(examples[0])
for chunk in doc.noun_chunks:
    print(chunk.text)
          
          
#chunk.root.text, chunk.root.dep_,chunk.root.head.text
# Out:
#  [Music
# what
# guys mkbhd
# the pixel
# excel
# the phones
# I
# the most this entire year
# a couple
# reasons
# I
# it
# its unveiling
# my honest review
# 's
# the wait
# I
# it
# a pretty decent looking phone
# it
# almost no markings
# the back
# just the Google G
# the bottom matte black aluminum
# part
# the design
# the phone speaker slots
# the bottom
# the USB type-c port
# the colored power button
# course
# every version
# the phone
# the colors
# this soft touch matte finish
# which
# a great job
# fingerprints
# it
# the three colors
# I
# this Panda version
# that
# power buttons
# I
# second place
# not so great power button
# it
# matte
# that jet-black weirdly very glossy version
# third place
# the rails
# you
# a matte black D brand skin
# the back
# these phones
# you
# black everything
# phone Google
# the first place
# course
# D brand
# this video
# the pixels square camera bump
# I
# Apple's larger double raised triple camera bump
# the cameras
# you
# ...

# %%
df = pd.read_csv("videoExamples.csv")
examples = list(df.captions)

# %%
r = Rake()

# %%
r.extract_keywords_from_text(examples[0])

# %%
r.get_ranked_phrases()
# Out:
# ['smooth high res high refresh rate 90 hertz displays',
#  'pixel three great dynamic range great sharpness',
#  'new 16 megapixel 2x tell photocamera okay',
#  '70 percent swipe success rate maybe 75',
#  'see iphone 11 pro versus pixel 4 side',
#  'really like high refresh rate screens',
#  'little bit towards cooler tones typically',
#  'larger double raised triple camera bump',
#  'g8 weird hover hand swiping action',
#  'high refresh rate also requires',
#  'third place fun fact though since',
#  'serious difference versus 60 hertz',
#  'alarm clocks timers media controls',
#  'phone felt significantly choppier like',
#  'contrast ii punchy detailed look',
#  'brightest display sometimes daytime visibility',
#  'would pick iphone 11 pro',
#  'personally really enjoyed using pixel',
#  'bottom matte black aluminum rails',
#  'especially iphone 11 pro',
#  '12 megapixel primary camera',
#  'cheaper iphone 11 weird',
#  'go 6 8 x zoomed',
#  'pixels square camera bump',
# ...

# %%
r.extract_keywords_from_text('I love Ice Cream. Chocolate is my favorite flavor')

# %%
r.get_ranked_phrases()

# %%
examples[0]

# %%
nltk.tokenize.sent_tokenize(examples[3])
# Out:
# [' (mellow piano music) (upbeat music) - This is the GoPro MAX.',
#  "And it's GoPro's second attempt at a consumer level, 360 camera.",
#  '(camera whirring) Last year, Insta360 came out with the One X, and it totally revolutionized the idea of what a 360 camera could be used for.',
#  'First off, footage shot with the One X was stitched in camera, and then you were able to edit it right on your phone and upload to social platforms almost instantly.',
#  'Secondly, they market it not as a 360-degree camera but instead a camera that could shoot 360 degrees of possible angles.',
#  "Now fast forward a year and we have the GoPro Max, which is the successor to the GoPro Fusion that came out in 2017, that was filled with all of the headaches of 360's past.",
#  'It required two memory cards.',
#  'You had to stitch the footage on a desktop.',
# ...

# %%
nltk.tokenize.wordpunct_tokenize(examples[3])
# Out:
# ['(',
#  'mellow',
#  'piano',
#  'music',
#  ')',
#  '(',
#  'upbeat',
#  'music',
#  ')',
#  '-',
#  'This',
#  'is',
#  'the',
#  'GoPro',
#  'MAX',
#  '.',
#  'And',
#  'it',
#  "'",
#  's',
#  'GoPro',
#  "'",
#  's',
#  'second',
#  'attempt',
#  'at',
#  'a',
#  'consumer',
#  'level',
#  ',',
#  '360',
#  'camera',
#  '.',
#  '(',
#  'camera',
#  'whirring',
#  ')',
#  'Last',
#  'year',
#  ',',
#  'Insta360',
#  'came',
#  'out',
#  'with',
#  'the',
#  'One',
#  'X',
#  ',',
#  'and',
#  'it',
#  'totally',
#  'revolutionized',
#  'the',
#  'idea',
#  'of',
#  'what',
#  'a',
#  '360',
#  'camera',
#  'could',
#  'be',
#  'used',
#  'for',
#  '.',
#  'First',
#  'off',
#  ',',
#  'footage',
#  'shot',
#  'with',
#  'the',
#  'One',
#  'X',
#  'was',
#  'stitched',
#  'in',
#  'camera',
#  ',',
#  'and',
#  'then',
#  'you',
#  'were',
#  'able',
#  'to',
#  'edit',
#  'it',
#  'right',
#  'on',
#  'your',
#  'phone',
#  'and',
#  'upload',
#  'to',
#  'social',
# ...

# %%
examples[3]
# Out:
# " (mellow piano music) (upbeat music) - This is the GoPro MAX. And it's GoPro's second attempt at a consumer level, 360 camera. (camera whirring) Last year, Insta360 came out with the One X, and it totally revolutionized the idea of what a 360 camera could be used for. First off, footage shot with the One X was stitched in camera, and then you were able to edit it right on your phone and upload to social platforms almost instantly. Secondly, they market it not as a 360-degree camera but instead a camera that could shoot 360 degrees of possible angles. Now fast forward a year and we have the GoPro Max, which is the successor to the GoPro Fusion that came out in 2017, that was filled with all of the headaches of 360's past. It required two memory cards. You had to stitch the footage on a desktop. But they overhauled all of that with the Max, and they in turn made a really accessible 360 camera, which makes me believe I might continue to actually use this thing. ♪ We wag, we wag, we wag
# ...

# %%
nltk.wordpunct_tokenize(examples[1])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-8d3969c6c25b> in <module>()
# ----> 1 nltk.wordpunct_tokenize(examples[1]).lower()
#
# AttributeError: 'list' object has no attribute 'lower'

# %%
from itertools import groupby

# %%
for i in groupby(['hi','my','name','is', 'adam'], lambda x: x not in ['is']):
    print(i)
# Out:
# (True, <itertools._grouper object at 0x1a23792400>)
# (False, <itertools._grouper object at 0x1a23792198>)
# (True, <itertools._grouper object at 0x1a23792400>)

# %%
phrases = [tuple(group[1]) for group in groupby(['hi','my','name','is', 'adam'], lambda x: x not in ['is']) if group[0]]

# %%
phrases
# Out:
# [('hi', 'my', 'name'), ('adam',)]
