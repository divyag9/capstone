# %%
import nltk
import numpy as np
from itertools import groupby, chain
from collections import Counter, defaultdict
import spacy
spacy_nlp = spacy.load("en_core_web_sm")
import re

class StatementExtracter(object):
    """
    As part of key word extraction and sentiment summarization, this code will be
    able to extract certain types of statements from a block of text.
    """
    
    def __init__(self, stopwords = None, punctuations = None):
        self.stopwords = stopwords
        self.punctuations = punctuations
        if self.stopwords == None:
            self.stopwords = []
        if self.punctuations == None:
            self.punctuations = list('!"#%&\'()*+,./:;<=>?@[\\]^_`{|}~♪')
        self.phrase_breaks = set(self.stopwords + self.punctuations)
        
    def replace_contraction(self, text):
        """
        Takes in text and replaces certain contractions
        """
        contraction_patterns = [(r'won\'t', 'will not'), (r'can\'t', 'can not'), (r'i\'m', 'i am'), 
                                (r'ain\'t', 'is not'), (r'(\w+)\'ll', '\g<1> will'), (r'(\w+)n\'t', '\g<1> not'),
                                (r'(\w+)\'ve', '\g<1> have'), (r'(\w+)\'d', '\g<1> would'), (r'&', 'and'),
                                (r'dammit', 'damn it'), (r'dont', 'do not'), (r'wont', 'will not'),
                                (r'they\'re', 'they are'), (r'They\'re', 'They are'), (r'it\'s', 'it is'), (r'It\'s', 'It is')]
        patterns = [(re.compile(regex), repl) for (regex, repl) in contraction_patterns]
        for (pattern, repl) in patterns:
            (text, count) = re.subn(pattern, repl, text)
        return text
    
    def add_periods(self, text):
        """
        Takes in a string of text with no punctuation, uses Spacy's method of breaking up sentences to 
        add periods to the end of these sentences. Returns text with periods.
        """
        doc = spacy_nlp(text)
        sentence_tokens = [sents.text for sents in doc.sents]
        new_sentence_tokens = []
        add_on = None
        for i in range(len(sentence_tokens)-1,-1,-1):
            if " " in sentence_tokens[i]:
                if add_on == None:
                    # Add a period to the end of the sentence
                    new_sentence_tokens.append(sentence_tokens[i]+'.')
                else:
                    # Add 1 word and period to the end of the sentence.
                    new_sentence_tokens.append(sentence_tokens[i]+' '+add_on+'.')
                    add_on = None
            else:
                # If there is a sentence which is just one word, add it to the end of the previous sentence.
                add_on = sentence_tokens[i]
        new_text = " ".join(new_sentence_tokens[::-1])
        return new_text
        
    def spacy_POS_phrase_breaks(self, doc, POS_we_want, tag_we_want):
        """
        Inputs a string of text, a list of POS, and a list of Spacy Tags that we want to keep in.
        This method parses the text and adds words that do not fall into POS and TAGS to phrase breaks list.
        """
        # Initialize the set with our existing phrase breaks
        temp_phrase_breaks = self.phrase_breaks.copy()

        for token in doc:
            if token.pos_ not in POS_we_want and token.tag_ not in tag_we_want:
                temp_phrase_breaks.add(token.text.lower())
        return temp_phrase_breaks
    
    def visualize_POS(self, text, punctuation = False):
        """Visualize the POS of each word in the text"""
        if punctuation == False:
            text = self.add_periods(text)
            text = self.replace_contraction(text)
        else:
            text = self.replace_contraction(text)
        doc = spacy_nlp(text)
        for token in doc:
            print("{0}/{1}/{2} <--{3}-- {4}/{5}/{6}".format(
                    token.text,token.pos_,token.tag_,token.dep_,token.head.text,token.head.pos_,token.head.tag_))        
    
    def is_statements(self, text):
        # Situation where text contains sentences/punctuation
        if ", " in text:
            text = self.replace_contraction(text)
            self.statementExtraction(text, withPunctuation = True)
        # Situation where text does not contain sentences/punctuation
        else:
            text = self.add_periods(text)
            text = self.replace_contraction(text)
            self.statementExtraction(text, withPunctuation = False)
        
    def statementExtraction(self, text, withPunctuation = False):
        doc = spacy_nlp(text)
        for token in doc:
            # If the token is "is" or "are", we want to look at the subtree
            if token.text in ['is','are']:
                # Pull the subtree as token objects and as pure text
                subtree = [i for i in token.subtree]

                # Split the subtree up into left and right groups
                left_subtree = [word for word in subtree if word.i < token.i]
                right_subtree = [word for word in subtree if word.i > token.i]

                if withPunctuation == True:
                    # Create a temporary set of break words based on the Part of Speech
                    left_POS = ['ADJ','DET','NOUN','NUM','PART','PROPN','PUNCT','ADP','PRON','AUX','SYM','SCONJ']
                    left_tags = []
                    right_POS = ['ADJ','DET','NOUN','NUM','PART','PROPN','ADV','PUNCT','ADP','AUX','SYM','SCONJ','CCONJ','PRON']
                    right_tags = ['VBG','VBZ','VBP','VB','VBD','VBN']
                if withPunctuation == False:
                    left_POS = ['ADJ','DET','NOUN','NUM','PART','PROPN','PRON']
                    left_tags = []
                    right_POS = ['ADJ','DET','NOUN','NUM','PART','PROPN','ADV','ADP','CCONJ','SCONJ']
                    right_tags = ['VB','VBG']
                left_phrase_breaks = self.spacy_POS_phrase_breaks(subtree, left_POS, left_tags)
                right_phrase_breaks = self.spacy_POS_phrase_breaks(subtree, right_POS, right_tags)

                # group words together using phrase breaks and a separator 
                left_phrase_groups = groupby(left_subtree, lambda word: word.text.lower() not in left_phrase_breaks)
                # Pull out the groups of words that do not include any of the phrase breaks   
                left_phrase_tuples = [tuple(group[1]) for group in left_phrase_groups if group[0] == True]

                # group words together using phrase breaks and a separator 
                right_phrase_groups = groupby(right_subtree, lambda word: word.text.lower() not in right_phrase_breaks)
                # Pull out the groups of words that do not include any of the phrase breaks   
                right_phrase_tuples = [tuple(group[1]) for group in right_phrase_groups if group[0] == True]

                subject = []
                description = []
                
                # For the subjects on the left side of "is/are"
                subject_word = None
                for tuple_ in left_phrase_tuples:
                    for word in tuple_:
                        # if any of the words inside the tuple is a 'nsubj', it is potentially what we want
                        if word.dep_ in ['nsubj', 'expl']:
                            # check if we already have a good candidate for subject
                            if len(subject) < 1:
                                subject_word = word
                                subject = tuple_
                                break
                            elif subject_word.pos_ in ['NOUN'] and word.pos_ not in ['NOUN']:
                                pass
                            # if the existing candidate is not a noun, then we can update it.
                            else:
                                subject_word = word
                                subject = tuple_
                                break
                # Look at right text, if it includes adj, keep it + or just take the first phrase in the tuple.
                if len(right_phrase_tuples) > 0:
                    description = right_phrase_tuples[0]
                    
                # Create the statements
#                 print(" ".join([word.text for word in subtree]))
#                 print([(word.text,word.pos_,word.tag_,word.dep_) for word in left_subtree])
#                 print([(word.text,word.pos_,word.tag_,word.dep_) for word in right_subtree])
#                 print('\n')
                if len(subject) > 0 and len(description) > 0 and len(subtree) < 30:
                    output = " ".join([word.text for word in subject]) + " " + token.text + " " + " ".join([word.text for word in description])
                    print(output)

# %%
import pandas as pd
df = pd.read_csv("videoExamples.csv")
examples = list(df.captions)

# %%
se = StatementExtracter()

# %%
se.is_statements(examples[2])
# Out:
# it is still a lot of money for a Chromebook
# the pixel book is a nice device
# it is a phone or pedestrian computer than
# it is thicker than that device still
# it is glass an aluminum lid
# it is good to see Google 's more playful side on this otherwise dull laptop and while the goal
# it is much heavier than the go for example
# such there are some other notable changes to the go
# it is not a convertible so tablet mode
# it is just not nearly as gorgeous to look at as those last two computers 1080p on a 13.3 inch screen
# the good news is that the go as much slimmer bezels around the screen than the original pixel book
# the go is almost as good
# they are pretty quiet Google about the whole thing right here
# the trackpad is just fine
# it is not bad
# which is frustrating
# Android apps are not usually worth using if
# it is a worthwhile upgrade for
# which is a definite improvement over the first pixel book
# the pixel book go is a much easier device to evaluate than either the first pixel book or the pixel
# it is a standard familiar almost boring laptop
# the go is just a straightforward no
# it is still not particularly cheap especially if

# %%
se.visualize_POS(examples[2])
# Out:
#  /SPACE/_SP <---- Google/PROPN/NNP
# Google/PROPN/NNP <--nsubj-- building/VERB/VBG
# has/AUX/VBZ <--aux-- building/VERB/VBG
# been/AUX/VBN <--aux-- building/VERB/VBG
# building/VERB/VBG <--ROOT-- building/VERB/VBG
# its/PRON/PRP$ <--poss-- Chromebooks/PROPN/NNP
# own/ADJ/JJ <--amod-- Chromebooks/PROPN/NNP
# Chromebooks/PROPN/NNP <--dobj-- building/VERB/VBG
# for/ADP/IN <--prep-- building/VERB/VBG
# a/DET/DT <--det-- while/NOUN/NN
# while/NOUN/NN <--pobj-- for/ADP/IN
# now/ADV/RB <--advmod-- while/NOUN/NN
# ./PUNCT/. <--punct-- building/VERB/VBG
# first/ADV/RB <--advmod-- were/AUX/VBD
# there/PRON/EX <--expl-- were/AUX/VBD
# were/AUX/VBD <--ROOT-- were/AUX/VBD
# two/NUM/CD <--nummod-- iterations/NOUN/NNS
# iterations/NOUN/NNS <--attr-- were/AUX/VBD
# of/ADP/IN <--prep-- iterations/NOUN/NNS
# the/DET/DT <--det-- pixel/NOUN/NN
# Chromebook/PROPN/NNP <--compound-- pixel/NOUN/NN
# pixel/NOUN/NN <--pobj-- of/ADP/IN
# and/CCONJ/CC <--cc-- were/AUX/VBD
# then/ADV/RB <--advmod-- was/AUX/VBD
# there/PRON/EX <--expl-- was/AUX/VBD
# was/AUX/VBD <--conj-- were/AUX/VBD
# 2017/NUM/CD <--nummod-- book/NOUN/NN
# pixel/NOUN/NN <--compound-- book/NOUN/NN
# book/NOUN/NN <--attr-- was/AUX/VBD
# all/DET/DT <--det-- three/NUM/CD
# three/NUM/CD <--nsubj-- worked/VERB/VBD
# worked/VERB/VBD <--relcl-- book/NOUN/NN
# great/ADJ/JJ <--amod-- laptops/NOUN/NNS
# laptops/NOUN/NNS <--dobj-- worked/VERB/VBD
# with/ADP/IN <--prep-- worked/VERB/VBD
# one/NUM/CD <--nummod-- flaw/NOUN/NN
# huge/ADJ/JJ <--amod-- flaw/NOUN/NN
# flaw/NOUN/NN <--pobj-- with/ADP/IN
# they/PRON/PRP <--nsubj-- cost/VERB/VBP
# cost/VERB/VBP <--relcl-- book/NOUN/NN
# way/ADV/RB <--dobj-- cost/VERB/VBP
# too/ADV/RB <--advmod-- much/ADJ/JJ
# much/ADJ/JJ <--amod-- money/NOUN/NN
# money/NOUN/NN <--dobj-- cost/VERB/VBP
# ./PUNCT/. <--punct-- was/AUX/VBD
# Google/PROPN/NNP <--nsubj-- go/VERB/VB
# 's/PART/POS <--case-- Google/PROPN/NNP
# back/ADV/RB <--advmod-- Google/PROPN/NNP
# at/ADP/IN <--prep-- back/ADV/RB
# it/PRON/PRP <--pobj-- at/ADP/IN
# again/ADV/RB <--advmod-- Google/PROPN/NNP
# this/DET/DT <--det-- year/NOUN/NN
# year/NOUN/NN <--npadvmod-- Google/PROPN/NNP
# with/ADP/IN <--prep-- Google/PROPN/NNP
# the/DET/DT <--det-- book/NOUN/NN
# new/ADJ/JJ <--amod-- book/NOUN/NN
# pixel/PROPN/NNP <--compound-- book/NOUN/NN
# book/NOUN/NN <--nsubj-- go/VERB/VB
# go/VERB/VB <--ROOT-- go/VERB/VB
# and/CCONJ/CC <--cc-- go/VERB/VB
# for/ADP/IN <--prep-- trying/VERB/VBG
# the/DET/DT <--det-- time/NOUN/NN
# first/ADJ/JJ <--amod-- time/NOUN/NN
# time/NOUN/NN <--pobj-- for/ADP/IN
# Google/PROPN/NNP <--nsubj-- trying/VERB/VBG
# 's/PART/POS <--aux-- trying/VERB/VBG
# not/PART/RB <--neg-- trying/VERB/VBG
# trying/VERB/VBG <--conj-- go/VERB/VB
# to/PART/TO <--aux-- make/VERB/VB
# make/VERB/VB <--xcomp-- trying/VERB/VBG
# the/DET/DT <--det-- Chromebook/PROPN/NNP
# best/ADJ/JJS <--amod-- Chromebook/PROPN/NNP
# Chromebook/PROPN/NNP <--nsubjpass-- damned/VERB/VBN
# ever/ADV/RB <--advmod-- price/NOUN/NN
# price/NOUN/NN <--appos-- Chromebook/PROPN/NNP
# be/AUX/VB <--auxpass-- damned/VERB/VBN
# damned/VERB/VBN <--ccomp-- make/VERB/VB
# [/PUNCT/-LRB- <--punct-- Music/NOUN/NN
# Music/NOUN/NN <--npadvmod-- damned/VERB/VBN
# ]/PUNCT/-RRB- <--punct-- Music/NOUN/NN
# ./PUNCT/. <--punct-- trying/VERB/VBG
# instead/ADV/RB <--advmod-- trying/VERB/VBG
# Google/PROPN/NNP <--nsubj-- trying/VERB/VBG
# is/AUX/VBZ <--aux-- trying/VERB/VBG
# trying/VERB/VBG <--ROOT-- trying/VERB/VBG
# to/PART/TO <--aux-- build/VERB/VB
# build/VERB/VB <--xcomp-- trying/VERB/VBG
# a/DET/DT <--det-- Chromebook/PROPN/NNP
# Chromebook/PROPN/NNP <--dobj-- build/VERB/VB
# that/SCONJ/IN <--dobj-- use/VERB/VB
# anyone/PRON/NN <--nsubj-- use/VERB/VB
# can/AUX/MD <--aux-- use/VERB/VB
# use/VERB/VB <--relcl-- Chromebook/PROPN/NNP
# and/CCONJ/CC <--cc-- use/VERB/VB
# afford/VERB/VB <--conj-- use/VERB/VB
# the/DET/DT <--det-- pixel/NOUN/NN
# pixel/NOUN/NN <--dobj-- afford/VERB/VB
# will/AUX/MD <--aux-- go/VERB/VB
# go/VERB/VB <--conj-- trying/VERB/VBG
# starts/NOUN/NNS <--dobj-- go/VERB/VB
# at/ADP/IN <--prep-- go/VERB/VB
# six/NUM/CD <--compound-- hundred/NUM/CD
# hundred/NUM/CD <--nummod-- dollars/NOUN/NNS
# and/CCONJ/CC <--cc-- hundred/NUM/CD
# fifty/NUM/CD <--conj-- hundred/NUM/CD
# dollars/NOUN/NNS <--pobj-- at/ADP/IN
# a/DET/DT <--det-- 350/NUM/CD
# full/ADJ/JJ <--amod-- 350/NUM/CD
# 350/NUM/CD <--npadvmod-- less/ADJ/JJR
# less/ADJ/JJR <--amod-- dollars/NOUN/NNS
# than/SCONJ/IN <--prep-- less/ADJ/JJR
# the/DET/DT <--det-- book/NOUN/NN
# original/ADJ/JJ <--amod-- book/NOUN/NN
# pixel/PROPN/NNP <--compound-- book/NOUN/NN
# book/NOUN/NN <--pobj-- than/SCONJ/IN
# ./PUNCT/. <--punct-- trying/VERB/VBG
# it/PRON/PRP <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--ROOT-- is/AUX/VBZ
# still/ADV/RB <--advmod-- is/AUX/VBZ
# a/DET/DT <--det-- lot/NOUN/NN
# lot/NOUN/NN <--attr-- is/AUX/VBZ
# of/ADP/IN <--prep-- lot/NOUN/NN
# money/NOUN/NN <--pobj-- of/ADP/IN
# for/ADP/IN <--prep-- is/AUX/VBZ
# a/DET/DT <--det-- Chromebook/PROPN/NNP
# Chromebook/PROPN/NNP <--pobj-- for/ADP/IN
# ./PUNCT/. <--punct-- is/AUX/VBZ
# but/CCONJ/CC <--cc-- built/VERB/VBN
# for/ADP/IN <--prep-- built/VERB/VBN
# the/DET/DT <--det-- time/NOUN/NN
# first/ADJ/JJ <--amod-- time/NOUN/NN
# time/NOUN/NN <--pobj-- for/ADP/IN
# Google/PROPN/NNP <--nsubj-- built/VERB/VBN
# 's/PART/POS <--case-- Google/PROPN/NNP
# built/VERB/VBN <--ROOT-- built/VERB/VBN
# something/PRON/NN <--dobj-- built/VERB/VBN
# better/ADJ/JJR <--amod-- something/PRON/NN
# than/SCONJ/IN <--prep-- better/ADJ/JJR
# the/DET/DT <--det-- Chromebooks/PROPN/NNP
# cheap/ADJ/JJ <--amod-- Chromebooks/PROPN/NNP
# low/ADJ/JJ <--amod-- end/NOUN/NN
# -/PUNCT/HYPH <--punct-- end/NOUN/NN
# end/NOUN/NN <--compound-- Chromebooks/PROPN/NNP
# Chromebooks/PROPN/NNP <--pobj-- than/SCONJ/IN
# out/ADV/RB <--advmod-- there/ADV/RB
# there/ADV/RB <--advmod-- Chromebooks/PROPN/NNP
# that/PRON/WDT <--nsubj-- affordable/ADJ/JJ
# still/ADV/RB <--advmod-- affordable/ADJ/JJ
# semi/ADV/RB <--advmod-- affordable/ADJ/JJ
# affordable/ADJ/JJ <--relcl-- something/PRON/NN
# unfortunately/ADV/RB <--advmod-- affordable/ADJ/JJ
# in/ADP/IN <--prep-- affordable/ADJ/JJ
# its/PRON/PRP$ <--poss-- quest/NOUN/NN
# quest/NOUN/NN <--pobj-- in/ADP/IN
# to/PART/TO <--aux-- get/AUX/VB
# get/AUX/VB <--acl-- quest/NOUN/NN
# the/DET/DT <--det-- price/NOUN/NN
# price/NOUN/NN <--dobj-- get/AUX/VB
# down/ADP/IN <--prep-- get/AUX/VB
# Google/PROPN/NNP <--pobj-- down/ADP/IN
# ./PUNCT/. <--punct-- built/VERB/VBN
# also/ADV/RB <--advmod-- rest/NOUN/NN
# second/ADJ/JJ <--advmod-- rest/NOUN/NN
# rest/NOUN/NN <--ROOT-- rest/NOUN/NN
# a/DET/DT <--det-- lot/NOUN/NN
# lot/NOUN/NN <--dobj-- rest/NOUN/NN
# of/ADP/IN <--prep-- lot/NOUN/NN
# what/PRON/WP <--nsubj-- made/VERB/VBD
# made/VERB/VBD <--pcomp-- of/ADP/IN
# the/DET/DT <--det-- pixel/NOUN/NN
# original/ADJ/JJ <--amod-- pixel/NOUN/NN
# pixel/NOUN/NN <--nsubj-- looks/VERB/VBZ
# looks/VERB/VBZ <--ccomp-- made/VERB/VBD
# so/ADV/RB <--advmod-- intriguing/ADJ/JJ
# intriguing/ADJ/JJ <--advcl-- looks/VERB/VBZ
# in/ADP/IN <--prep-- intriguing/ADJ/JJ
# the/DET/DT <--det-- place/NOUN/NN
# first/ADJ/JJ <--amod-- place/NOUN/NN
# place/NOUN/NN <--pobj-- in/ADP/IN
# but/CCONJ/CC <--cc-- of/ADP/IN
# for/ADP/IN <--conj-- of/ADP/IN
# a/DET/DT <--det-- lot/NOUN/NN
# lot/NOUN/NN <--pobj-- for/ADP/IN
# of/ADP/IN <--prep-- lot/NOUN/NN
# people/NOUN/NNS <--pobj-- of/ADP/IN
# ./PUNCT/. <--punct-- rest/NOUN/NN
# those/DET/DT <--det-- offs/NOUN/NNS
# trade/NOUN/NN <--compound-- offs/NOUN/NNS
# -/PUNCT/HYPH <--punct-- offs/NOUN/NNS
# offs/NOUN/NNS <--nsubj-- be/AUX/VB
# will/AUX/MD <--aux-- be/AUX/VB
# be/AUX/VB <--ROOT-- be/AUX/VB
# worth/ADJ/JJ <--acomp-- be/AUX/VB
# it/PRON/PRP <--npadvmod-- worth/ADJ/JJ
# all/DET/DT <--nsubj-- had/AUX/VBD
# of/ADP/IN <--prep-- all/DET/DT
# Google/PROPN/NNP <--poss-- Chromebooks/PROPN/NNP
# 's/PART/POS <--case-- Google/PROPN/NNP
# previous/ADJ/JJ <--amod-- Chromebooks/PROPN/NNP
# Chromebooks/PROPN/NNP <--pobj-- of/ADP/IN
# as/ADV/RB <--advmod-- as/SCONJ/IN
# well/ADV/RB <--advmod-- as/SCONJ/IN
# as/SCONJ/IN <--cc-- Chromebooks/PROPN/NNP
# last/ADJ/JJ <--amod-- year/NOUN/NN
# year/NOUN/NN <--poss-- tablet/PROPN/NNP
# 's/PART/POS <--case-- year/NOUN/NN
# ill/ADV/RB <--advmod-- fated/VERB/VBN
# -/PUNCT/HYPH <--punct-- fated/VERB/VBN
# fated/VERB/VBN <--amod-- tablet/PROPN/NNP
# pixel/NOUN/NN <--compound-- slate/NOUN/NN
# slate/NOUN/NN <--compound-- tablet/PROPN/NNP
# tablet/PROPN/NNP <--conj-- Chromebooks/PROPN/NNP
# had/AUX/VBD <--conj-- be/AUX/VB
# distinctive/ADJ/JJ <--amod-- designs/NOUN/NNS
# designs/NOUN/NNS <--dobj-- had/AUX/VBD
# and/CCONJ/CC <--cc-- designs/NOUN/NNS
# premium/NOUN/NN <--compound-- hardware/NOUN/NN
# hardware/NOUN/NN <--conj-- designs/NOUN/NNS
# with/ADP/IN <--prep-- had/AUX/VBD
# very/ADV/RB <--advmod-- few/ADJ/JJ
# few/ADJ/JJ <--amod-- corners/NOUN/NNS
# corners/NOUN/NNS <--nsubj-- cut/VERB/VBN
# cut/VERB/VBN <--pcomp-- with/ADP/IN
# while/SCONJ/IN <--mark-- is/AUX/VBZ
# the/DET/DT <--det-- book/NOUN/NN
# pixel/NOUN/NN <--compound-- book/NOUN/NN
# book/NOUN/NN <--nsubj-- is/AUX/VBZ
# though/ADV/RB <--advmod-- is/AUX/VBZ
# is/AUX/VBZ <--advcl-- cut/VERB/VBN
# a/DET/DT <--det-- device/NOUN/NN
# nice/ADJ/JJ <--amod-- device/NOUN/NN
# device/NOUN/NN <--attr-- is/AUX/VBZ
# ./PUNCT/. <--punct-- be/AUX/VB
# it/PRON/PRP <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--ROOT-- is/AUX/VBZ
# a/DET/DT <--det-- computer/NOUN/NN
# phone/NOUN/NN <--nmod-- computer/NOUN/NN
# or/CCONJ/CC <--cc-- phone/NOUN/NN
# pedestrian/NOUN/NN <--conj-- phone/NOUN/NN
# computer/NOUN/NN <--attr-- is/AUX/VBZ
# than/SCONJ/IN <--prep-- is/AUX/VBZ
# anything/PRON/NN <--pobj-- than/SCONJ/IN
# Google/PROPN/NNP <--nsubj-- released/VERB/VBN
# has/AUX/VBZ <--aux-- released/VERB/VBN
# released/VERB/VBN <--relcl-- anything/PRON/NN
# thus/ADV/RB <--advmod-- far/ADV/RB
# far/ADV/RB <--advmod-- released/VERB/VBN
# ./PUNCT/. <--punct-- is/AUX/VBZ
# it/PRON/PRP <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--ROOT-- is/AUX/VBZ
# a/DET/DT <--det-- laptop/NOUN/NN
# basic/ADJ/JJ <--amod-- clamshell/ADJ/JJ
# looking/VERB/VBG <--amod-- clamshell/ADJ/JJ
# clamshell/ADJ/JJ <--compound-- laptop/NOUN/NN
# laptop/NOUN/NN <--attr-- is/AUX/VBZ
# with/ADP/IN <--prep-- laptop/NOUN/NN
# a/DET/DT <--det-- touchscreen/NOUN/NNS
# 13.3/NUM/CD <--nummod-- inch/NOUN/NN
# inch/NOUN/NN <--compound-- touchscreen/NOUN/NNS
# 1080p/NUM/CD <--compound-- touchscreen/NOUN/NNS
# touchscreen/NOUN/NNS <--pobj-- with/ADP/IN
# and/CCONJ/CC <--cc-- touchscreen/NOUN/NNS
# a/DET/DT <--det-- job/NOUN/NN
# black/ADJ/JJ <--amod-- job/NOUN/NN
# paint/NOUN/NN <--compound-- job/NOUN/NN
# job/NOUN/NN <--conj-- touchscreen/NOUN/NNS
# unmarked/VERB/VBN <--acl-- laptop/NOUN/NN
# except/SCONJ/IN <--prep-- unmarked/VERB/VBN
# for/ADP/IN <--prep-- except/SCONJ/IN
# a/DET/DT <--det-- logo/NOUN/NN
# small/ADJ/JJ <--amod-- logo/NOUN/NN
# Google/PROPN/NNP <--compound-- Gee/PROPN/NNP
# Gee/PROPN/NNP <--compound-- logo/NOUN/NN
# logo/NOUN/NN <--pobj-- for/ADP/IN
# in/ADP/IN <--prep-- logo/NOUN/NN
# the/DET/DT <--det-- corner/NOUN/NN
# corner/NOUN/NN <--pobj-- in/ADP/IN
# of/ADP/IN <--prep-- corner/NOUN/NN
# the/DET/DT <--det-- lid/NOUN/NN
# lid/NOUN/NN <--pobj-- of/ADP/IN
# it/PRON/PRP <--nsubj-- comes/VERB/VBZ
# also/ADV/RB <--advmod-- comes/VERB/VBZ
# comes/VERB/VBZ <--relcl-- lid/NOUN/NN
# in/ADP/IN <--prep-- comes/VERB/VBZ
# very/ADV/RB <--advmod-- light/ADJ/JJ
# light/ADJ/JJ <--amod-- pink/ADJ/JJ
# pink/ADJ/JJ <--pobj-- in/ADP/IN
# with/ADP/IN <--prep-- pink/ADJ/JJ
# a/DET/DT <--det-- underside/NOUN/NN
# bright/ADJ/JJ <--amod-- underside/NOUN/NN
# coral/NOUN/NN <--amod-- underside/NOUN/NN
# underside/NOUN/NN <--pobj-- with/ADP/IN
# ./PUNCT/. <--punct-- is/AUX/VBZ
# a/DET/DT <--det-- combo/NOUN/NN
# much/ADV/RB <--advmod-- more/ADV/RBR
# more/ADV/RBR <--advmod-- distinctive/ADJ/JJ
# distinctive/ADJ/JJ <--amod-- combo/NOUN/NN
# combo/NOUN/NN <--nsubj-- has/AUX/VBZ
# but/CCONJ/CC <--cc-- combo/NOUN/NN
# the/DET/DT <--det-- black/ADJ/JJ
# all/ADV/RB <--advmod-- black/ADJ/JJ
# -/PUNCT/HYPH <--punct-- black/ADJ/JJ
# black/ADJ/JJ <--conj-- combo/NOUN/NN
# has/AUX/VBZ <--ROOT-- has/AUX/VBZ
# a/DET/DT <--det-- elegance/NOUN/NN
# certain/ADJ/JJ <--amod-- elegance/NOUN/NN
# understated/VERB/VBN <--amod-- elegance/NOUN/NN
# elegance/NOUN/NN <--dobj-- has/AUX/VBZ
# either/DET/DT <--det-- way/NOUN/NN
# way/NOUN/NN <--npadvmod-- has/AUX/VBZ
# the/DET/DT <--det-- go/NOUN/NN
# go/NOUN/NN <--nsubj-- feels/VERB/VBZ
# feels/VERB/VBZ <--relcl-- way/NOUN/NN
# sturdy/ADJ/JJ <--acomp-- feels/VERB/VBZ
# and/CCONJ/CC <--cc-- sturdy/ADJ/JJ
# well/ADV/RB <--advmod-- built/VERB/VBN
# built/VERB/VBN <--conj-- sturdy/ADJ/JJ
# but/CCONJ/CC <--cc-- feels/VERB/VBZ
# does/AUX/VBZ <--aux-- have/AUX/VB
# not/PART/RB <--neg-- have/AUX/VB
# have/AUX/VB <--conj-- feels/VERB/VBZ
# any/DET/DT <--dobj-- have/AUX/VB
# of/ADP/IN <--prep-- any/DET/DT
# the/DET/DT <--det-- elements/NOUN/NNS
# distinctive/ADJ/JJ <--amod-- elements/NOUN/NNS
# design/NOUN/NN <--compound-- elements/NOUN/NNS
# elements/NOUN/NNS <--pobj-- of/ADP/IN
# you/PRON/PRP <--nsubj-- see/VERB/VB
# will/AUX/MD <--aux-- see/VERB/VB
# see/VERB/VB <--relcl-- elements/NOUN/NNS
# in/ADP/IN <--prep-- see/VERB/VB
# the/DET/DT <--det-- book/NOUN/NN
# original/ADJ/JJ <--amod-- book/NOUN/NN
# pixel/PROPN/NNP <--compound-- book/NOUN/NN
# book/NOUN/NN <--pobj-- in/ADP/IN
# ./PUNCT/. <--punct-- has/AUX/VBZ
# it/PRON/PRP <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--ROOT-- is/AUX/VBZ
# thicker/ADJ/JJR <--acomp-- is/AUX/VBZ
# than/SCONJ/IN <--mark-- weighs/VERB/VBZ
# that/DET/DT <--det-- device/NOUN/NN
# device/NOUN/NN <--nsubj-- weighs/VERB/VBZ
# still/ADV/RB <--advmod-- weighs/VERB/VBZ
# weighs/VERB/VBZ <--advcl-- is/AUX/VBZ
# about/ADP/IN <--advmod-- same/ADJ/JJ
# the/DET/DT <--det-- same/ADJ/JJ
# same/ADJ/JJ <--dobj-- weighs/VERB/VBZ
# at/ADP/IN <--prep-- weighs/VERB/VBZ
# 2.3/NUM/CD <--nummod-- pounds/NOUN/NNS
# pounds/NOUN/NNS <--pobj-- at/ADP/IN
# ./PUNCT/. <--punct-- is/AUX/VBZ
# I/PRON/PRP <--nsubj-- miss/VERB/VBP
# definitely/ADV/RB <--advmod-- miss/VERB/VBP
# miss/VERB/VBP <--ROOT-- miss/VERB/VBP
# the/DET/DT <--det-- aesthetics/NOUN/NNS
# aesthetics/NOUN/NNS <--dobj-- miss/VERB/VBP
# of/ADP/IN <--prep-- aesthetics/NOUN/NNS
# the/DET/DT <--det-- original/ADJ/JJ
# original/ADJ/JJ <--pobj-- of/ADP/IN
# ./PUNCT/. <--punct-- miss/VERB/VBP
# though/SCONJ/IN <--mark-- is/AUX/VBZ
# particularly/ADV/RB <--advmod-- is/AUX/VBZ
# it/PRON/PRP <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--ROOT-- is/AUX/VBZ
# glass/NOUN/NN <--attr-- is/AUX/VBZ
# an/DET/DT <--det-- lid/NOUN/NN
# aluminum/NOUN/NN <--compound-- lid/NOUN/NN
# lid/NOUN/NN <--attr-- is/AUX/VBZ
# that/PRON/WDT <--nsubj-- echoed/VERB/VBD
# echoed/VERB/VBD <--relcl-- lid/NOUN/NN
# the/DET/DT <--det-- design/NOUN/NN
# design/NOUN/NN <--dobj-- echoed/VERB/VBD
# of/ADP/IN <--prep-- design/NOUN/NN
# goulds/PROPN/NNP <--pobj-- of/ADP/IN
# pixel/PROPN/NNP <--compound-- phones/VERB/VBZ
# phones/VERB/VBZ <--relcl-- lid/NOUN/NN
# the/DET/DT <--det-- go/NOUN/NN
# go/NOUN/NN <--dobj-- phones/VERB/VBZ
# as/SCONJ/IN <--prep-- go/NOUN/NN
# a/DET/DT <--det-- design/NOUN/NN
# functional/ADJ/JJ <--amod-- design/NOUN/NN
# utilitarian/ADJ/JJ <--amod-- design/NOUN/NN
# design/NOUN/NN <--pobj-- as/SCONJ/IN
# which/PRON/WDT <--dobj-- appreciate/VERB/VB
# I/PRON/PRP <--nsubj-- appreciate/VERB/VB
# can/AUX/MD <--aux-- appreciate/VERB/VB
# appreciate/VERB/VB <--relcl-- design/NOUN/NN
# ./PUNCT/. <--punct-- is/AUX/VBZ
# but/CCONJ/CC <--cc-- wish/VERB/VBP
# I/PRON/PRP <--nsubj-- wish/VERB/VBP
# wish/VERB/VBP <--ROOT-- wish/VERB/VBP
# it/PRON/PRP <--nsubj-- was/AUX/VBD
# was/AUX/VBD <--ccomp-- wish/VERB/VBP
# slightly/ADV/RB <--advmod-- exciting/ADJ/JJ
# more/ADV/RBR <--advmod-- exciting/ADJ/JJ
# exciting/ADJ/JJ <--acomp-- was/AUX/VBD
# ./PUNCT/. <--punct-- wish/VERB/VBP
# there/PRON/EX <--expl-- is/AUX/VBZ
# is/AUX/VBZ <--ROOT-- is/AUX/VBZ
# one/NUM/CD <--nummod-- design/NOUN/NN
# new/ADJ/JJ <--amod-- design/NOUN/NN
# funky/ADJ/JJ <--amod-- design/NOUN/NN
# design/NOUN/NN <--attr-- is/AUX/VBZ
# flourish/ADJ/JJ <--amod-- design/NOUN/NN
# to/PART/TO <--aux-- found/VERB/VBN
# be/AUX/VB <--auxpass-- found/VERB/VBN
# found/VERB/VBN <--xcomp-- flourish/ADJ/JJ
# the/DET/DT <--det-- book/NOUN/NN
# pixel/NOUN/NN <--compound-- book/NOUN/NN
# book/NOUN/NN <--nsubj-- go/VERB/VB
# go/VERB/VB <--relcl-- design/NOUN/NN
# it/PRON/PRP <--nsubjpass-- ridged/VERB/VBN
# is/AUX/VBZ <--auxpass-- ridged/VERB/VBN
# ridged/VERB/VBN <--relcl-- design/NOUN/NN
# underside/NOUN/NN <--oprd-- ridged/VERB/VBN
# for/ADP/IN <--prep-- ridged/VERB/VBN
# whatever/PRON/WDT <--det-- reason/NOUN/NN
# reason/NOUN/NN <--pcomp-- for/ADP/IN
# pictures/NOUN/NNS <--nsubj-- made/VERB/VBD
# made/VERB/VBD <--relcl-- reason/NOUN/NN
# me/PRON/PRP <--nsubj-- think/VERB/VB
# think/VERB/VB <--ccomp-- made/VERB/VBD
# that/SCONJ/IN <--mark-- was/AUX/VBD
# this/DET/DT <--nsubj-- was/AUX/VBD
# was/AUX/VBD <--ccomp-- think/VERB/VB
# a/DET/DT <--det-- material/NOUN/NN
# different/ADJ/JJ <--amod-- material/NOUN/NN
# softer/ADJ/JJR <--amod-- material/NOUN/NN
# material/NOUN/NN <--attr-- was/AUX/VBD
# than/SCONJ/IN <--prep-- material/NOUN/NN
# the/DET/DT <--det-- magnesium/NOUN/NN
# magnesium/NOUN/NN <--pobj-- than/SCONJ/IN
# that/PRON/WDT <--nsubj-- makes/VERB/VBZ
# makes/VERB/VBZ <--relcl-- magnesium/NOUN/NN
# up/ADP/RP <--prt-- makes/VERB/VBZ
# the/DET/DT <--det-- rest/NOUN/NN
# rest/NOUN/NN <--dobj-- makes/VERB/VBZ
# of/ADP/IN <--prep-- rest/NOUN/NN
# the/DET/DT <--det-- case/NOUN/NN
# goes/VERB/VBZ <--compound-- case/NOUN/NN
# case/NOUN/NN <--pobj-- of/ADP/IN
# but/CCONJ/CC <--cc-- was/AUX/VBD
# it/PRON/PRP <--nsubj-- feel/VERB/VB
# does/AUX/VBZ <--aux-- feel/VERB/VB
# not/PART/RB <--neg-- feel/VERB/VB
# feel/VERB/VB <--conj-- was/AUX/VBD
# any/DET/DT <--advmod-- different/ADJ/JJ
# different/ADJ/JJ <--acomp-- feel/VERB/VB
# than/SCONJ/IN <--prep-- different/ADJ/JJ
# the/DET/DT <--det-- rest/NOUN/NN
# rest/NOUN/NN <--pobj-- than/SCONJ/IN
# of/ADP/IN <--prep-- rest/NOUN/NN
# the/DET/DT <--det-- device/NOUN/NN
# device/NOUN/NN <--compound-- google/PROPN/NNP
# google/PROPN/NNP <--pobj-- of/ADP/IN
# ./PUNCT/. <--punct-- is/AUX/VBZ
# says/VERB/VBZ <--ROOT-- says/VERB/VBZ
# it/PRON/PRP <--nsubj-- design/VERB/VBP
# design/VERB/VBP <--nsubj-- needs/NOUN/NNS
# needs/NOUN/NNS <--ccomp-- says/VERB/VBZ
# word/NOUN/NN <--dobj-- needs/NOUN/NNS
# just/ADV/RB <--advmod-- make/VERB/VB
# to/PART/TO <--aux-- make/VERB/VB
# make/VERB/VB <--advcl-- needs/NOUN/NNS
# the/DET/DT <--det-- laptop/NOUN/NN
# laptop/NOUN/NN <--nsubj-- easier/ADJ/JJR
# easier/ADJ/JJR <--ccomp-- make/VERB/VB
# to/PART/TO <--aux-- grip/VERB/VB
# grip/VERB/VB <--xcomp-- easier/ADJ/JJR
# or/CCONJ/CC <--cc-- grip/VERB/VB
# pull/VERB/VB <--conj-- grip/VERB/VB
# out/SCONJ/IN <--prep-- pull/VERB/VB
# of/ADP/IN <--prep-- out/SCONJ/IN
# a/DET/DT <--det-- sleeve/NOUN/NN
# sleeve/NOUN/NN <--pobj-- of/ADP/IN
# ./PUNCT/. <--punct-- says/VERB/VBZ
# but/CCONJ/CC <--cc-- had/VERB/VBN
# I/PRON/PRP <--nsubj-- had/VERB/VBN
# can/AUX/MD <--aux-- had/VERB/VBN
# not/PART/RB <--neg-- had/VERB/VBN
# have/AUX/VB <--aux-- had/VERB/VBN
# had/VERB/VBN <--ROOT-- had/VERB/VBN
# any/DET/DT <--det-- problems/NOUN/NNS
# problems/NOUN/NNS <--dobj-- had/VERB/VBN
# handling/VERB/VBG <--acl-- problems/NOUN/NNS
# other/ADJ/JJ <--amod-- computers/NOUN/NNS
# computers/NOUN/NNS <--dobj-- handling/VERB/VBG
# ./PUNCT/. <--punct-- had/VERB/VBN
# still/ADV/RB <--advmod-- is/AUX/VBZ
# it/PRON/PRP <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--ROOT-- is/AUX/VBZ
# good/ADJ/JJ <--acomp-- is/AUX/VBZ
# to/PART/TO <--aux-- see/VERB/VB
# see/VERB/VB <--xcomp-- is/AUX/VBZ
# Google/PROPN/NNP <--poss-- side/NOUN/NN
# 's/PART/POS <--case-- Google/PROPN/NNP
# more/ADV/RBR <--advmod-- playful/ADJ/JJ
# playful/ADJ/JJ <--amod-- side/NOUN/NN
# side/NOUN/NN <--dobj-- see/VERB/VB
# on/ADP/IN <--prep-- side/NOUN/NN
# this/DET/DT <--det-- laptop/NOUN/NN
# otherwise/ADV/RB <--advmod-- dull/ADJ/JJ
# dull/ADJ/JJ <--amod-- laptop/NOUN/NN
# laptop/NOUN/NN <--pobj-- on/ADP/IN
# and/CCONJ/CC <--cc-- is/AUX/VBZ
# while/SCONJ/IN <--mark-- be/AUX/VB
# the/DET/DT <--det-- goal/NOUN/NN
# goal/NOUN/NN <--nsubj-- be/AUX/VB
# might/AUX/MD <--aux-- be/AUX/VB
# be/AUX/VB <--conj-- is/AUX/VBZ
# a/DET/DT <--det-- little/ADJ/JJ
# little/ADJ/JJ <--amod-- boring/ADJ/JJ
# boring/ADJ/JJ <--acomp-- be/AUX/VB
# ./PUNCT/. <--punct-- is/AUX/VBZ
# it/PRON/PRP <--nsubj-- feels/VERB/VBZ
# still/ADV/RB <--advmod-- feels/VERB/VBZ
# feels/VERB/VBZ <--ROOT-- feels/VERB/VBZ
# nicer/ADJ/JJR <--acomp-- feels/VERB/VBZ
# and/CCONJ/CC <--cc-- nicer/ADJ/JJR
# sturdier/ADJ/JJR <--conj-- nicer/ADJ/JJR
# than/SCONJ/IN <--prep-- feels/VERB/VBZ
# almost/ADV/RB <--advmod-- any/DET/DT
# any/DET/DT <--nummod-- Chromebook/PROPN/NNP
# other/ADJ/JJ <--amod-- Chromebook/PROPN/NNP
# Chromebook/PROPN/NNP <--pobj-- than/SCONJ/IN
# on/ADP/IN <--prep-- Chromebook/PROPN/NNP
# the/DET/DT <--det-- market/NOUN/NN
# market/NOUN/NN <--pobj-- on/ADP/IN
# ./PUNCT/. <--punct-- feels/VERB/VBZ
# the/DET/DT <--det-- Chromebook/PROPN/NNP
# otherwise/ADV/RB <--advmod-- excellent/ADJ/JJ
# excellent/ADJ/JJ <--amod-- Chromebook/PROPN/NNP
# Asus/PROPN/NNP <--compound-- Chromebook/PROPN/NNP
# Chromebook/PROPN/NNP <--nsubj-- flip/NOUN/NN
# flip/NOUN/NN <--ROOT-- flip/NOUN/NN
# that/PRON/WDT <--dobj-- reviewed/VERB/VBD
# I/PRON/PRP <--nsubj-- reviewed/VERB/VBD
# reviewed/VERB/VBD <--ccomp-- flip/NOUN/NN
# earlier/ADV/RBR <--advmod-- year/NOUN/NN
# this/DET/DT <--det-- year/NOUN/NN
# year/NOUN/NN <--npadvmod-- reviewed/VERB/VBD
# it/PRON/PRP <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--ccomp-- reviewed/VERB/VBD
# much/ADV/RB <--advmod-- heavier/ADJ/JJR
# heavier/ADJ/JJR <--acomp-- is/AUX/VBZ
# than/SCONJ/IN <--prep-- heavier/ADJ/JJR
# the/DET/DT <--det-- go/NOUN/NN
# go/NOUN/NN <--pobj-- than/SCONJ/IN
# for/ADP/IN <--prep-- go/NOUN/NN
# example/NOUN/NN <--pobj-- for/ADP/IN
# ./PUNCT/. <--punct-- flip/NOUN/NN
# Google/PROPN/NNP <--nsubj-- simplified/VERB/VBD
# 's/PART/POS <--case-- Google/PROPN/NNP
# surely/ADV/RB <--advmod-- simplified/VERB/VBD
# simplified/VERB/VBD <--ROOT-- simplified/VERB/VBD
# its/PRON/PRP$ <--poss-- design/NOUN/NN
# design/NOUN/NN <--dobj-- simplified/VERB/VBD
# as/SCONJ/IN <--prep-- simplified/VERB/VBD
# a/DET/DT <--det-- way/NOUN/NN
# way/NOUN/NN <--pobj-- as/SCONJ/IN
# to/PART/TO <--aux-- cut/VERB/VB
# cut/VERB/VB <--relcl-- way/NOUN/NN
# costs/NOUN/NNS <--dobj-- cut/VERB/VB
# and/CCONJ/CC <--cc-- simplified/VERB/VBD
# as/ADV/RB <--prep-- are/AUX/VBP
# such/ADJ/JJ <--amod-- as/ADV/RB
# there/PRON/EX <--expl-- are/AUX/VBP
# are/AUX/VBP <--conj-- simplified/VERB/VBD
# some/DET/DT <--det-- changes/NOUN/NNS
# other/ADJ/JJ <--amod-- changes/NOUN/NNS
# notable/ADJ/JJ <--amod-- changes/NOUN/NNS
# changes/NOUN/NNS <--attr-- are/AUX/VBP
# to/ADP/IN <--prep-- changes/NOUN/NNS
# the/DET/DT <--det-- go/NOUN/NN
# go/NOUN/NN <--pobj-- to/ADP/IN
# compared/VERB/VBN <--prep-- are/AUX/VBP
# to/ADP/IN <--prep-- compared/VERB/VBN
# its/PRON/PRP$ <--poss-- predecessor/NOUN/NN
# predecessor/NOUN/NN <--pobj-- to/ADP/IN
# unlike/ADP/IN <--prep-- predecessor/NOUN/NN
# the/DET/DT <--det-- book/NOUN/NN
# first/ADJ/JJ <--amod-- book/NOUN/NN
# pixel/PROPN/NNP <--compound-- book/NOUN/NN
# book/NOUN/NN <--pobj-- unlike/ADP/IN
# ./PUNCT/. <--punct-- simplified/VERB/VBD
# it/PRON/PRP <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--ROOT-- is/AUX/VBZ
# not/PART/RB <--neg-- is/AUX/VBZ
# a/DET/DT <--det-- mode/NOUN/NN
# convertible/NOUN/NN <--amod-- mode/NOUN/NN
# so/ADV/RB <--advmod-- tablet/ADJ/JJ
# tablet/ADJ/JJ <--compound-- mode/NOUN/NN
# mode/NOUN/NN <--attr-- is/AUX/VBZ
# ./PUNCT/. <--punct-- is/AUX/VBZ
# is/AUX/VBZ <--ROOT-- is/AUX/VBZ
# out/ADV/RB <--advmod-- is/AUX/VBZ
# that/SCONJ/IN <--nsubj-- means/VERB/VBZ
# also/ADV/RB <--advmod-- means/VERB/VBZ
# means/VERB/VBZ <--ccomp-- is/AUX/VBZ
# it/PRON/PRP <--nsubj-- work/VERB/VB
# does/AUX/VBZ <--aux-- work/VERB/VB
# not/PART/RB <--neg-- work/VERB/VB
# work/VERB/VB <--ccomp-- means/VERB/VBZ
# with/ADP/IN <--prep-- work/VERB/VB
# the/DET/DT <--det-- stylus/NOUN/NN
# pixel/PROPN/NNP <--compound-- book/NOUN/NN
# book/NOUN/NN <--compound-- stylus/NOUN/NN
# pen/NOUN/NN <--compound-- stylus/NOUN/NN
# stylus/NOUN/NN <--pobj-- with/ADP/IN
# both/CCONJ/CC <--predet-- book/NOUN/NN
# the/DET/DT <--det-- book/NOUN/NN
# pixel/NOUN/NN <--compound-- book/NOUN/NN
# book/NOUN/NN <--dobj-- work/VERB/VB
# in/ADP/IN <--prep-- book/NOUN/NN
# the/DET/DT <--det-- slate/NOUN/NN
# pixel/NOUN/NN <--compound-- slate/NOUN/NN
# slate/NOUN/NN <--pobj-- in/ADP/IN
# at/ADP/IN <--prep-- work/VERB/VB
# excellent/ADJ/JJ <--amod-- displays/NOUN/NNS
# displays/NOUN/NNS <--pobj-- at/ADP/IN
# with/ADP/IN <--prep-- displays/NOUN/NNS
# a/DET/DT <--det-- ratio/NOUN/NN
# taller/ADJ/JJR <--amod-- ratio/NOUN/NN
# aspect/NOUN/NN <--compound-- ratio/NOUN/NN
# ratio/NOUN/NN <--pobj-- with/ADP/IN
# and/CCONJ/CC <--cc-- ratio/NOUN/NN
# higher/ADJ/JJR <--amod-- resolutions/NOUN/NNS
# resolutions/NOUN/NNS <--conj-- ratio/NOUN/NN
# in/ADP/IN <--prep-- resolutions/NOUN/NNS
# the/DET/DT <--det-- book/NOUN/NN
# pixel/PROPN/NNP <--compound-- book/NOUN/NN
# book/NOUN/NN <--pobj-- in/ADP/IN
# go/VERB/VB <--ccomp-- means/VERB/VBZ
# ./PUNCT/. <--punct-- is/AUX/VBZ
# and/CCONJ/CC <--cc-- 'm/AUX/VBP
# I/PRON/PRP <--nsubj-- 'm/AUX/VBP
# 'm/AUX/VBP <--ROOT-- 'm/AUX/VBP
# a/DET/DT <--det-- little/ADJ/JJ
# little/ADJ/JJ <--amod-- sad/ADJ/JJ
# sad/ADJ/JJ <--acomp-- 'm/AUX/VBP
# to/PART/TO <--aux-- see/VERB/VB
# see/VERB/VB <--xcomp-- sad/ADJ/JJ
# the/DET/DT <--det-- step/NOUN/NN
# step/NOUN/NN <--dobj-- see/VERB/VB
# back/ADV/RB <--advmod-- step/NOUN/NN
# and/CCONJ/CC <--cc-- see/VERB/VB
# display/VERB/VB <--conj-- see/VERB/VB
# quality/NOUN/NN <--dobj-- display/VERB/VB
# here/ADV/RB <--advmod-- display/VERB/VB
# ./PUNCT/. <--punct-- 'm/AUX/VBP
# that/DET/DT <--nsubj-- 's/AUX/VBZ
# 's/AUX/VBZ <--ROOT-- 's/AUX/VBZ
# not/PART/RB <--neg-- 's/AUX/VBZ
# to/PART/TO <--aux-- say/VERB/VB
# say/VERB/VB <--xcomp-- 's/AUX/VBZ
# the/DET/DT <--det-- Dell/PROPN/NNP
# Dell/PROPN/NNP <--nsubj-- has/AUX/VBZ
# has/AUX/VBZ <--ccomp-- say/VERB/VB
# a/DET/DT <--det-- screen/NOUN/NN
# bad/ADJ/JJ <--amod-- screen/NOUN/NN
# screen/NOUN/NN <--dobj-- has/AUX/VBZ
# ./PUNCT/. <--punct-- 's/AUX/VBZ
# it/PRON/PRP <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--ROOT-- is/AUX/VBZ
# just/ADV/RB <--advmod-- is/AUX/VBZ
# not/PART/RB <--neg-- is/AUX/VBZ
# nearly/ADV/RB <--advmod-- gorgeous/ADJ/JJ
# as/ADV/RB <--advmod-- gorgeous/ADJ/JJ
# gorgeous/ADJ/JJ <--acomp-- is/AUX/VBZ
# to/PART/TO <--aux-- look/VERB/VB
# look/VERB/VB <--xcomp-- is/AUX/VBZ
# at/ADP/IN <--prep-- look/VERB/VB
# as/SCONJ/IN <--prep-- look/VERB/VB
# those/DET/DT <--det-- computers/NOUN/NNS
# last/ADJ/JJ <--amod-- computers/NOUN/NNS
# two/NUM/CD <--nummod-- computers/NOUN/NNS
# computers/NOUN/NNS <--pobj-- as/SCONJ/IN
# 1080p/NOUN/NNS <--npadvmod-- look/VERB/VB
# on/ADP/IN <--prep-- look/VERB/VB
# a/DET/DT <--det-- screen/NOUN/NN
# 13.3/NUM/CD <--nummod-- inch/NOUN/NN
# inch/NOUN/NN <--compound-- screen/NOUN/NN
# screen/NOUN/NN <--pobj-- on/ADP/IN
# ./PUNCT/. <--punct-- is/AUX/VBZ
# works/VERB/VBZ <--ROOT-- works/VERB/VBZ
# out/ADP/RP <--prt-- works/VERB/VBZ
# to/ADP/IN <--prep-- works/VERB/VBZ
# 166/NUM/CD <--nummod-- pixels/NOUN/NNS
# pixels/NOUN/NNS <--pobj-- to/ADP/IN
# per/ADP/IN <--prep-- pixels/NOUN/NNS
# inch/NOUN/NN <--pobj-- per/ADP/IN
# a/DET/DT <--det-- cry/NOUN/NN
# far/ADJ/JJ <--amod-- cry/NOUN/NN
# cry/NOUN/NN <--dobj-- works/VERB/VBZ
# from/ADP/IN <--prep-- cry/NOUN/NN
# the/DET/DT <--det-- PPI/PROPN/NNP
# 235/NUM/CD <--nummod-- PPI/PROPN/NNP
# PPI/PROPN/NNP <--pobj-- from/ADP/IN
# on/ADP/IN <--prep-- cry/NOUN/NN
# the/DET/DT <--det-- book/NOUN/NN
# first/ADJ/JJ <--amod-- book/NOUN/NN
# pixel/PROPN/NNP <--compound-- book/NOUN/NN
# book/NOUN/NN <--pobj-- on/ADP/IN
# and/CCONJ/CC <--cc-- book/NOUN/NN
# the/DET/DT <--det-- PPI/PROPN/NNP
# impressive/ADJ/JJ <--amod-- PPI/PROPN/NNP
# 293/NUM/CD <--nummod-- PPI/PROPN/NNP
# PPI/PROPN/NNP <--conj-- book/NOUN/NN
# on/ADP/IN <--prep-- PPI/PROPN/NNP
# the/DET/DT <--det-- sleep/NOUN/NN
# pixel/NOUN/NN <--compound-- sleep/NOUN/NN
# sleep/NOUN/NN <--pobj-- on/ADP/IN
# Google/PROPN/NNP <--nsubj-- build/VERB/VB
# did/AUX/VBD <--aux-- build/VERB/VB
# build/VERB/VB <--ROOT-- build/VERB/VB
# a/DET/DT <--det-- go/NOUN/NN
# go/NOUN/NN <--dobj-- build/VERB/VB
# with/ADP/IN <--prep-- go/NOUN/NN
# a/DET/DT <--det-- screen/NOUN/NN
# 4k/NUM/CD <--compound-- screen/NOUN/NN
# screen/NOUN/NN <--pobj-- with/ADP/IN
# but/CCONJ/CC <--cc-- build/VERB/VB
# that/DET/DT <--det-- option/NOUN/NN
# option/NOUN/NN <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--conj-- build/VERB/VB
# only/ADV/RB <--advmod-- available/ADJ/JJ
# available/ADJ/JJ <--acomp-- is/AUX/VBZ
# if/SCONJ/IN <--mark-- get/VERB/VBP
# you/PRON/PRP <--nsubj-- get/VERB/VBP
# get/VERB/VBP <--advcl-- is/AUX/VBZ
# a/DET/DT <--det-- model/NOUN/NN
# top/ADJ/JJ <--amod-- model/NOUN/NN
# -/PUNCT/HYPH <--punct-- top/ADJ/JJ
# of/ADP/IN <--prep-- top/ADJ/JJ
# -/PUNCT/HYPH <--punct-- of/ADP/IN
# the/DET/DT <--det-- line/NOUN/NN
# -/PUNCT/HYPH <--punct-- line/NOUN/NN
# line/NOUN/NN <--pobj-- of/ADP/IN
# model/NOUN/NN <--dobj-- get/VERB/VBP
# which/PRON/WDT <--nsubj-- costs/VERB/VBZ
# costs/VERB/VBZ <--relcl-- model/NOUN/NN
# an/DET/DT <--det-- hundred/NUM/CD
# eye/NOUN/NN <--npadvmod-- popping/VERB/VBG
# -/PUNCT/HYPH <--punct-- popping/VERB/VBG
# popping/VERB/VBG <--amod-- hundred/NUM/CD
# thirteen/NUM/CD <--compound-- hundred/NUM/CD
# hundred/NUM/CD <--nummod-- dollars/NOUN/NNS
# and/CCONJ/CC <--cc-- hundred/NUM/CD
# ninety/NUM/CD <--compound-- nine/NUM/CD
# nine/NUM/CD <--conj-- hundred/NUM/CD
# dollars/NOUN/NNS <--dobj-- costs/VERB/VBZ
# the/DET/DT <--det-- news/PROPN/NNP
# good/PROPN/NNP <--compound-- news/PROPN/NNP
# news/PROPN/NNP <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--conj-- is/AUX/VBZ
# that/SCONJ/IN <--dobj-- is/AUX/VBZ
# the/DET/DT <--det-- go/NOUN/NN
# go/NOUN/NN <--pcomp-- that/SCONJ/IN
# as/ADV/RB <--advmod-- much/ADJ/JJ
# much/ADJ/JJ <--amod-- bezels/NOUN/NNS
# slimmer/NOUN/NN <--amod-- bezels/NOUN/NNS
# bezels/NOUN/NNS <--appos-- go/NOUN/NN
# around/ADP/IN <--prep-- bezels/NOUN/NNS
# the/DET/DT <--det-- screen/NOUN/NN
# screen/NOUN/NN <--pobj-- around/ADP/IN
# than/SCONJ/IN <--prep-- bezels/NOUN/NNS
# the/DET/DT <--det-- book/NOUN/NN
# original/ADJ/JJ <--amod-- book/NOUN/NN
# pixel/NOUN/NN <--compound-- book/NOUN/NN
# book/NOUN/NN <--pobj-- than/SCONJ/IN
# ./PUNCT/. <--punct-- is/AUX/VBZ
# but/CCONJ/CC <--cc-- prefer/VERB/VBP
# I/PRON/PRP <--nsubj-- prefer/VERB/VBP
# still/ADV/RB <--advmod-- prefer/VERB/VBP
# prefer/VERB/VBP <--ROOT-- prefer/VERB/VBP
# the/DET/DT <--det-- display/NOUN/NN
# taller/ADJ/JJR <--amod-- display/NOUN/NN
# and/CCONJ/CC <--cc-- taller/ADJ/JJR
# more/ADJ/JJR <--conj-- taller/ADJ/JJR
# pixel/VERB/VBP <--conj-- taller/ADJ/JJR
# dense/ADJ/JJ <--amod-- display/NOUN/NN
# display/NOUN/NN <--dobj-- prefer/VERB/VBP
# on/ADP/IN <--prep-- display/NOUN/NN
# that/DET/DT <--det-- laptop/NOUN/NN
# laptop/NOUN/NN <--pobj-- on/ADP/IN
# to/ADP/IN <--prep-- prefer/VERB/VBP
# the/DET/DT <--det-- screen/NOUN/NN
# screen/NOUN/NN <--pobj-- to/ADP/IN
# on/ADP/IN <--prep-- prefer/VERB/VBP
# the/DET/DT <--det-- go/NOUN/NN
# go/NOUN/NN <--pobj-- on/ADP/IN
# fortunately/ADV/RB <--advmod-- prefer/VERB/VBP
# ./PUNCT/. <--punct-- prefer/VERB/VBP
# Google/PROPN/NNP <--nsubj-- skimp/VERB/VB
# did/AUX/VBD <--aux-- skimp/VERB/VB
# not/PART/RB <--neg-- skimp/VERB/VB
# skimp/VERB/VB <--ROOT-- skimp/VERB/VB
# out/ADP/RP <--prt-- skimp/VERB/VB
# on/ADP/IN <--prep-- skimp/VERB/VB
# the/DET/DT <--det-- keyboard/NOUN/NN
# keyboard/NOUN/NN <--pobj-- on/ADP/IN
# ./PUNCT/. <--punct-- skimp/VERB/VB
# the/DET/DT <--det-- book/NOUN/NN
# original/ADJ/JJ <--amod-- book/NOUN/NN
# pixel/PROPN/NNP <--compound-- book/NOUN/NN
# book/NOUN/NN <--nsubj-- offered/VERB/VBD
# offered/VERB/VBD <--ROOT-- offered/VERB/VBD
# a/DET/DT <--det-- experience/NOUN/NN
# great/ADJ/JJ <--amod-- experience/NOUN/NN
# typing/NOUN/NN <--compound-- experience/NOUN/NN
# experience/NOUN/NN <--dobj-- offered/VERB/VBD
# and/CCONJ/CC <--cc-- offered/VERB/VBD
# the/DET/DT <--det-- go/NOUN/NN
# go/NOUN/NN <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--conj-- offered/VERB/VBD
# almost/ADV/RB <--advmod-- good/ADJ/JJ
# as/ADV/RB <--advmod-- good/ADJ/JJ
# good/ADJ/JJ <--acomp-- is/AUX/VBZ
# ./PUNCT/. <--punct-- is/AUX/VBZ
# I/PRON/PRP <--nsubj-- put/VERB/VB
# can/AUX/MD <--aux-- put/VERB/VB
# not/PART/RB <--neg-- put/VERB/VB
# quite/ADV/RB <--advmod-- put/VERB/VB
# put/VERB/VB <--ROOT-- put/VERB/VB
# my/PRON/PRP$ <--poss-- finger/NOUN/NN
# finger/NOUN/NN <--dobj-- put/VERB/VB
# on/ADP/IN <--prep-- put/VERB/VB
# what/PRON/WP <--nsubj-- 's/AUX/VBZ
# 's/AUX/VBZ <--pcomp-- on/ADP/IN
# different/ADJ/JJ <--acomp-- 's/AUX/VBZ
# but/CCONJ/CC <--cc-- put/VERB/VB
# the/DET/DT <--det-- keys/NOUN/NNS
# keys/NOUN/NNS <--nsubj-- feel/VERB/VB
# do/AUX/VBP <--aux-- feel/VERB/VB
# not/PART/RB <--neg-- feel/VERB/VB
# feel/VERB/VB <--conj-- put/VERB/VB
# quite/ADV/RB <--advmod-- soft/ADJ/JJ
# as/ADV/RB <--advmod-- soft/ADJ/JJ
# soft/ADJ/JJ <--acomp-- feel/VERB/VB
# when/ADV/WRB <--advmod-- typing/VERB/VBG
# you/PRON/PRP <--nsubj-- typing/VERB/VBG
# 're/AUX/VBP <--aux-- typing/VERB/VBG
# typing/VERB/VBG <--advcl-- feel/VERB/VB
# that/DET/DT <--det-- set/NOUN/NN
# set/NOUN/NN <--dobj-- typing/VERB/VBG
# ./PUNCT/. <--punct-- feel/VERB/VB
# there/PRON/EX <--expl-- 's/AUX/VBZ
# 's/AUX/VBZ <--ROOT-- 's/AUX/VBZ
# plenty/NOUN/NN <--attr-- 's/AUX/VBZ
# of/ADP/IN <--prep-- plenty/NOUN/NN
# travel/NOUN/NN <--pobj-- of/ADP/IN
# and/CCONJ/CC <--cc-- 's/AUX/VBZ
# they/PRON/PRP <--nsubj-- are/AUX/VBP
# are/AUX/VBP <--conj-- 's/AUX/VBZ
# pretty/ADV/RB <--advmod-- quiet/ADJ/JJ
# quiet/ADJ/JJ <--amod-- Google/PROPN/NNP
# Google/PROPN/NNP <--attr-- are/AUX/VBP
# about/ADP/IN <--prep-- Google/PROPN/NNP
# the/DET/DT <--det-- thing/NOUN/NN
# whole/ADJ/JJ <--amod-- thing/NOUN/NN
# thing/NOUN/NN <--pobj-- about/ADP/IN
# right/ADV/RB <--advmod-- here/ADV/RB
# here/ADV/RB <--advmod-- thing/NOUN/NN
# ./PUNCT/. <--punct-- are/AUX/VBP
# the/DET/DT <--det-- trackpad/PROPN/NNP
# trackpad/PROPN/NNP <--nsubj-- is/AUX/VBZ
# under/ADP/IN <--prep-- trackpad/PROPN/NNP
# their/PRON/PRP$ <--poss-- hand/NOUN/NN
# hand/NOUN/NN <--pobj-- under/ADP/IN
# is/AUX/VBZ <--ROOT-- is/AUX/VBZ
# just/ADV/RB <--advmod-- fine/ADJ/JJ
# fine/ADJ/JJ <--acomp-- is/AUX/VBZ
# ./PUNCT/. <--punct-- is/AUX/VBZ
# it/PRON/PRP <--nsubj-- feels/VERB/VBZ
# feels/VERB/VBZ <--ROOT-- feels/VERB/VBZ
# kind/ADV/RB <--advmod-- of/ADV/RB
# of/ADV/RB <--advmod-- rough/ADJ/JJ
# rough/ADJ/JJ <--acomp-- feels/VERB/VBZ
# under/ADP/IN <--prep-- feels/VERB/VBZ
# my/PRON/PRP$ <--poss-- finger/NOUN/NN
# finger/NOUN/NN <--pobj-- under/ADP/IN
# and/CCONJ/CC <--cc-- feels/VERB/VBZ
# scrolling/NOUN/NN <--csubj-- is/AUX/VBZ
# around/ADP/RP <--advmod-- scrolling/NOUN/NN
# is/AUX/VBZ <--conj-- feels/VERB/VBZ
# not/PART/RB <--neg-- is/AUX/VBZ
# as/ADV/RB <--advmod-- smooth/ADJ/JJ
# smooth/ADJ/JJ <--acomp-- is/AUX/VBZ
# ./PUNCT/. <--punct-- is/AUX/VBZ
# as/SCONJ/IN <--mark-- like/VERB/VB
# I/PRON/PRP <--nsubj-- like/VERB/VB
# would/AUX/MD <--aux-- like/VERB/VB
# like/VERB/VB <--ROOT-- like/VERB/VB
# ./PUNCT/. <--punct-- like/VERB/VB
# it/PRON/PRP <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--ROOT-- is/AUX/VBZ
# not/PART/RB <--neg-- is/AUX/VBZ
# bad/ADJ/JJ <--acomp-- is/AUX/VBZ
# ./PUNCT/. <--punct-- is/AUX/VBZ
# and/CCONJ/CC <--cc-- gotten/VERB/VBN
# I/PRON/PRP <--nsubj-- gotten/VERB/VBN
# have/AUX/VBP <--aux-- gotten/VERB/VBN
# gotten/VERB/VBN <--ROOT-- gotten/VERB/VBN
# used/ADJ/JJ <--acomp-- gotten/VERB/VBN
# to/ADP/IN <--prep-- used/ADJ/JJ
# it/PRON/PRP <--pobj-- to/ADP/IN
# ./PUNCT/. <--punct-- gotten/VERB/VBN
# but/CCONJ/CC <--cc-- used/VERB/VBN
# I/PRON/PRP <--nsubj-- used/VERB/VBN
# have/AUX/VBP <--aux-- used/VERB/VBN
# definitely/ADV/RB <--advmod-- used/VERB/VBN
# used/VERB/VBN <--ROOT-- used/VERB/VBN
# better/ADJ/JJR <--amod-- beds/NOUN/NNS
# touch/NOUN/NN <--compound-- beds/NOUN/NNS
# beds/NOUN/NNS <--dobj-- used/VERB/VBN
# ./PUNCT/. <--punct-- used/VERB/VBN
# well/INTJ/UH <--intj-- cut/VERB/VBD
# google/PROPN/NNP <--nsubj-- cut/VERB/VBD
# cut/VERB/VBD <--ROOT-- cut/VERB/VBD
# some/DET/DT <--det-- corners/NOUN/NNS
# corners/NOUN/NNS <--dobj-- cut/VERB/VBD
# in/ADP/IN <--prep-- cut/VERB/VBD
# the/DET/DT <--det-- department/PROPN/NNP
# design/NOUN/NN <--compound-- department/PROPN/NNP
# department/PROPN/NNP <--pobj-- in/ADP/IN
# the/DET/DT <--det-- book/NOUN/NN
# pixel/PROPN/NNP <--compound-- book/NOUN/NN
# book/NOUN/NN <--nsubj-- go/VERB/VB
# go/VERB/VB <--relcl-- department/PROPN/NNP
# ./PUNCT/. <--punct-- cut/VERB/VBD
# is/AUX/VBZ <--ROOT-- is/AUX/VBZ
# still/ADV/RB <--advmod-- is/AUX/VBZ
# among/ADP/IN <--prep-- is/AUX/VBZ
# the/DET/DT <--det-- Chromebooks/NOUN/NNS
# more/ADV/RBR <--advmod-- powerful/ADJ/JJ
# powerful/ADJ/JJ <--amod-- Chromebooks/NOUN/NNS
# Chromebooks/NOUN/NNS <--pobj-- among/ADP/IN
# out/ADV/RB <--advmod-- there/ADV/RB
# there/ADV/RB <--advmod-- Chromebooks/NOUN/NNS
# ./PUNCT/. <--punct-- is/AUX/VBZ
# the/DET/DT <--det-- model/NOUN/NN
# base/NOUN/NN <--compound-- model/NOUN/NN
# model/NOUN/NN <--nsubj-- pairs/VERB/VBZ
# pairs/VERB/VBZ <--ROOT-- pairs/VERB/VBZ
# an/DET/DT <--det-- generation/NOUN/NN
# eighth/ADJ/JJ <--amod-- generation/NOUN/NN
# generation/NOUN/NN <--compound-- processor/VERB/VBD
# Intel/PROPN/NNP <--compound-- Core/PROPN/NNP
# Core/PROPN/NNP <--compound-- processor/VERB/VBD
# m3/PROPN/NNP <--compound-- processor/VERB/VBD
# processor/VERB/VBD <--dobj-- pairs/VERB/VBZ
# with/ADP/IN <--prep-- pairs/VERB/VBZ
# 8/NUM/CD <--nummod-- gigabytes/NOUN/NNS
# gigabytes/NOUN/NNS <--pobj-- with/ADP/IN
# of/ADP/IN <--prep-- gigabytes/NOUN/NNS
# RAM/PROPN/NNP <--pobj-- of/ADP/IN
# and/CCONJ/CC <--cc-- gigabytes/NOUN/NNS
# 64/NUM/CD <--nummod-- gigabytes/NOUN/NNS
# gigabytes/NOUN/NNS <--conj-- gigabytes/NOUN/NNS
# of/ADP/IN <--prep-- gigabytes/NOUN/NNS
# storage/NOUN/NN <--pobj-- of/ADP/IN
# the/DET/DT <--det-- one/NOUN/NN
# one/NOUN/NN <--dobj-- pairs/VERB/VBZ
# I/PRON/PRP <--nsubj-- reviewed/VERB/VBD
# reviewed/VERB/VBD <--relcl-- one/NOUN/NN
# steps/NOUN/NNS <--dobj-- reviewed/VERB/VBD
# up/ADP/IN <--prep-- reviewed/VERB/VBD
# to/ADP/IN <--prep-- up/ADP/IN
# an/DET/DT <--det-- processor/NOUN/NN
# i5/NOUN/NN <--compound-- processor/NOUN/NN
# processor/NOUN/NN <--pobj-- to/ADP/IN
# in/ADP/IN <--prep-- reviewed/VERB/VBD
# 128/NUM/CD <--nummod-- gigabytes/NOUN/NNS
# gigabytes/NOUN/NNS <--pobj-- in/ADP/IN
# of/ADP/IN <--prep-- gigabytes/NOUN/NNS
# storage/NOUN/NN <--pobj-- of/ADP/IN
# that/PRON/WDT <--mark-- costs/VERB/VBZ
# model/NOUN/NN <--nsubj-- costs/VERB/VBZ
# costs/VERB/VBZ <--relcl-- one/NOUN/NN
# $/SYM/$ <--nmod-- 849/NUM/CD
# 849/NUM/CD <--dobj-- costs/VERB/VBZ
# comparable/ADJ/JJ <--amod-- 849/NUM/CD
# to/ADP/IN <--prep-- comparable/ADJ/JJ
# what/PRON/WP <--nsubj-- defined/VERB/VBD
# defined/VERB/VBD <--pcomp-- to/ADP/IN
# in/ADP/RP <--prep-- defined/VERB/VBD
# ./PUNCT/. <--punct-- pairs/VERB/VBZ
# the/DET/DT <--det-- look/NOUN/NN
# nine/NUM/CD <--nummod-- look/NOUN/NN
# $/SYM/$ <--nmod-- 99/NUM/CD
# 99/NUM/CD <--nummod-- look/NOUN/NN
# pixel/NOUN/NN <--compound-- look/NOUN/NN
# look/NOUN/NN <--ROOT-- look/NOUN/NN
# ./PUNCT/. <--punct-- look/NOUN/NN
# I/PRON/PRP <--nsubj-- wish/VERB/VBP
# wish/VERB/VBP <--ROOT-- wish/VERB/VBP
# I/PRON/PRP <--nsubj-- tried/VERB/VBN
# could/AUX/MD <--aux-- tried/VERB/VBN
# have/AUX/VB <--aux-- tried/VERB/VBN
# tried/VERB/VBN <--ccomp-- wish/VERB/VBP
# that/SCONJ/IN <--det-- model/NOUN/NN
# m3/PROPN/NNP <--compound-- model/NOUN/NN
# model/NOUN/NN <--dobj-- tried/VERB/VBN
# because/SCONJ/IN <--mark-- want/VERB/VBP
# I/PRON/PRP <--nsubj-- want/VERB/VBP
# really/ADV/RB <--advmod-- want/VERB/VBP
# want/VERB/VBP <--advcl-- tried/VERB/VBN
# to/PART/TO <--aux-- see/VERB/VB
# see/VERB/VB <--xcomp-- want/VERB/VBP
# what/PRON/WP <--det-- kind/NOUN/NN
# kind/NOUN/NN <--dobj-- offering/VERB/VBG
# of/ADP/IN <--prep-- kind/NOUN/NN
# performance/NOUN/NN <--pobj-- of/ADP/IN
# Google/PROPN/NNP <--nsubj-- offering/VERB/VBG
# is/AUX/VBZ <--aux-- offering/VERB/VBG
# offering/VERB/VBG <--ccomp-- see/VERB/VB
# for/ADP/IN <--prep-- offering/VERB/VBG
# $/SYM/$ <--nmod-- 650/NUM/CD
# 650/NUM/CD <--nummod-- i5/NOUN/NN
# unsurprisingly/ADJ/JJ <--advmod-- 650/NUM/CD
# Intel/PROPN/NNP <--poss-- i5/NOUN/NN
# 's/PART/POS <--case-- Intel/PROPN/NNP
# Core/PROPN/NNP <--compound-- i5/NOUN/NN
# i5/NOUN/NN <--pobj-- for/ADP/IN
# and/CCONJ/CC <--cc-- i5/NOUN/NN
# eight/NUM/CD <--nummod-- gigs/NOUN/NNS
# gigs/NOUN/NNS <--conj-- i5/NOUN/NN
# of/ADP/IN <--prep-- gigs/NOUN/NNS
# ram/NOUN/NN <--pobj-- of/ADP/IN
# is/AUX/VBZ <--ccomp-- want/VERB/VBP
# plenty/NOUN/NN <--attr-- is/AUX/VBZ
# for/ADP/IN <--prep-- plenty/NOUN/NN
# Chrome/PROPN/NNP <--compound-- OS/PROPN/NNP
# OS/PROPN/NNP <--pobj-- for/ADP/IN
# ./PUNCT/. <--punct-- wish/VERB/VBP
# the/DET/DT <--det-- book/NOUN/NN
# pixel/PROPN/NNP <--compound-- book/NOUN/NN
# book/NOUN/NN <--nsubj-- go/VERB/VBP
# go/VERB/VBP <--ROOT-- go/VERB/VBP
# handle/VERB/VB <--advcl-- go/VERB/VBP
# my/PRON/PRP$ <--poss-- workload/NOUN/NN
# normal/ADJ/JJ <--amod-- workload/NOUN/NN
# workload/NOUN/NN <--dobj-- handle/VERB/VB
# without/ADP/IN <--prep-- handle/VERB/VB
# any/DET/DT <--det-- issues/NOUN/NNS
# issues/NOUN/NNS <--pobj-- without/ADP/IN
# my/PRON/PRP$ <--poss-- routine/NOUN/NN
# routine/NOUN/NN <--nsubj-- involves/VERB/VBZ
# involves/VERB/VBZ <--relcl-- issues/NOUN/NNS
# a/DET/DT <--quantmod-- dozen/NOUN/NN
# dozen/NOUN/NN <--nummod-- tabs/NOUN/NNS
# or/CCONJ/CC <--cc-- dozen/NOUN/NN
# so/ADV/RB <--conj-- dozen/NOUN/NN
# browser/NOUN/NN <--compound-- tabs/NOUN/NNS
# tabs/NOUN/NNS <--compound-- slack/NOUN/NN
# TweetDeck/PROPN/NNP <--compound-- hangouts/VERB/VBZ
# hangouts/VERB/VBZ <--compound-- slack/NOUN/NN
# slack/NOUN/NN <--conj-- go/VERB/VBP
# todoist/ADJ/JJ <--compound-- keep/VERB/VBP
# google/PROPN/NNP <--compound-- keep/VERB/VBP
# keep/VERB/VBP <--dobj-- slack/NOUN/NN
# and/CCONJ/CC <--cc-- keep/VERB/VBP
# Trello/PROPN/NNP <--conj-- keep/VERB/VBP
# all/DET/DT <--dep-- running/VERB/VBG
# running/VERB/VBG <--csubj-- worked/VERB/VBD
# as/SCONJ/IN <--prep-- running/VERB/VBG
# Chrome/PROPN/NNP <--compound-- apps/VERB/VBZ
# apps/VERB/VBZ <--pobj-- as/SCONJ/IN
# along/ADP/RP <--prep-- running/VERB/VBG
# with/ADP/IN <--prep-- along/ADP/RP
# the/DET/DT <--det-- app/NOUN/NN
# occasional/ADJ/JJ <--amod-- app/NOUN/NN
# Android/PROPN/NNP <--compound-- app/NOUN/NN
# app/NOUN/NN <--pobj-- with/ADP/IN
# or/CCONJ/CC <--cc-- with/ADP/IN
# to/ADP/IN <--conj-- with/ADP/IN
# Adobe/PROPN/NNP <--poss-- music/NOUN/NN
# 's/PART/POS <--case-- Adobe/PROPN/NNP
# Lightroom/PROPN/NNP <--nmod-- Netflix/PROPN/NNP
# Netflix/PROPN/NNP <--nmod-- music/NOUN/NN
# and/CCONJ/CC <--cc-- Netflix/PROPN/NNP
# YouTube/PROPN/NNP <--conj-- Netflix/PROPN/NNP
# music/NOUN/NN <--pobj-- to/ADP/IN
# all/DET/DT <--nsubj-- worked/VERB/VBD
# mostly/ADV/RB <--advmod-- worked/VERB/VBD
# worked/VERB/VBD <--conj-- go/VERB/VBP
# well/ADV/RB <--advmod-- worked/VERB/VBD
# although/SCONJ/IN <--mark-- had/AUX/VBD
# music/NOUN/NN <--compound-- playback/NOUN/NN
# playback/NOUN/NN <--nsubj-- had/AUX/VBD
# had/AUX/VBD <--advcl-- worked/VERB/VBD
# the/DET/DT <--det-- hiccup/NOUN/NN
# occasional/ADJ/JJ <--amod-- hiccup/NOUN/NN
# low/ADJ/JJ <--amod-- memory/NOUN/NN
# memory/NOUN/NN <--compound-- hiccup/NOUN/NN
# hiccup/NOUN/NN <--dobj-- had/AUX/VBD
# which/PRON/WDT <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--relcl-- hiccup/NOUN/NN
# frustrating/ADJ/JJ <--acomp-- is/AUX/VBZ
# ./PUNCT/. <--punct-- go/VERB/VBP
# notably/ADV/RB <--advmod-- happen/VERB/VB
# this/DET/DT <--nsubj-- happen/VERB/VB
# did/AUX/VBD <--aux-- happen/VERB/VB
# not/PART/RB <--neg-- happen/VERB/VB
# happen/VERB/VB <--ROOT-- happen/VERB/VB
# when/ADV/WRB <--advmod-- using/VERB/VBG
# using/VERB/VBG <--advcl-- happen/VERB/VB
# YouTube/PROPN/NNP <--compound-- music/NOUN/NN
# music/NOUN/NN <--dobj-- using/VERB/VBG
# as/SCONJ/IN <--prep-- using/VERB/VBG
# a/DET/DT <--det-- tab/NOUN/NN
# browser/NOUN/NN <--compound-- tab/NOUN/NN
# tab/NOUN/NN <--pobj-- as/SCONJ/IN
# ./PUNCT/. <--punct-- happen/VERB/VB
# this/DET/DT <--nsubj-- reinforces/VERB/VBZ
# reinforces/VERB/VBZ <--ROOT-- reinforces/VERB/VBZ
# my/PRON/PRP$ <--poss-- belief/NOUN/NN
# belief/NOUN/NN <--dobj-- reinforces/VERB/VBZ
# that/SCONJ/IN <--mark-- are/AUX/VBP
# Android/NOUN/NN <--compound-- apps/NOUN/NNS
# apps/NOUN/NNS <--nsubj-- are/AUX/VBP
# on/ADP/IN <--prep-- apps/NOUN/NNS
# Chrome/PROPN/NNP <--pobj-- on/ADP/IN
# are/AUX/VBP <--acl-- belief/NOUN/NN
# not/PART/RB <--neg-- are/AUX/VBP
# usually/ADV/RB <--advmod-- are/AUX/VBP
# worth/ADJ/JJ <--acomp-- are/AUX/VBP
# using/VERB/VBG <--xcomp-- worth/ADJ/JJ
# if/SCONJ/IN <--mark-- 's/AUX/VBZ
# there/PRON/EX <--expl-- 's/AUX/VBZ
# 's/AUX/VBZ <--ccomp-- using/VERB/VBG
# a/DET/DT <--det-- alternative/NOUN/NN
# web/NOUN/NN <--npadvmod-- based/VERB/VBN
# -/PUNCT/HYPH <--punct-- based/VERB/VBN
# based/VERB/VBN <--amod-- alternative/NOUN/NN
# alternative/NOUN/NN <--attr-- 's/AUX/VBZ
# overall/NOUN/NN <--advmod-- 's/AUX/VBZ
# ./PUNCT/. <--punct-- reinforces/VERB/VBZ
# I/PRON/PRP <--nsubj-- imagine/VERB/VB
# can/AUX/MD <--aux-- imagine/VERB/VB
# not/PART/RB <--neg-- imagine/VERB/VB
# imagine/VERB/VB <--ROOT-- imagine/VERB/VB
# most/ADJ/JJS <--amod-- people/NOUN/NNS
# people/NOUN/NNS <--nsubj-- need/VERB/VBP
# need/VERB/VBP <--ccomp-- imagine/VERB/VB
# to/PART/TO <--aux-- upgrade/VERB/VB
# upgrade/VERB/VB <--xcomp-- need/VERB/VBP
# from/ADP/IN <--prep-- upgrade/VERB/VB
# the/DET/DT <--det-- model/NOUN/NN
# $/SYM/$ <--nmod-- 849/NUM/CD
# 849/NUM/CD <--nummod-- model/NOUN/NN
# model/NOUN/NN <--pobj-- from/ADP/IN
# I/PRON/PRP <--nsubj-- tried/VERB/VBD
# tried/VERB/VBD <--relcl-- model/NOUN/NN
# Google/PROPN/NNP <--nsubj-- selling/VERB/VBG
# was/AUX/VBD <--aux-- selling/VERB/VBG
# also/ADV/RB <--advmod-- selling/VERB/VBG
# selling/VERB/VBG <--ccomp-- tried/VERB/VBD
# in/ADP/IN <--prep-- selling/VERB/VBG
# 999/NUM/CD <--nummod-- configuration/NOUN/NN
# configuration/NOUN/NN <--pobj-- in/ADP/IN
# that/PRON/WDT <--nsubj-- doubles/VERB/VBZ
# doubles/VERB/VBZ <--relcl-- configuration/NOUN/NN
# the/DET/DT <--det-- range/NOUN/NN
# range/NOUN/NN <--dobj-- doubles/VERB/VBZ
# of/ADP/IN <--prep-- range/NOUN/NN
# 16/NUM/CD <--nummod-- gigabytes/NOUN/NNS
# gigabytes/NOUN/NNS <--pobj-- of/ADP/IN
# well/ADV/RB <--advmod-- doubles/VERB/VBZ
# that/SCONJ/IN <--det-- model/NOUN/NN
# $/SYM/$ <--quantmod-- model/NOUN/NN
# 13.99/NUM/CD <--nummod-- model/NOUN/NN
# model/NOUN/NN <--dobj-- doubles/VERB/VBZ
# I/PRON/PRP <--nsubj-- mentioned/VERB/VBD
# mentioned/VERB/VBD <--relcl-- model/NOUN/NN
# includes/VERB/VBZ <--conj-- imagine/VERB/VB
# a/DET/DT <--det-- processor/VERB/VBD
# core/NOUN/NN <--nmod-- processor/VERB/VBD
# i7/NOUN/NN <--compound-- processor/VERB/VBD
# processor/VERB/VBD <--dobj-- includes/VERB/VBZ
# 16/NUM/CD <--nummod-- gigs/NOUN/NNS
# gigs/NOUN/NNS <--appos-- processor/VERB/VBD
# of/ADP/IN <--prep-- gigs/NOUN/NNS
# ram/NOUN/NN <--pobj-- of/ADP/IN
# 206/NUM/CD <--nummod-- gigs/NOUN/NNS
# gigs/NOUN/NNS <--appos-- ram/NOUN/NN
# of/ADP/IN <--prep-- gigs/NOUN/NNS
# storage/NOUN/NN <--pobj-- of/ADP/IN
# and/CCONJ/CC <--cc-- gigs/NOUN/NNS
# a/DET/DT <--det-- display/NOUN/NN
# 4k/NUM/CD <--compound-- display/NOUN/NN
# display/NOUN/NN <--conj-- gigs/NOUN/NNS
# ./PUNCT/. <--punct-- imagine/VERB/VB
# well/INTJ/UH <--intj-- enjoy/VERB/VB
# I/PRON/PRP <--nsubj-- enjoy/VERB/VB
# would/AUX/MD <--aux-- enjoy/VERB/VB
# surely/ADV/RB <--advmod-- enjoy/VERB/VB
# enjoy/VERB/VB <--ROOT-- enjoy/VERB/VB
# that/SCONJ/IN <--det-- screen/NOUN/NN
# high/ADJ/JJ <--amod-- screen/NOUN/NN
# res/NOUN/NN <--compound-- screen/NOUN/NN
# screen/NOUN/NN <--dobj-- enjoy/VERB/VB
# ./PUNCT/. <--punct-- enjoy/VERB/VB
# I/PRON/PRP <--nsubj-- think/VERB/VB
# do/AUX/VBP <--aux-- think/VERB/VB
# not/PART/RB <--neg-- think/VERB/VB
# think/VERB/VB <--ROOT-- think/VERB/VB
# it/PRON/PRP <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--ccomp-- think/VERB/VB
# a/DET/DT <--det-- upgrade/NOUN/NN
# worthwhile/ADJ/JJ <--amod-- upgrade/NOUN/NN
# upgrade/NOUN/NN <--attr-- is/AUX/VBZ
# for/ADP/IN <--prep-- upgrade/NOUN/NN
# anyone/PRON/NN <--pobj-- for/ADP/IN
# ./PUNCT/. <--punct-- think/VERB/VB
# the/DET/DT <--det-- book/NOUN/NN
# pixel/PROPN/NNP <--compound-- book/NOUN/NN
# book/NOUN/NN <--nsubj-- holds/VERB/VBZ
# though/ADV/RB <--advmod-- holds/VERB/VBZ
# also/ADV/RB <--advmod-- holds/VERB/VBZ
# holds/VERB/VBZ <--ROOT-- holds/VERB/VBZ
# up/ADP/RP <--prt-- holds/VERB/VBZ
# pretty/ADV/RB <--advmod-- well/ADV/RB
# well/ADV/RB <--advmod-- holds/VERB/VBZ
# in/ADP/IN <--prep-- holds/VERB/VBZ
# the/DET/DT <--det-- something/PRON/NN
# battery/NOUN/NN <--compound-- side/NOUN/NN
# side/NOUN/NN <--compound-- something/PRON/NN
# something/PRON/NN <--pobj-- in/ADP/IN
# that/PRON/WDT <--nsubj-- was/AUX/VBD
# was/AUX/VBD <--relcl-- something/PRON/NN
# not/PART/RB <--neg-- was/AUX/VBD
# always/ADV/RB <--advmod-- was/AUX/VBD
# true/ADJ/JJ <--acomp-- was/AUX/VBD
# with/ADP/IN <--prep-- true/ADJ/JJ
# the/DET/DT <--det-- original/ADJ/JJ
# original/ADJ/JJ <--pobj-- with/ADP/IN
# and/CCONJ/CC <--cc-- original/ADJ/JJ
# our/PRON/PRP$ <--poss-- test/NOUN/NN
# video/NOUN/NN <--compound-- playback/NOUN/NN
# playback/NOUN/NN <--compound-- test/NOUN/NN
# test/NOUN/NN <--conj-- original/ADJ/JJ
# ./PUNCT/. <--punct-- holds/VERB/VBZ
# the/DET/DT <--det-- go/NOUN/NN
# go/NOUN/NN <--nsubj-- ran/VERB/VBD
# ran/VERB/VBD <--ROOT-- ran/VERB/VBD
# for/ADP/IN <--prep-- ran/VERB/VBD
# just/ADV/RB <--advmod-- 13/NUM/CD
# over/ADP/IN <--quantmod-- 13/NUM/CD
# 13/NUM/CD <--nummod-- hours/NOUN/NNS
# and/CCONJ/CC <--cc-- 13/NUM/CD
# a/DET/DT <--quantmod-- half/NOUN/NN
# half/NOUN/NN <--conj-- 13/NUM/CD
# hours/NOUN/NNS <--pobj-- for/ADP/IN
# before/ADP/IN <--prep-- ran/VERB/VBD
# shutting/VERB/VBG <--pcomp-- before/ADP/IN
# down/ADP/RP <--prt-- shutting/VERB/VBG
# ./PUNCT/. <--punct-- ran/VERB/VBD
# that/DET/DT <--nsubj-- 's/AUX/VBZ
# 's/AUX/VBZ <--ROOT-- 's/AUX/VBZ
# more/ADJ/JJR <--amod-- hour/NOUN/NN
# than/SCONJ/IN <--quantmod-- hour/NOUN/NN
# an/DET/DT <--det-- hour/NOUN/NN
# hour/NOUN/NN <--npadvmod-- longer/ADV/RBR
# longer/ADV/RBR <--acomp-- 's/AUX/VBZ
# than/SCONJ/IN <--prep-- longer/ADV/RBR
# the/DET/DT <--det-- claims/VERB/VBZ
# 12/NUM/CD <--nummod-- hour/NOUN/NN
# hour/NOUN/NN <--compound-- claims/VERB/VBZ
# battery/NOUN/NN <--compound-- life/NOUN/NN
# life/NOUN/NN <--compound-- google/PROPN/NNP
# google/PROPN/NNP <--compound-- claims/VERB/VBZ
# claims/VERB/VBZ <--pobj-- than/SCONJ/IN
# with/ADP/IN <--prep-- claims/VERB/VBZ
# mixed/ADJ/JJ <--amod-- usage/NOUN/NN
# usage/NOUN/NN <--pobj-- with/ADP/IN
# ./PUNCT/. <--punct-- 's/AUX/VBZ
# unfortunately/ADV/RB <--advmod-- came/VERB/VBD
# I/PRON/PRP <--nsubj-- came/VERB/VBD
# never/ADV/RB <--neg-- came/VERB/VBD
# came/VERB/VBD <--ROOT-- came/VERB/VBD
# close/ADV/RB <--advmod-- 12/NUM/CD
# to/PART/TO <--quantmod-- 12/NUM/CD
# 12/NUM/CD <--nummod-- hours/NOUN/NNS
# hours/NOUN/NNS <--dobj-- came/VERB/VBD
# and/CCONJ/CC <--cc-- came/VERB/VBD
# putting/VERB/VBG <--conj-- came/VERB/VBD
# the/DET/DT <--det-- go/NOUN/NN
# go/NOUN/NN <--dobj-- putting/VERB/VBG
# through/ADP/IN <--prep-- putting/VERB/VBG
# my/PRON/PRP$ <--poss-- routine/NOUN/NN
# normal/ADJ/JJ <--amod-- routine/NOUN/NN
# routine/NOUN/NN <--pobj-- through/ADP/IN
# but/CCONJ/CC <--cc-- came/VERB/VBD
# it/PRON/PRP <--nsubj-- last/VERB/VB
# did/AUX/VBD <--aux-- last/VERB/VB
# last/VERB/VB <--conj-- came/VERB/VBD
# more/ADJ/JJR <--amod-- eight/NUM/CD
# than/SCONJ/IN <--quantmod-- eight/NUM/CD
# eight/NUM/CD <--nummod-- hours/NOUN/NNS
# hours/NOUN/NNS <--dobj-- last/VERB/VB
# which/PRON/WDT <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--relcl-- hours/NOUN/NNS
# a/DET/DT <--det-- improvement/NOUN/NN
# definite/ADJ/JJ <--amod-- improvement/NOUN/NN
# improvement/NOUN/NN <--attr-- is/AUX/VBZ
# over/ADP/IN <--prep-- improvement/NOUN/NN
# the/DET/DT <--det-- book/NOUN/NN
# first/ADJ/JJ <--amod-- book/NOUN/NN
# pixel/PROPN/NNP <--compound-- book/NOUN/NN
# book/NOUN/NN <--pobj-- over/ADP/IN
# ./PUNCT/. <--punct-- last/VERB/VB
# all/DET/PDT <--predet-- this/DET/DT
# this/DET/DT <--nsubj-- said/VERB/VBD
# said/VERB/VBD <--ROOT-- said/VERB/VBD
# ./PUNCT/. <--punct-- said/VERB/VBD
# the/DET/DT <--det-- book/NOUN/NN
# pixel/PROPN/NNP <--compound-- book/NOUN/NN
# book/NOUN/NN <--nsubj-- go/PROPN/NNP
# go/PROPN/NNP <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--ROOT-- is/AUX/VBZ
# a/DET/DT <--det-- device/NOUN/NN
# much/ADV/RB <--advmod-- easier/ADJ/JJR
# easier/ADJ/JJR <--amod-- device/NOUN/NN
# device/NOUN/NN <--attr-- is/AUX/VBZ
# to/PART/TO <--aux-- evaluate/VERB/VB
# evaluate/VERB/VB <--relcl-- device/NOUN/NN
# than/SCONJ/IN <--prep-- evaluate/VERB/VB
# either/CCONJ/CC <--preconj-- book/NOUN/NN
# the/DET/DT <--det-- book/NOUN/NN
# first/ADJ/JJ <--amod-- book/NOUN/NN
# pixel/NOUN/NN <--compound-- book/NOUN/NN
# book/NOUN/NN <--pobj-- than/SCONJ/IN
# or/CCONJ/CC <--cc-- book/NOUN/NN
# the/DET/DT <--det-- pixel/NOUN/NN
# pixel/NOUN/NN <--conj-- book/NOUN/NN
# Slaten/PROPN/NNP <--ROOT-- Slaten/PROPN/NNP
# ./PUNCT/. <--punct-- Slaten/PROPN/NNP
# it/PRON/PRP <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--ROOT-- is/AUX/VBZ
# a/DET/DT <--det-- laptop/NOUN/NN
# standard/ADJ/JJ <--amod-- familiar/ADJ/JJ
# familiar/ADJ/JJ <--amod-- laptop/NOUN/NN
# almost/ADV/RB <--advmod-- boring/ADJ/JJ
# boring/ADJ/JJ <--amod-- laptop/NOUN/NN
# laptop/NOUN/NN <--attr-- is/AUX/VBZ
# ./PUNCT/. <--punct-- is/AUX/VBZ
# but/CCONJ/CC <--cc-- of/ADP/IN
# instead/ADV/RB <--advmod-- of/ADP/IN
# of/ADP/IN <--ROOT-- of/ADP/IN
# figuring/VERB/VBG <--pcomp-- of/ADP/IN
# out/ADP/RP <--prt-- figuring/VERB/VBG
# if/SCONJ/IN <--mark-- works/VERB/VBZ
# cromoz/PROPN/NNP <--nsubj-- works/VERB/VBZ
# works/VERB/VBZ <--advcl-- figuring/VERB/VBG
# on/ADP/IN <--prep-- works/VERB/VBZ
# a/DET/DT <--det-- tablet/NOUN/NN
# convertible/ADJ/JJ <--amod-- tablet/NOUN/NN
# tablet/NOUN/NN <--pobj-- on/ADP/IN
# or/CCONJ/CC <--cc-- works/VERB/VBZ
# if/SCONJ/IN <--mark-- 're/AUX/VBP
# you/PRON/PRP <--nsubj-- 're/AUX/VBP
# 're/AUX/VBP <--conj-- works/VERB/VBZ
# willing/ADJ/JJ <--acomp-- 're/AUX/VBP
# to/PART/TO <--aux-- spend/VERB/VB
# spend/VERB/VB <--xcomp-- willing/ADJ/JJ
# $/SYM/$ <--nmod-- 1000/NUM/CD
# 1000/NUM/CD <--dobj-- spend/VERB/VB
# on/ADP/IN <--prep-- spend/VERB/VB
# a/DET/DT <--det-- laptop/NOUN/NN
# premium/ADJ/JJ <--compound-- laptop/NOUN/NN
# laptop/NOUN/NN <--pobj-- on/ADP/IN
# ./PUNCT/. <--punct-- of/ADP/IN
# the/DET/DT <--det-- go/NOUN/NN
# go/NOUN/NN <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--ROOT-- is/AUX/VBZ
# just/ADV/RB <--advmod-- device/NOUN/NN
# a/DET/DT <--det-- device/NOUN/NN
# straightforward/ADJ/JJ <--amod-- device/NOUN/NN
# no/DET/DT <--det-- frills/NOUN/NNS
# -/PUNCT/HYPH <--punct-- frills/NOUN/NNS
# frills/NOUN/NNS <--compound-- device/NOUN/NN
# device/NOUN/NN <--attr-- is/AUX/VBZ
# ./PUNCT/. <--punct-- is/AUX/VBZ
# it/PRON/PRP <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--ROOT-- is/AUX/VBZ
# still/ADV/RB <--advmod-- is/AUX/VBZ
# not/PART/RB <--neg-- is/AUX/VBZ
# particularly/ADV/RB <--advmod-- cheap/ADJ/JJ
# cheap/ADJ/JJ <--acomp-- is/AUX/VBZ
# especially/ADV/RB <--advmod-- step/VERB/VBP
# if/SCONJ/IN <--mark-- step/VERB/VBP
# you/PRON/PRP <--nsubj-- step/VERB/VBP
# step/VERB/VBP <--advcl-- is/AUX/VBZ
# up/ADP/RP <--prt-- step/VERB/VBP
# to/ADP/IN <--prep-- step/VERB/VBP
# the/DET/DT <--det-- processor/NOUN/NN
# i5/NOUN/NN <--compound-- processor/NOUN/NN
# processor/NOUN/NN <--pobj-- to/ADP/IN
# I/PRON/PRP <--nsubj-- tried/VERB/VBD
# tried/VERB/VBD <--relcl-- processor/NOUN/NN
# but/CCONJ/CC <--cc-- processor/NOUN/NN
# premium/NOUN/NN <--compound-- Chromebooks/PROPN/NNP
# Chromebooks/PROPN/NNP <--conj-- processor/NOUN/NN
# in/ADP/IN <--prep-- processor/NOUN/NN
# the/DET/DT <--det-- range/NOUN/NN
# 600/NUM/CD <--quantmod-- 800/NUM/CD
# to/PART/TO <--quantmod-- 800/NUM/CD
# 800/NUM/CD <--nummod-- dollar/NOUN/NN
# dollar/NOUN/NN <--compound-- range/NOUN/NN
# range/NOUN/NN <--pobj-- in/ADP/IN
# ./PUNCT/. <--punct-- is/AUX/VBZ
# are/AUX/VBP <--aux-- becoming/VERB/VBG
# becoming/VERB/VBG <--ROOT-- becoming/VERB/VBG
# more/ADV/RBR <--advmod-- common/ADJ/JJ
# common/ADJ/JJ <--acomp-- becoming/VERB/VBG
# now/ADV/RB <--advmod-- becoming/VERB/VBG
# and/CCONJ/CC <--cc-- becoming/VERB/VBG
# now/ADV/RB <--advmod-- has/AUX/VBZ
# Google/PROPN/NNP <--nsubj-- has/AUX/VBZ
# has/AUX/VBZ <--conj-- becoming/VERB/VBG
# something/PRON/NN <--dobj-- has/AUX/VBZ
# that/PRON/WDT <--nsubj-- compete/VERB/VB
# can/AUX/MD <--aux-- compete/VERB/VB
# compete/VERB/VB <--relcl-- something/PRON/NN
# on/ADP/IN <--prep-- compete/VERB/VB
# quality/NOUN/NN <--pobj-- on/ADP/IN
# as/ADV/RB <--advmod-- as/SCONJ/IN
# well/ADV/RB <--advmod-- as/SCONJ/IN
# as/SCONJ/IN <--cc-- quality/NOUN/NN
# price/NOUN/NN <--conj-- quality/NOUN/NN
# ./PUNCT/. <--punct-- has/AUX/VBZ
# yes/INTJ/UH <--intj-- get/AUX/VB
# you/PRON/PRP <--nsubj-- get/AUX/VB
# can/AUX/MD <--aux-- get/AUX/VB
# still/ADV/RB <--advmod-- get/AUX/VB
# get/AUX/VB <--ROOT-- get/AUX/VB
# a/DET/DT <--det-- Chromebook/PROPN/NNP
# Chromebook/PROPN/NNP <--dobj-- get/AUX/VB
# for/ADP/IN <--prep-- Chromebook/PROPN/NNP
# less/ADJ/JJR <--amod-- money/NOUN/NN
# money/NOUN/NN <--pobj-- for/ADP/IN
# than/SCONJ/IN <--prep-- get/AUX/VB
# what/PRON/WP <--dobj-- asked/VERB/VBN
# Google/PROPN/NNP <--nsubjpass-- asked/VERB/VBN
# was/AUX/VBD <--auxpass-- asked/VERB/VBN
# asked/VERB/VBN <--pcomp-- than/SCONJ/IN
# for/ADP/IN <--prep-- asked/VERB/VBN
# the/DET/DT <--det-- NGO/PROPN/NNP
# NGO/PROPN/NNP <--pobj-- for/ADP/IN
# if/SCONJ/IN <--mark-- think/VERB/VBP
# you/PRON/PRP <--nsubj-- think/VERB/VBP
# think/VERB/VBP <--advcl-- asked/VERB/VBN
# a/DET/DT <--det-- Chromebook/PROPN/NNP
# Chromebook/PROPN/NNP <--nsubj-- be/AUX/VB
# can/AUX/MD <--aux-- be/AUX/VB
# be/AUX/VB <--ccomp-- think/VERB/VBP
# your/PRON/PRP$ <--poss-- computer/NOUN/NN
# main/ADJ/JJ <--amod-- computer/NOUN/NN
# computer/NOUN/NN <--attr-- be/AUX/VB
# and/CCONJ/CC <--cc-- be/AUX/VB
# do/AUX/VBP <--aux-- mind/VERB/VB
# not/PART/RB <--neg-- mind/VERB/VB
# mind/VERB/VB <--conj-- be/AUX/VB
# paying/VERB/VBG <--xcomp-- mind/VERB/VB
# a/DET/DT <--det-- extra/ADJ/JJ
# little/ADJ/JJ <--amod-- extra/ADJ/JJ
# extra/ADJ/JJ <--dobj-- paying/VERB/VBG
# for/ADP/IN <--prep-- paying/VERB/VBG
# a/DET/DT <--det-- device/NOUN/NN
# device/NOUN/NN <--pobj-- for/ADP/IN
# that/PRON/WDT <--nsubj-- 's/AUX/VBZ
# 's/AUX/VBZ <--relcl-- device/NOUN/NN
# thin/ADJ/JJ <--amod-- light/NOUN/NN
# light/NOUN/NN <--attr-- 's/AUX/VBZ
# and/CCONJ/CC <--cc-- 's/AUX/VBZ
# well/ADV/RB <--advmod-- engineered/VERB/VBD
# engineered/VERB/VBD <--acl-- device/NOUN/NN
# the/DET/DT <--det-- book/NOUN/NN
# pixel/NOUN/NN <--compound-- book/NOUN/NN
# book/NOUN/NN <--dobj-- engineered/VERB/VBD
# go/VERB/VB <--dobj-- engineered/VERB/VBD
# will/AUX/MD <--aux-- meet/VERB/VB
# likely/ADV/RB <--advmod-- meet/VERB/VB
# meet/VERB/VB <--ccomp-- think/VERB/VBP
# your/PRON/PRP$ <--poss-- needs/NOUN/NNS
# needs/NOUN/NNS <--dobj-- meet/VERB/VB
# thanks/NOUN/NNS <--npadvmod-- meet/VERB/VB
# for/ADP/IN <--prep-- thanks/NOUN/NNS
# watching/NOUN/NN <--pcomp-- for/ADP/IN
# and/CCONJ/CC <--cc-- watching/NOUN/NN
# subscribe/VERB/VB <--conj-- watching/NOUN/NN
# to/ADP/IN <--prep-- subscribe/VERB/VB
# and/CCONJ/CC <--cc-- subscribe/VERB/VB
# gadgets/VERB/VBZ <--conj-- subscribe/VERB/VB
# YouTube/PROPN/NNP <--compound-- channel/NOUN/NN
# channel/NOUN/NN <--dobj-- gadgets/VERB/VBZ
# for/ADP/IN <--prep-- channel/NOUN/NN
# more/ADJ/JJR <--amod-- news/NOUN/NN
# news/NOUN/NN <--pobj-- for/ADP/IN
# and/CCONJ/CC <--cc-- news/NOUN/NN
# reviews/NOUN/NNS <--conj-- news/NOUN/NN
# ./PUNCT/. <--punct-- get/AUX/VB

# %%
examples[0]
# Out:
# " [Music] hey what is up guys mkbhd here this is the pixel for excel this is one of the phones I was looking forward to the most this entire year for 2019 for a couple of reasons and so now I've been using it daily since its unveiling this is my honest review so let's just start with the wait looks I honestly think it's a pretty decent looking phone it's low-key really clean there's almost no markings along the back just the Google G at the bottom matte black aluminum rails as part of the design all the way around the phone speaker slots at the bottom lined up with the USB type-c port and the colored power button of course on every version and the whole back of the phone on two of the colors is this soft touch matte finish which does a great job of not showing fingerprints it doesn't seem to scratch very easily at all so of the three colors available I'm gonna say this white this Panda version is the best one that power buttons pretty sweet then I'm gonna say oh so orange is in second place not so great power button but at least it's matte and then that jet-black weirdly very glossy version is in third place fun fact though since the rails are still matte black you can slap a matte black D brand skin on the back of any of these phones and you just created the matte black everything phone Google should have made in the first place so link to that below and of course shout out to D brand for sponsoring this video the pixels square camera bump is again annoyingly a little bit raised but I don't find this as drastic as say Apple's larger double raised triple camera bump but more on the cameras later so yeah you know what generally it's grown on me pretty decent looking phone I was though let a little bit down by the not super clicky buttons just the volume ones mainly but on the other hand something a lot of people have missed that's good to know the phone is now ip68 water-resistant it still has the squeeze sensitivity for the assistant and it still has stereo speakers so they're not front-facing pair like they were last year but they are still a good sounding solid pair with the slots at the bottom and the earpiece speaker combined the worst part about the way this phone looks is the front the part you look at most of the time I'm not a fan of the forehead it has a smaller chin at the bottom than before but yeah that big forehead I don't like it I'm still kind of barely getting used to it and overall the reason for the forehead doesn't really have me convinced so there's a cluster of new sensors up here in the top including the selfie camera then also infrared projector receiver and radar which is new in any smartphone and this new sensor suite up here is good for two things the fastest face unlock in any smartphone and some gestures okay maybe it makes me a little not forward-thinking but I still like fingerprint sensors and this phone has none of that the face unlock is the only biometric unlock this phone has and I find myself missing a fingerprint sensor and the rate of improvement for fingerprint sensors under the glass has been pretty good so that move was not my favorite pixel for uses a radar sensor to essentially project a little bubble around the phone to see when things are near it when things are in the bubble want to enter it exit it etc so when you reach for your phone basically your hand enters the bubble and it starts firing up the infrared and face unlock sensors early so by the time you pick the phone up it's already reading your face and logging you in and it's incredibly fast over and over again it's super impressive possibly too fast this kind of reminds me of the 1 plus 6 and other phones that would just do face unlock with just the RGB cameras so they'd be insanely fast they would just see anything that looks like you and just unlock as soon as you glanced at it so this isn't that it's still infrared so it still can't be fooled by a photo or video of you it still works in the dark and things like that so i ...
