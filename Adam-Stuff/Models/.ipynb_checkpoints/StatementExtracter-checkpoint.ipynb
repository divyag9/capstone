# %%
# !pip install -U spacy
# !python -m spacy download en_core_web_sm

# %%
import nltk
import numpy as np
from itertools import groupby, chain
from collections import Counter, defaultdict
import spacy
spacy_nlp = spacy.load("en_core_web_sm")
import re
#import boto3

class StatementExtracter(object):
    """
    As part of key word extraction and sentiment summarization, this code will be
    able to extract certain types of statements from a block of text.
    """
    
    def __init__(self, stopwords = None, punctuations = None):
        self.stopwords = stopwords
        self.punctuations = punctuations
        if self.stopwords == None:
            self.stopwords = []
        if self.punctuations == None:
            self.punctuations = list('!"#%&\'()*+,./:;<=>?@[\\]^_`{|}~♪')
        self.phrase_breaks = set(self.stopwords + self.punctuations)
        
    def replace_contraction(self, text):
        """
        Takes in text and replaces certain contractions
        """
        contraction_patterns = [(r'won\'t', 'will not'), (r'can\'t', 'can not'), (r'i\'m', 'i am'), 
                                (r'ain\'t', 'is not'), (r'(\w+)\'ll', '\g<1> will'), (r'(\w+)n\'t', '\g<1> not'),
                                (r'(\w+)\'ve', '\g<1> have'), (r'(\w+)\'d', '\g<1> would'), (r'&', 'and'),
                                (r'dammit', 'damn it'), (r'dont', 'do not'), (r'wont', 'will not'),
                                (r'they\'re', 'they are'), (r'They\'re', 'They are'), (r'it\'s', 'it is'), (r'It\'s', 'It is')]
        patterns = [(re.compile(regex), repl) for (regex, repl) in contraction_patterns]
        for (pattern, repl) in patterns:
            (text, count) = re.subn(pattern, repl, text)
        return text
    
    def add_periods(self, text):
        """
        Takes in a string of text with no punctuation, uses Spacy's method of breaking up sentences to 
        add periods to the end of these sentences. Returns text with periods.
        """
        doc = spacy_nlp(text)
        sentence_tokens = [sents.text for sents in doc.sents]
        new_sentence_tokens = []
        add_on = None
        for i in range(len(sentence_tokens)-1,-1,-1):
            if " " in sentence_tokens[i]:
                if add_on == None:
                    # Add a period to the end of the sentence
                    new_sentence_tokens.append(sentence_tokens[i]+'.')
                else:
                    # Add 1 word and period to the end of the sentence.
                    new_sentence_tokens.append(sentence_tokens[i]+' '+add_on+'.')
                    add_on = None
            else:
                # If there is a sentence which is just one word, add it to the end of the previous sentence.
                add_on = sentence_tokens[i]
        new_text = " ".join(new_sentence_tokens[::-1])
        return new_text
        
    def spacy_POS_phrase_breaks(self, doc, POS_we_want, tag_we_want, dep_we_want):
        """
        Inputs a string of text, a list of POS, and a list of Spacy Tags that we want to keep in.
        This method parses the text and adds words that do not fall into POS and TAGS to phrase breaks list.
        """
        # Initialize the set with our existing phrase breaks
        temp_phrase_breaks = self.phrase_breaks.copy()

        for token in doc:
            if token.pos_ not in POS_we_want and token.tag_ not in tag_we_want and token.dep_ not in dep_we_want:
                temp_phrase_breaks.add(token.text.lower())
        return temp_phrase_breaks
    
    def visualize_POS(self, text, punctuation = False):
        """Visualize the POS of each word in the text"""
        if punctuation == False:
            text = self.add_periods(text)
            text = self.replace_contraction(text)
        else:
            text = self.replace_contraction(text)
        doc = spacy_nlp(text)
        for token in doc:
            print("{0}/{1}/{2} <--{3}-- {4}/{5}/{6}".format(
                    token.text,token.pos_,token.tag_,token.dep_,token.head.text,token.head.pos_,token.head.tag_))        
    
    def is_statements(self, text):
        # Situation where text contains sentences/punctuation
        if ", " in text:
            text = self.replace_contraction(text)
            return self.statementExtraction(text, withPunctuation = True)
        # Situation where text does not contain sentences/punctuation
        else:
            text = self.add_periods(text)
            text = self.replace_contraction(text)
            return self.statementExtraction(text, withPunctuation = False)
        
    def statementExtraction(self, text, withPunctuation = False):
        doc = spacy_nlp(text)
        statements = list()
        for token in doc:
            # If the token is "is" or "are", we want to look at the subtree
            if token.text in ['is','are']:
                # Pull the subtree as token objects and as pure text
                subtree = [i for i in token.subtree]

                # Split the subtree up into left and right groups
                left_subtree = [word for word in subtree if word.i < token.i]
                right_subtree = [word for word in subtree if word.i > token.i]

                if withPunctuation == True:
                    # Create a temporary set of break words based on the Part of Speech
                    left_POS = ['ADJ','DET','NOUN','NUM','PART','PROPN','PUNCT','ADP','PRON','AUX','SYM','SCONJ']
                    left_tags = []
                    left_dep = []
                    right_POS = ['ADJ','DET','NOUN','NUM','PART','PROPN','ADV','PUNCT','ADP','AUX','SYM','SCONJ','CCONJ','PRON']
                    right_tags = ['VBG','VBZ','VBP','VB','VBD','VBN']
                    right_dep = []
                if withPunctuation == False:
                    left_POS = ['NOUN']
                    left_tags = ['NNP','PRP','HYPH','JJ']
                    left_dep = ['advmod','amod','neg', 'nsubj']
                    right_POS = ['ADJ','DET','NOUN','NUM','PART','PROPN','ADV','ADP']
                    right_tags = ['VB','VBG','HYPH','VBN','UH']
                    right_dep = ['intj','prep','neg','pobj']
                left_phrase_breaks = self.spacy_POS_phrase_breaks(subtree, left_POS, left_tags, left_dep)
                right_phrase_breaks = self.spacy_POS_phrase_breaks(subtree, right_POS, right_tags, right_dep)

                # group words together using phrase breaks and a separator 
                left_phrase_groups = groupby(left_subtree, lambda word: word.text.lower() not in left_phrase_breaks)
                # Pull out the groups of words that do not include any of the phrase breaks   
                left_phrase_tuples = [tuple(group[1]) for group in left_phrase_groups if group[0] == True]

                # group words together using phrase breaks and a separator 
                right_phrase_groups = groupby(right_subtree, lambda word: word.text.lower() not in right_phrase_breaks)
                # Pull out the groups of words that do not include any of the phrase breaks   
                right_phrase_tuples = [tuple(group[1]) for group in right_phrase_groups if group[0] == True]

                subject = []
                description = []
                
                if withPunctuation == True:
                    # For the subjects on the left side of "is/are"
                    subject_word = None
                    for tuple_ in left_phrase_tuples:
                        for word in tuple_:
                            # if any of the words inside the tuple is a 'nsubj', it is potentially what we want
                            if word.dep_ in ['nsubj', 'expl']:
                                # check if we already have a good candidate for subject
                                if len(subject) < 1:
                                    subject_word = word
                                    subject = tuple_
                                    break
                                elif subject_word.pos_ in ['NOUN'] and word.pos_ not in ['NOUN']:
                                    pass
                                # if the existing candidate is not a noun, then we can update it.
                                else:
                                    subject_word = word
                                    subject = tuple_
                                    break
                    # Look at right text, if it includes adj, keep it + or just take the first phrase in the tuple.
                    if len(right_phrase_tuples) > 0:
                        description = right_phrase_tuples[0]
                if withPunctuation == False:
                    # For the subjects on the left side of "is/are"
                    subject_word = None
                    for tuple_ in left_phrase_tuples:
                        for word in tuple_:
                            # if any of the words inside the tuple is a 'nsubj', it is potentially what we want
                            if word.dep_ in ['nsubj', 'expl'] and word.pos_ in ['NOUN','DET','PRON']:
                                # check if we already have a good candidate for subject
                                if len(subject) < 1:
                                    subject_word = word
                                    subject = tuple_
                                    break
                                elif subject_word.pos_ in ['NOUN','DET'] and word.pos_ not in ['NOUN','DET']:
                                    pass
                                # if the existing candidate is not a noun, then we can update it.
                                else:
                                    subject_word = word
                                    subject = tuple_
                                    break
                    # Look at right text to get a description.
                    if len(right_phrase_tuples) > 0  and len(subtree) < 30:
                        for word in right_phrase_tuples[0]:
                            if word.pos_ == "ADJ":
                                description = right_phrase_tuples[0]

                    
                # Create the statements
#                 print(" ".join([word.text for word in subtree]))
#                 print([(word.text,word.pos_,word.tag_,word.dep_) for word in left_subtree])
#                 print([(word.text,word.pos_,word.tag_,word.dep_) for word in right_subtree])
#                 print('\n')
                print(" ".join([word.text for word in subtree]))
                if len(subject) > 0 and len(description) > 0:
                    output = " ".join([word.text for word in subject]) + " " + token.text + " " + " ".join([word.text for word in description])
                    print(output+"\n")
                    if output not in statements:
                        statements.append(output)
        return statements

# %%
import pandas as pd
df = pd.read_csv("ExampleTexts/videoExamples.csv")
examples = list(df.captions)

# %%
se = StatementExtracter()

# %%
statements = se.is_statements(examples[0])
# Out:
# what is up guys mkbhd here
# what is up guys mkbhd here this is the pixel for excel .
# this is one of the phones I was looking forward to the most this entire year for 2019 for a couple of reasons .
# this is my honest review .
# this is honest review
#
# it is a pretty decent looking phone
# it is a pretty decent looking phone
#
# it is low - key really clean .
# it is low - key really clean
#
# just the Google G at the bottom matte black aluminum rails as part of the design all the way around the phone speaker slots at the bottom lined up with the USB type - c port and the colored power button of course on every version and the whole back of the phone on two of the colors is this soft touch matte finish which does a great job of not showing fingerprints it does not seem to scratch very easily at all so of the three colors .
# this Panda version is the best one that power buttons pretty sweet .
# Panda version is the best one
#
# oh so orange is in second place .
# but at least it is matte and then that jet - black weirdly very glossy version is in third place
# at least it is matte
#
# then that jet - black weirdly very glossy version is in third place
# jet - black weirdly very glossy version is in third place
#
# since the rails are still matte black
# rails are still matte black
#
# the pixels square camera bump is again annoyingly a little bit raised .
# pixels square camera bump is again annoyingly a little bit raised
#
# is
# the phone is now ip68 water - resistant it still has the squeeze sensitivity for the assistant and
# phone is now ip68 water - resistant
#
# so they are not front - facing pair .
# so they are not front - facing pair
#
# but they are still a good sounding solid pair with the slots at the bottom and the earpiece speaker combined the worst part about the way this phone looks is the front the part you look at most of the time I 'm not a fan of the forehead it has a smaller chin at the bottom than before .
# this phone looks is the front the part you look at most of the time I 'm not a fan of the forehead it has a smaller chin at the bottom than before
# which is new in any smartphone
# which is new in any smartphone
#
# is good for two things
# the face unlock is the only biometric unlock .
# face unlock is the only biometric unlock
#
# when things are near it when things are in the bubble
# when things are in the bubble
# is
# it is incredibly fast over and .
# over again it is super impressive possibly too fast this kind of reminds me of the 1 plus 6 and other phones that would just do face unlock with just the RGB cameras so they would be insanely fast .
# so this is not that it is still infrared so it still can not be fooled by a photo or video of you it still works in the dark and things like that .
# is
# is
# but it is still a little bit wild .
# it is still a little bit wild
#
# is
# even if your eyes are closed and potentially could be unlocked by someone who just looks a lot like you
# eyes are closed
#
# these chillie be fixed or improved with a software update and Google 's been pretty good about software updates but as of right now they are just pretty annoying my solution is turn off the skip lockscreen option are things that could pretend
# as of right now they are just pretty annoying my solution is turn off the skip lockscreen option
# they are just pretty annoying
#
# my solution is
# it is a little safer
# it is a little safer
#
# it is ready so those situations are alarm clocks timers media controls and a Pikachu live wallpaper and there are no instructions like really built into Android there 's none in the Android 10 setup for example .
# so those situations are alarm clocks timers media controls and a Pikachu live wallpaper and there are no instructions like really built into Android there 's none in the Android 10 setup for example .
# there are no instructions like really built into Android there 's none in the Android 10 setup for example .
# is
# is music apps .
# so it is less of like a big arm movement although that sometimes does work .
# so it is less of like a big arm movement
#
# but it is more of like a casual swipe and not too close to the phone like right around .
# it is more of like a casual swipe
#
# the real problem is it does not show you or tell you how to do it then made by Google Twitter account they tweeted at me saying you can go to the pixel tips app
# is
# but even then there is not actually .
# there is not actually any feedback .
# is
# it is the new display pixel 4 and pixel 4 XL have made the jump to smooth high res high refresh rate .
# it is the new display pixel 4
#
# so it is difficult to show you exactly how much better that looks obviously .
# so it is difficult to show
#
# because this is a 30fps video
# this is a 30fps video
#
# though it is not the brightest display
# it is not the brightest display
#
# sometimes daytime visibility is pretty weak unfortunately .
# sometimes daytime visibility is pretty weak unfortunately
#
# which is a lot better than the F.
# which is a lot better than the F.
#
# battery life is because it ratchets down to 60 Hertz constantly all the time it is supposed to be smart about it
# is
# like it is almost always at 90 Hertz
# okay this is not great .
# this is not great
#
# it is not my favorite implementation of 90 Hertz .
# but it is almost like a tease that it switches back and forth so much .
# there is I found an option that I have never seen before it is called force .
# is
# is
# now it is always smooth .
# now it is always smooth
#
# it is definitely even worse now closer to addy .
# it is definitely even worse now closer to addy
#
# is
# but at least it is smoother now .
# is
# it is not nearly as dramatic and overall .
# it is not nearly as dramatic
#
# it is just it is not the flashiest or most eye - catching or dramatic display on any smartphone it does not curve over the edges or anything .
# just it is not the flashiest or most eye - catching or dramatic display on any smartphone it does not curve over the edges or anything
# just it is not the flashiest
#
# but it is 90 Hertz .
# it is 1440p .
# it is OLED and it is flat but listen we all know the pixel four is what about so the pixel 3 was what about .
# it is flat but listen we all know the pixel four is what about so the pixel 3 was what about .
# it is flat
#
# the pixel four is what about so
# and it is what the pixel 2 was about it is the cameras .
# it is the cameras
# it is a 12 megapixel primary camera and a new 16 megapixel 2x tell photocamera .
# it is a 12 megapixel primary camera
#
# what specs are just one thing I got actually use it in person that 's what I have been doing maybe
# are very similar to pixel three great dynamic range great sharpness and detail very contrasting and punchy and dramatic and biasing a little bit towards cooler tones typically .
# but they are excellent photos they have got this image processing pipeline and their HDR down to a science .
# they are excellent photos
#
# the improvements in the viewfinder are cool
# improvements are cool
#
# is
# portrait photos are better now because you have two lenses and you can finally do depth data between them .
# portrait photos are better now
#
# that they are about the same matter of fact
# they are about the same matter of fact
#
# is
# is
# is
# so basically the best thing about having a telephoto camera is for zoomed in photos .
# the question still is is this the best camera in any smartphone because I think we can all agree pixel 3 was top of the stack last year .
# question still is this the best camera in any smartphone
#
# is this the best camera in any smartphone
# is
# which is better ok honestly in daylight for most photos
# which is better ok honestly in daylight for most photos
#
# that are really cool and nitesite
# that are really cool
#
# so is this the best camera in any smartphone .
# it is a toss - up depending on the scenario
# which is sort of a different question I would pick iPhone 11 Pro because it is more versatile it has the ultra wide and it absolutely crushes it in video like video
# because it is more versatile it has the ultra wide and it absolutely crushes it in video like video
# it is more versatile
#
# is just not as much of a focus with the pickle forest camera anymore .
# is
# my pixel vs. iPhone camera graph is like this pair of lines where the middle is where most photos are taken most of the time and that 's where I prefer pixel but on the edges of photography like low - light or ultra wide .
# where the middle is where most photos are taken most of the time and that 's where I prefer pixel but on the edges of photography like low - light or ultra wide
# are
# since it is Google 's baby
# there are some good features here that add to how smart it is as a smart phone you already heard about the radar bubble and the smart unlock .
# how smart it is as a smart phone you already heard about the radar bubble and the smart unlock
# how smart it is as a smart phone
#
# so text - to - speech is way faster and way more consistent .
# then index is that text to make it searchable that 's like an S Pen level feature I personally probably will not use it too much .
# the best part of a pixel again is how refined Android is if you want the latest version of Android .
# best part is how refined Android
#
# how refined Android is if you want the latest version of Android
# that is the phone again
# if you want to be first with updates if you want the coolest edge features and the assistant and all that is the phone again so overall many of the conclusions about pixel 4 are of course about how disappointing it is i think which is an easy conclusion to reach if you have followed all the leaks and nothing really surprised you and are things that are let down I personally really enjoyed using pixel because of the punchy confident excellent camera for still photos and the 90 Hertz display which a lot of phones do not have yet
# how disappointing it is i think which is an easy conclusion to reach if you have followed all the leaks and nothing really surprised you and are things that are let down I personally really enjoyed using pixel because of the punchy confident excellent camera for still photos and the 90 Hertz display which a lot of phones do not have yet
# which is an easy conclusion to reach if you have followed all the leaks and nothing really surprised you and are things that are let down I personally really enjoyed using pixel because of the punchy confident excellent camera for still photos and the 90 Hertz display which a lot of phones do not have yet
# are things that are let down I personally really enjoyed using pixel because of the punchy confident excellent camera for still photos and the 90 Hertz display which a lot of phones do not have yet
# are
# but this is not a phone I 'm gon na go around recommending to everyone it still needs a bigger battery .
# and it is just generally not complete for most people .
# it is just generally not complete for most people
#
# which is in a tiny group of people who really like high refresh rate screens of course
# which is in a tiny group of people
#
# the pixel is a bit overpriced for the storage you do not get then
# pixel is a bit overpriced for the storage
#
# it is great for people like that
# it is great for people like that
#
# because there are just better deals out there right now including the cheaper iPhone 11 weird to say
# but it is true .
# it is true
#
# it is what like to own it
# are you in this tiny group of people who would like this pixel experience .

# %%
se.visualize_POS(examples[1])
# Out:
#  /SPACE/_SP <---- it/PRON/PRP
# it/PRON/PRP <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--ROOT-- is/AUX/VBZ
# Google/PROPN/NNP <--compound-- pixel/NOUN/NN
# pixel/NOUN/NN <--attr-- is/AUX/VBZ
# for/ADP/IN <--prep-- pixel/NOUN/NN
# day/NOUN/NN <--pobj-- for/ADP/IN
# and/CCONJ/CC <--cc-- is/AUX/VBZ
# of/ADV/RB <--prep-- know/VERB/VB
# course/NOUN/NN <--pobj-- of/ADV/RB
# as/SCONJ/IN <--mark-- know/VERB/VB
# you/PRON/PRP <--nsubj-- know/VERB/VB
# should/AUX/MD <--aux-- know/VERB/VB
# know/VERB/VB <--conj-- is/AUX/VBZ
# we/PRON/PRP <--nsubj-- got/VERB/VBN
# have/AUX/VBP <--aux-- got/VERB/VBN
# got/VERB/VBN <--ccomp-- know/VERB/VB
# every/DET/DT <--det-- version/NOUN/NN
# single/ADJ/JJ <--amod-- version/NOUN/NN
# version/NOUN/NN <--dobj-- got/VERB/VBN
# sitting/VERB/VBG <--acl-- version/NOUN/NN
# in/ADP/IN <--prep-- sitting/VERB/VBG
# front/NOUN/NN <--pobj-- in/ADP/IN
# of/ADP/IN <--prep-- front/NOUN/NN
# me/PRON/PRP <--pobj-- of/ADP/IN
# ./PUNCT/. <--punct-- know/VERB/VB
# this/DET/DT <--det-- version/NOUN/NN
# every/DET/DT <--det-- version/NOUN/NN
# single/ADJ/JJ <--amod-- version/NOUN/NN
# version/NOUN/NN <--nsubj-- right/NOUN/NN
# right/NOUN/NN <--ROOT-- right/NOUN/NN
# ./PUNCT/. <--punct-- right/NOUN/NN
# so/ADV/RB <--advmod-- is/AUX/VBZ
# it/PRON/PRP <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--ROOT-- is/AUX/VBZ
# the/DET/DT <--attr-- is/AUX/VBZ
# for/ADP/IN <--prep-- is/AUX/VBZ
# excel/NOUN/NN <--pobj-- for/ADP/IN
# in/ADP/IN <--prep-- excel/NOUN/NN
# the/DET/DT <--det-- colors/NOUN/NNS
# three/NUM/CD <--nummod-- colors/NOUN/NNS
# different/ADJ/JJ <--amod-- colors/NOUN/NNS
# colors/NOUN/NNS <--pobj-- in/ADP/IN
# they/PRON/PRP <--nsubj-- got/VERB/VBD
# always/ADV/RB <--advmod-- got/VERB/VBD
# got/VERB/VBD <--relcl-- colors/NOUN/NNS
# fancy/ADJ/JJ <--amod-- names/NOUN/NNS
# names/NOUN/NNS <--dobj-- got/VERB/VBD
# for/ADP/IN <--prep-- names/NOUN/NNS
# the/DET/DT <--det-- colors/NOUN/NNS
# colors/NOUN/NNS <--pobj-- for/ADP/IN
# a/DET/DT <--det-- white/ADJ/JJ
# clearly/ADV/RB <--advmod-- white/ADJ/JJ
# white/ADJ/JJ <--acomp-- is/AUX/VBZ
# ./PUNCT/. <--punct-- is/AUX/VBZ
# oh/INTJ/UH <--intj-- orange/ADJ/JJ
# so/ADV/RB <--advmod-- orange/ADJ/JJ
# orange/ADJ/JJ <--ROOT-- orange/ADJ/JJ
# ./PUNCT/. <--punct-- orange/ADJ/JJ
# just/ADV/RB <--advmod-- black/ADJ/JJ
# black/ADJ/JJ <--ROOT-- black/ADJ/JJ
# ./PUNCT/. <--punct-- black/ADJ/JJ
# and/CCONJ/CC <--cc-- have/AUX/VBP
# so/ADV/RB <--advmod-- have/AUX/VBP
# we/PRON/PRP <--nsubj-- have/AUX/VBP
# have/AUX/VBP <--ROOT-- have/AUX/VBP
# the/DET/DT <--det-- versions/NOUN/NNS
# Excel/ADJ/JJ <--compound-- versions/NOUN/NNS
# versions/NOUN/NNS <--dobj-- have/AUX/VBP
# on/ADP/IN <--prep-- versions/NOUN/NNS
# the/DET/DT <--det-- top/NOUN/NN
# top/NOUN/NN <--pobj-- on/ADP/IN
# and/CCONJ/CC <--cc-- have/AUX/VBP
# ./PUNCT/. <--punct-- have/AUX/VBP
# then/ADV/RB <--advmod-- know/VERB/VB
# below/ADP/IN <--prep-- know/VERB/VB
# that/SCONJ/IN <--pobj-- below/ADP/IN
# you/PRON/PRP <--nsubj-- know/VERB/VB
# would/AUX/MD <--aux-- know/VERB/VB
# not/PART/RB <--neg-- know/VERB/VB
# know/VERB/VB <--ROOT-- know/VERB/VB
# from/ADP/IN <--prep-- know/VERB/VB
# the/DET/DT <--det-- size/NOUN/NN
# size/NOUN/NN <--pobj-- from/ADP/IN
# of/ADP/IN <--prep-- size/NOUN/NN
# the/DET/DT <--det-- box/NOUN/NN
# box/NOUN/NN <--pobj-- of/ADP/IN
# ./PUNCT/. <--punct-- know/VERB/VB
# but/CCONJ/CC <--cc-- have/AUX/VBP
# we/PRON/PRP <--nsubj-- have/AUX/VBP
# have/AUX/VBP <--ROOT-- have/AUX/VBP
# the/DET/DT <--det-- pixel/NOUN/NN
# standard/ADJ/JJ <--amod-- pixel/NOUN/NN
# size/NOUN/NN <--compound-- pixel/NOUN/NN
# pixel/NOUN/NN <--dobj-- have/AUX/VBP
# for/ADP/IN <--prep-- pixel/NOUN/NN
# some/DET/DT <--det-- specifications/NOUN/NNS
# specifications/NOUN/NNS <--pobj-- for/ADP/IN
# for/ADP/IN <--prep-- specifications/NOUN/NNS
# each/DET/DT <--pobj-- for/ADP/IN
# here/ADV/RB <--advmod-- have/AUX/VBP
# ./PUNCT/. <--punct-- have/AUX/VBP
# the/DET/DT <--det-- inch/NOUN/NN
# XL/PROPN/NNP <--nmod-- inch/NOUN/NN
# 6.3/NUM/CD <--nummod-- inch/NOUN/NN
# inch/NOUN/NN <--nsubj-- display/NOUN/NN
# display/NOUN/NN <--ROOT-- display/NOUN/NN
# 128/NUM/CD <--nummod-- gigs/NOUN/NNS
# gigs/NOUN/NNS <--dobj-- display/NOUN/NN
# of/ADP/IN <--prep-- gigs/NOUN/NNS
# storage/NOUN/NN <--pobj-- of/ADP/IN
# on/ADP/IN <--prep-- display/NOUN/NN
# this/DET/DT <--det-- model/NOUN/NN
# particular/ADJ/JJ <--amod-- model/NOUN/NN
# model/NOUN/NN <--pobj-- on/ADP/IN
# the/DET/DT <--det-- pixel/NOUN/NN
# non/ADJ/JJ <--compound-- XL/PROPN/NNP
# XL/PROPN/NNP <--compound-- pixel/NOUN/NN
# version/NOUN/NN <--compound-- pixel/NOUN/NN
# pixel/NOUN/NN <--dobj-- display/NOUN/NN
# for/ADP/IN <--prep-- pixel/NOUN/NN
# 5.7/NUM/CD <--nummod-- display/NOUN/NN
# inch/NOUN/NN <--compound-- display/NOUN/NN
# display/NOUN/NN <--pobj-- for/ADP/IN
# ./PUNCT/. <--punct-- display/NOUN/NN
# this/DET/DT <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--ROOT-- is/AUX/VBZ
# fresh/ADJ/JJ <--acomp-- is/AUX/VBZ
# ./PUNCT/. <--punct-- is/AUX/VBZ
# it/PRON/PRP <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--ROOT-- is/AUX/VBZ
# hot/ADJ/JJ <--acomp-- is/AUX/VBZ
# off/ADP/IN <--prep-- hot/ADJ/JJ
# the/DET/DT <--det-- presses/NOUN/NNS
# presses/NOUN/NNS <--pobj-- off/ADP/IN
# so/SCONJ/IN <--prep-- is/AUX/VBZ
# this/DET/DT <--det-- video/NOUN/NN
# video/NOUN/NN <--pobj-- so/SCONJ/IN
# ./PUNCT/. <--punct-- is/AUX/VBZ
# it/PRON/PRP <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--ROOT-- is/AUX/VBZ
# just/ADV/RB <--advmod-- is/AUX/VBZ
# it/PRON/PRP <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--ccomp-- is/AUX/VBZ
# an/DET/DT <--det-- video/NOUN/NN
# unboxing/ADJ/JJ <--amod-- video/NOUN/NN
# video/NOUN/NN <--attr-- is/AUX/VBZ
# and/CCONJ/CC <--cc-- video/NOUN/NN
# a/DET/DT <--det-- type/NOUN/NN
# first/ADJ/JJ <--amod-- look/NOUN/NN
# -/PUNCT/HYPH <--punct-- look/NOUN/NN
# look/NOUN/NN <--compound-- type/NOUN/NN
# type/NOUN/NN <--conj-- video/NOUN/NN
# of/ADP/IN <--prep-- type/NOUN/NN
# video/NOUN/NN <--pobj-- of/ADP/IN
# ./PUNCT/. <--punct-- is/AUX/VBZ
# just/ADV/RB <--advmod-- keep/VERB/VB
# keep/VERB/VB <--ROOT-- keep/VERB/VB
# that/DET/DT <--dobj-- keep/VERB/VB
# in/ADP/IN <--oprd-- keep/VERB/VB
# mind/NOUN/NN <--pobj-- in/ADP/IN
# ./PUNCT/. <--punct-- keep/VERB/VB
# f/X/LS <--ROOT-- f/X/LS
# HD/NOUN/NN <--nsubj-- OLED/NOUN/NN
# Plus/CCONJ/CC <--cc-- HD/NOUN/NN
# flexible/ADJ/JJ <--conj-- HD/NOUN/NN
# OLED/NOUN/NN <--pobj-- f/X/LS
# 444/NUM/CD <--nummod-- PPI/NOUN/NN
# PPI/NOUN/NN <--dobj-- OLED/NOUN/NN
# and/CCONJ/CC <--cc-- OLED/NOUN/NN
# then/ADV/RB <--advmod-- qhd+/PROPN/NNP
# qhd+/PROPN/NNP <--conj-- OLED/NOUN/NN
# so/ADV/RB <--advmod-- OLED/NOUN/NN
# a/DET/DT <--det-- density/NOUN/NN
# higher/ADJ/JJR <--amod-- density/NOUN/NN
# pixel/NOUN/NN <--compound-- density/NOUN/NN
# density/NOUN/NN <--conj-- OLED/NOUN/NN
# on/ADP/IN <--prep-- density/NOUN/NN
# the/DET/DT <--det-- XL/PROPN/NNP
# XL/PROPN/NNP <--pobj-- on/ADP/IN
# at/ADP/IN <--prep-- density/NOUN/NN
# 5:37/NUM/CD <--nummod-- Glass/PROPN/NNP
# DPI/PROPN/NNP <--compound-- Gorilla/PROPN/NNP
# Gorilla/PROPN/NNP <--compound-- Glass/PROPN/NNP
# Glass/PROPN/NNP <--pobj-- at/ADP/IN
# 5/NUM/CD <--nummod-- Glass/PROPN/NNP
# on/ADP/IN <--prep-- density/NOUN/NN
# both/DET/DT <--pobj-- on/ADP/IN
# ./PUNCT/. <--punct-- OLED/NOUN/NN
# oh/INTJ/UH <--intj-- gon/VERB/VBG
# they/PRON/PRP <--nsubj-- gon/VERB/VBG
# are/AUX/VBP <--aux-- gon/VERB/VBG
# gon/VERB/VBG <--ROOT-- gon/VERB/VBG
# na/PART/TO <--aux-- have/AUX/VB
# have/AUX/VB <--xcomp-- gon/VERB/VBG
# 90/NUM/CD <--nummod-- Hertz/PROPN/NNP
# Hertz/PROPN/NNP <--nmod-- displays/NOUN/NNS
# smooth/ADJ/JJ <--amod-- displays/NOUN/NNS
# displays/NOUN/NNS <--dobj-- have/AUX/VB
# ./PUNCT/. <--punct-- gon/VERB/VBG
# you/PRON/PRP <--nsubj-- know/VERB/VBP
# know/VERB/VBP <--ROOT-- know/VERB/VBP
# ./PUNCT/. <--punct-- know/VERB/VBP
# that/DET/DT <--det-- kind/NOUN/NN
# kind/NOUN/NN <--nsubj-- buttery/NOUN/NN
# of/ADP/IN <--prep-- kind/NOUN/NN
# quickie/NOUN/NN <--pobj-- of/ADP/IN
# buttery/NOUN/NN <--ROOT-- buttery/NOUN/NN
# what/PRON/WP <--dep-- about/ADP/IN
# about/ADP/IN <--prep-- buttery/NOUN/NN
# a/DET/DT <--det-- milkshake/NOUN/NN
# milkshake/NOUN/NN <--pobj-- about/ADP/IN
# ./PUNCT/. <--punct-- buttery/NOUN/NN
# yeah/INTJ/UH <--intj-- is/AUX/VBZ
# is/AUX/VBZ <--ROOT-- is/AUX/VBZ
# that/DET/DT <--mark-- is/AUX/VBZ
# smooth/ADJ/JJ <--amod-- bad/ADJ/JJ
# not/PART/RB <--neg-- bad/ADJ/JJ
# bad/ADJ/JJ <--pcomp-- that/DET/DT
# the/DET/DT <--det-- guy/NOUN/NN
# little/ADJ/JJ <--amod-- guy/NOUN/NN
# guy/NOUN/NN <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--ccomp-- is/AUX/VBZ
# 2,800/NUM/CD <--nummod-- hours/NOUN/NNS
# milliamp/NOUN/NN <--amod-- hours/NOUN/NNS
# hours/NOUN/NNS <--attr-- is/AUX/VBZ
# at/ADP/IN <--prep-- hours/NOUN/NNS
# the/DET/DT <--det-- charging/VERB/VBG
# big/ADJ/JJ <--amod-- one/NUM/CD
# one/NUM/CD <--pobj-- the/DET/DT
# 3700/NUM/CD <--nummod-- one/NUM/CD
# both/DET/DT <--preconj-- charging/VERB/VBG
# 18/NUM/CD <--nummod-- watt/ADV/RB
# watt/ADV/RB <--npadvmod-- fast/ADJ/JJ
# fast/ADJ/JJ <--amod-- charging/VERB/VBG
# charging/VERB/VBG <--pobj-- at/ADP/IN
# and/CCONJ/CC <--cc-- charging/VERB/VBG
# wireless/ADJ/JJ <--amod-- charging/VERB/VBG
# charging/VERB/VBG <--conj-- charging/VERB/VBG
# ./PUNCT/. <--punct-- is/AUX/VBZ
# and/CCONJ/CC <--cc-- thing/NOUN/NN
# then/ADV/RB <--advmod-- thing/NOUN/NN
# of/ADP/IN <--prep-- thing/NOUN/NN
# course/NOUN/NN <--pobj-- of/ADP/IN
# a/DET/DT <--det-- thing/NOUN/NN
# big/ADJ/JJ <--amod-- thing/NOUN/NN
# thing/NOUN/NN <--ROOT-- thing/NOUN/NN
# near/SCONJ/IN <--prep-- thing/NOUN/NN
# the/DET/DT <--det-- cameras/NOUN/NNS
# cameras/NOUN/NNS <--pobj-- near/SCONJ/IN
# ./PUNCT/. <--punct-- thing/NOUN/NN
# the/DET/DT <--det-- design/NOUN/NN
# brand/NOUN/NN <--nmod-- design/NOUN/NN
# new/ADJ/JJ <--amod-- design/NOUN/NN
# design/NOUN/NN <--ROOT-- design/NOUN/NN
# on/ADP/IN <--prep-- design/NOUN/NN
# the/DET/DT <--det-- back/NOUN/NN
# back/NOUN/NN <--pobj-- on/ADP/IN
# ./PUNCT/. <--punct-- design/NOUN/NN
# now/ADV/RB <--advmod-- are/AUX/VBP
# they/PRON/PRP <--nsubj-- are/AUX/VBP
# are/AUX/VBP <--ROOT-- are/AUX/VBP
# like/SCONJ/IN <--intj-- are/AUX/VBP
# ./PUNCT/. <--punct-- are/AUX/VBP
# no/INTJ/UH <--intj-- gon/VERB/VBG
# we/PRON/PRP <--nsubj-- gon/VERB/VBG
# 're/AUX/VBP <--aux-- gon/VERB/VBG
# gon/VERB/VBG <--ROOT-- gon/VERB/VBG
# na/PART/TO <--aux-- give/VERB/VB
# give/VERB/VB <--xcomp-- gon/VERB/VBG
# you/PRON/PRP <--dative-- give/VERB/VB
# the/DET/DT <--det-- versatility/NOUN/NN
# versatility/NOUN/NN <--dobj-- give/VERB/VB
# of/ADP/IN <--prep-- versatility/NOUN/NN
# multiple/ADJ/JJ <--amod-- camera/NOUN/NN
# camera/NOUN/NN <--pobj-- of/ADP/IN
# ./PUNCT/. <--punct-- gon/VERB/VBG
# lenses/VERB/VBZ <--ROOT-- lenses/VERB/VBZ
# white/PROPN/NNP <--amod-- pixel/PROPN/NNP
# pixel/PROPN/NNP <--dobj-- lenses/VERB/VBZ
# for/ADP/IN <--prep-- pixel/PROPN/NNP
# excel/PROPN/NNP <--pobj-- for/ADP/IN
# and/CCONJ/CC <--cc-- pixel/PROPN/NNP
# the/DET/DT <--det-- thing/NOUN/NN
# first/ADJ/JJ <--amod-- thing/NOUN/NN
# thing/NOUN/NN <--conj-- pixel/PROPN/NNP
# you/PRON/PRP <--nsubj-- gon/VERB/VBG
# 're/AUX/VBP <--aux-- gon/VERB/VBG
# gon/VERB/VBG <--relcl-- thing/NOUN/NN
# na/PART/TO <--aux-- notice/VERB/VB
# notice/VERB/VB <--advcl-- lenses/VERB/VBZ
# here/ADV/RB <--advmod-- notice/VERB/VB
# a/DET/DT <--det-- effect/NOUN/NN
# similar/ADJ/JJ <--amod-- effect/NOUN/NN
# effect/NOUN/NN <--dobj-- notice/VERB/VB
# to/ADP/IN <--prep-- effect/NOUN/NN
# the/DET/DT <--det-- version/NOUN/NN
# Panda/PROPN/NNP <--compound-- version/NOUN/NN
# version/NOUN/NN <--pobj-- to/ADP/IN
# white/NOUN/NN <--acl-- effect/NOUN/NN
# on/ADP/IN <--prep-- white/NOUN/NN
# the/DET/DT <--det-- back/NOUN/NN
# back/NOUN/NN <--pobj-- on/ADP/IN
# ./PUNCT/. <--punct-- lenses/VERB/VBZ
# but/CCONJ/CC <--cc-- get/VERB/VBP
# then/ADV/RB <--advmod-- get/VERB/VBP
# you/PRON/PRP <--nsubj-- get/VERB/VBP
# get/VERB/VBP <--ROOT-- get/VERB/VBP
# the/DET/DT <--det-- cutout/NOUN/NN
# black/ADJ/JJ <--amod-- cutout/NOUN/NN
# cutout/NOUN/NN <--dobj-- get/VERB/VBP
# for/ADP/IN <--prep-- get/VERB/VBP
# the/DET/DT <--det-- cameras/NOUN/NNS
# cameras/NOUN/NNS <--pobj-- for/ADP/IN
# you/PRON/PRP <--nsubj-- get/VERB/VBP
# get/VERB/VBP <--ccomp-- get/VERB/VBP
# the/DET/DT <--det-- Ridge/PROPN/NNP
# black/ADJ/JJ <--amod-- Ridge/PROPN/NNP
# Ridge/PROPN/NNP <--dobj-- get/VERB/VBP
# on/ADP/IN <--prep-- get/VERB/VBP
# the/DET/DT <--det-- frame/NOUN/NN
# frame/NOUN/NN <--pobj-- on/ADP/IN
# ./PUNCT/. <--punct-- get/VERB/VBP
# this/DET/DT <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--ROOT-- is/AUX/VBZ
# all/DET/DT <--advmod-- is/AUX/VBZ
# metal/NOUN/NN <--attr-- is/AUX/VBZ
# ./PUNCT/. <--punct-- is/AUX/VBZ
# and/CCONJ/CC <--cc-- is/AUX/VBZ
# then/ADV/RB <--advmod-- is/AUX/VBZ
# the/DET/DT <--det-- front/NOUN/NN
# entire/ADJ/JJ <--amod-- front/NOUN/NN
# front/NOUN/NN <--nsubj-- is/AUX/VBZ
# of/ADP/IN <--prep-- front/NOUN/NN
# the/DET/DT <--det-- device/NOUN/NN
# device/NOUN/NN <--pobj-- of/ADP/IN
# is/AUX/VBZ <--ROOT-- is/AUX/VBZ
# black/ADJ/JJ <--acomp-- is/AUX/VBZ
# ./PUNCT/. <--punct-- is/AUX/VBZ
# so/ADV/RB <--advmod-- is/AUX/VBZ
# it/PRON/PRP <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--ROOT-- is/AUX/VBZ
# a/DET/DT <--det-- effect/NOUN/NN
# panda/NOUN/NN <--compound-- effect/NOUN/NN
# effect/NOUN/NN <--attr-- is/AUX/VBZ
# black/ADJ/JJ <--amod-- effect/NOUN/NN
# and/CCONJ/CC <--cc-- black/ADJ/JJ
# white/ADJ/JJ <--conj-- black/ADJ/JJ
# ./PUNCT/. <--punct-- is/AUX/VBZ
# I/PRON/PRP <--nsubj-- think/VERB/VBP
# think/VERB/VBP <--ROOT-- think/VERB/VBP
# a/DET/DT <--det-- lot/NOUN/NN
# lot/NOUN/NN <--dobj-- think/VERB/VBP
# of/ADP/IN <--prep-- lot/NOUN/NN
# people/NOUN/NNS <--pobj-- of/ADP/IN
# ./PUNCT/. <--punct-- think/VERB/VBP
# I/PRON/PRP <--nsubj-- think/VERB/VBP
# think/VERB/VBP <--ROOT-- think/VERB/VBP
# some/DET/DT <--det-- people/NOUN/NNS
# people/NOUN/NNS <--nsubj-- gon/VERB/VBG
# gon/VERB/VBG <--ccomp-- think/VERB/VBP
# na/ADP/IN <--aux-- like/INTJ/UH
# like/INTJ/UH <--xcomp-- gon/VERB/VBG
# that/DET/DT <--det-- cable/NOUN/NN
# mmm/PROPN/NNP <--compound-- hmm/PROPN/NNP
# -/PUNCT/HYPH <--punct-- hmm/PROPN/NNP
# hmm/PROPN/NNP <--nmod-- cable/NOUN/NN
# a/DET/DT <--det-- cable/NOUN/NN
# USB/NOUN/NN <--compound-- cable/NOUN/NN
# type/NOUN/NN <--compound-- c/NOUN/NN
# -/PUNCT/HYPH <--punct-- c/NOUN/NN
# c/NOUN/NN <--compound-- cable/NOUN/NN
# cable/NOUN/NN <--dobj-- like/INTJ/UH
# as/ADV/RB <--advmod-- as/SCONJ/IN
# well/ADV/RB <--advmod-- as/SCONJ/IN
# as/SCONJ/IN <--cc-- cable/NOUN/NN
# a/DET/DT <--det-- adapter/NOUN/NN
# USB/NOUN/NN <--compound-- adapter/NOUN/NN
# adapter/NOUN/NN <--conj-- cable/NOUN/NN
# ./PUNCT/. <--punct-- think/VERB/VBP
# and/CCONJ/CC <--cc-- is/AUX/VBZ
# then/ADV/RB <--advmod-- is/AUX/VBZ
# this/DET/DT <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--ROOT-- is/AUX/VBZ
# the/DET/DT <--det-- brick/NOUN/NN
# aforementioned/ADJ/JJ <--amod-- brick/NOUN/NN
# power/NOUN/NN <--compound-- brick/NOUN/NN
# brick/NOUN/NN <--attr-- is/AUX/VBZ
# with/ADP/IN <--prep-- brick/NOUN/NN
# the/DET/DT <--det-- capability/NOUN/NN
# quick/ADJ/JJ <--amod-- capability/NOUN/NN
# charge/NOUN/NN <--compound-- capability/NOUN/NN
# capability/NOUN/NN <--pobj-- with/ADP/IN
# that/PRON/WDT <--nsubj-- 's/AUX/VBZ
# 's/AUX/VBZ <--relcl-- capability/NOUN/NN
# also/ADV/RB <--advmod-- 's/AUX/VBZ
# orange/ADJ/JJ <--acomp-- 's/AUX/VBZ
# ./PUNCT/. <--punct-- is/AUX/VBZ
# this/DET/DT <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--ROOT-- is/AUX/VBZ
# for/ADP/IN <--prep-- is/AUX/VBZ
# the/DET/DT <--pobj-- for/ADP/IN
# for/ADP/IN <--prep-- is/AUX/VBZ
# those/DET/DT <--pobj-- for/ADP/IN
# that/PRON/WDT <--nsubj-- want/VERB/VBP
# want/VERB/VBP <--relcl-- those/DET/DT
# to/PART/TO <--aux-- make/VERB/VB
# make/VERB/VB <--xcomp-- want/VERB/VBP
# more/ADJ/JJR <--dobj-- make/VERB/VB
# of/ADP/IN <--prep-- more/ADJ/JJR
# a/DET/DT <--det-- statement/NOUN/NN
# statement/NOUN/NN <--pobj-- of/ADP/IN
# that/PRON/WDT <--nsubj-- 's/AUX/VBZ
# 's/AUX/VBZ <--relcl-- statement/NOUN/NN
# obviously/ADV/RB <--advmod-- 's/AUX/VBZ
# a/DET/DT <--det-- look/NOUN/NN
# look/NOUN/NN <--attr-- 's/AUX/VBZ
# I/PRON/PRP <--nsubj-- mention/VERB/VB
# should/AUX/MD <--aux-- mention/VERB/VB
# also/ADV/RB <--advmod-- mention/VERB/VB
# mention/VERB/VB <--relcl-- look/NOUN/NN
# at/ADP/IN <--prep-- mention/VERB/VB
# this/DET/DT <--det-- point/NOUN/NN
# point/NOUN/NN <--pobj-- at/ADP/IN
# ./PUNCT/. <--punct-- is/AUX/VBZ
# it/PRON/PRP <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--ROOT-- is/AUX/VBZ
# a/DET/DT <--det-- glass/NOUN/NN
# glass/NOUN/NN <--attr-- is/AUX/VBZ
# back/ADV/RB <--advmod-- is/AUX/VBZ
# ./PUNCT/. <--punct-- is/AUX/VBZ
# it/PRON/PRP <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--ROOT-- is/AUX/VBZ
# a/DET/DT <--det-- finish/NOUN/NN
# matte/ADJ/JJ <--compound-- finish/NOUN/NN
# finish/NOUN/NN <--attr-- is/AUX/VBZ
# ./PUNCT/. <--punct-- is/AUX/VBZ
# it/PRON/PRP <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--ROOT-- is/AUX/VBZ
# not/PART/RB <--neg-- is/AUX/VBZ
# a/DET/DT <--det-- finish/NOUN/NN
# glossy/ADJ/JJ <--amod-- finish/NOUN/NN
# finish/NOUN/NN <--attr-- is/AUX/VBZ
# ./PUNCT/. <--punct-- is/AUX/VBZ
# oh/INTJ/UH <--ROOT-- oh/INTJ/UH
# yeah/INTJ/UH <--intj-- oh/INTJ/UH
# ./PUNCT/. <--punct-- yeah/INTJ/UH
# you/PRON/PRP <--nsubj-- 're/AUX/VBP
# 're/AUX/VBP <--ROOT-- 're/AUX/VBP
# right/ADJ/JJ <--acomp-- 're/AUX/VBP
# it/PRON/PRP <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--ccomp-- right/ADJ/JJ
# glossy/ADJ/JJ <--acomp-- is/AUX/VBZ
# so/ADV/RB <--advmod-- on/ADP/IN
# on/ADP/IN <--prep-- is/AUX/VBZ
# the/DET/DT <--det-- version/NOUN/NN
# black/ADJ/JJ <--amod-- version/NOUN/NN
# version/NOUN/NN <--pobj-- on/ADP/IN
# ./PUNCT/. <--punct-- 're/AUX/VBP
# the/DET/DT <--det-- switch/NOUN/NN
# power/NOUN/NN <--compound-- switch/NOUN/NN
# switch/NOUN/NN <--nsubj-- going/VERB/VBG
# is/AUX/VBZ <--aux-- going/VERB/VBG
# going/VERB/VBG <--ROOT-- going/VERB/VBG
# to/PART/TO <--aux-- be/AUX/VB
# be/AUX/VB <--xcomp-- going/VERB/VBG
# this/DET/DT <--det-- color/NOUN/NN
# white/ADJ/JJ <--amod-- color/NOUN/NN
# color/NOUN/NN <--attr-- be/AUX/VB
# and/CCONJ/CC <--cc-- be/AUX/VB
# on/ADP/IN <--conj-- be/AUX/VB
# the/DET/DT <--det-- versions/NOUN/NNS
# other/ADJ/JJ <--amod-- versions/NOUN/NNS
# two/NUM/CD <--nummod-- versions/NOUN/NNS
# versions/NOUN/NNS <--pobj-- on/ADP/IN
# actually/ADV/RB <--advmod-- gets/VERB/VBZ
# and/CCONJ/CC <--cc-- actually/ADV/RB
# then/ADV/RB <--advmod-- gets/VERB/VBZ
# on/ADP/IN <--prep-- gets/VERB/VBZ
# the/DET/DT <--det-- phone/NOUN/NN
# orange/ADJ/JJ <--amod-- phone/NOUN/NN
# phone/NOUN/NN <--pobj-- on/ADP/IN
# it/PRON/PRP <--nsubj-- gets/VERB/VBZ
# gets/VERB/VBZ <--advcl-- going/VERB/VBG
# a/DET/DT <--det-- bit/NOUN/NN
# little/ADJ/JJ <--amod-- bit/NOUN/NN
# bit/NOUN/NN <--npadvmod-- lighter/ADJ/JJR
# lighter/ADJ/JJR <--acomp-- gets/VERB/VBZ
# in/ADP/IN <--prep-- gets/VERB/VBZ
# color/NOUN/NN <--pobj-- in/ADP/IN
# that/DET/DT <--nsubj-- 's/AUX/VBZ
# 's/AUX/VBZ <--ROOT-- 's/AUX/VBZ
# yeah/INTJ/UH <--intj-- 's/AUX/VBZ
# ./PUNCT/. <--punct-- yeah/INTJ/UH
# interesting/ADJ/JJ <--amod-- choices/NOUN/NNS
# choices/NOUN/NNS <--ROOT-- choices/NOUN/NNS
# here/ADV/RB <--advmod-- choices/NOUN/NNS
# ./PUNCT/. <--punct-- choices/NOUN/NNS
# this/DET/DT <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--ROOT-- is/AUX/VBZ
# a/DET/DT <--det-- look/NOUN/NN
# very/ADV/RB <--advmod-- simple/ADJ/JJ
# simple/ADJ/JJ <--amod-- look/NOUN/NN
# look/NOUN/NN <--attr-- is/AUX/VBZ
# to/ADP/IN <--prep-- look/NOUN/NN
# it/PRON/PRP <--pobj-- to/ADP/IN
# ./PUNCT/. <--punct-- is/AUX/VBZ
# but/CCONJ/CC <--cc-- opening/VERB/VBG
# of/ADP/IN <--prep-- opening/VERB/VBG
# course/NOUN/NN <--pobj-- of/ADP/IN
# with/ADP/IN <--prep-- opening/VERB/VBG
# any/DET/DT <--det-- finish/NOUN/NN
# glossy/ADJ/JJ <--amod-- finish/NOUN/NN
# finish/NOUN/NN <--pobj-- with/ADP/IN
# you/PRON/PRP <--nsubj-- opening/VERB/VBG
# 're/AUX/VBP <--aux-- opening/VERB/VBG
# opening/VERB/VBG <--ROOT-- opening/VERB/VBG
# yourself/PRON/PRP <--dobj-- opening/VERB/VBG
# up/ADP/RP <--prt-- opening/VERB/VBG
# to/ADP/IN <--prep-- opening/VERB/VBG
# finger/NOUN/NN <--compound-- prints/NOUN/NNS
# prints/NOUN/NNS <--pobj-- to/ADP/IN
# and/CCONJ/CC <--cc-- opening/VERB/VBG
# so/ADV/RB <--advmod-- forth/ADV/RB
# forth/ADV/RB <--conj-- opening/VERB/VBG
# ./PUNCT/. <--punct-- opening/VERB/VBG
# so/ADV/RB <--advmod-- decide/VERB/VBP
# you/PRON/PRP <--nmod-- guys/NOUN/NNS
# guys/NOUN/NNS <--nsubj-- decide/VERB/VBP
# decide/VERB/VBP <--ROOT-- decide/VERB/VBP
# it/PRON/PRP <--nsubj-- looks/VERB/VBZ
# looks/VERB/VBZ <--ccomp-- decide/VERB/VBP
# fancy/ADJ/JJ <--acomp-- looks/VERB/VBZ
# though/SCONJ/IN <--mark-- gon/VERB/VBG
# this/DET/DT <--det-- factor/NOUN/NN
# form/NOUN/NN <--compound-- factor/NOUN/NN
# factor/NOUN/NN <--nsubj-- gon/VERB/VBG
# is/AUX/VBZ <--aux-- gon/VERB/VBG
# gon/VERB/VBG <--advcl-- looks/VERB/VBZ
# na/PART/TO <--aux-- be/AUX/VB
# be/AUX/VB <--xcomp-- gon/VERB/VBG
# familiar/ADJ/JJ <--acomp-- be/AUX/VB
# to/ADP/IN <--prep-- familiar/ADJ/JJ
# you/PRON/PRP <--pobj-- to/ADP/IN
# ./PUNCT/. <--punct-- decide/VERB/VBP
# it/PRON/PRP <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--ROOT-- is/AUX/VBZ
# a/DET/DT <--det-- utility/NOUN/NN
# very/ADV/RB <--advmod-- practical/ADJ/JJ
# practical/ADJ/JJ <--amod-- utility/NOUN/NN
# utility/NOUN/NN <--attr-- is/AUX/VBZ
# more/ADV/RBR <--amod-- utility/NOUN/NN
# than/SCONJ/IN <--prep-- more/ADV/RBR
# anything/PRON/NN <--pobj-- than/SCONJ/IN
# easier/ADJ/JJR <--amod-- anything/PRON/NN
# to/PART/TO <--aux-- hold/VERB/VB
# hold/VERB/VB <--xcomp-- easier/ADJ/JJR
# yes/INTJ/UH <--intj-- is/AUX/VBZ
# ./PUNCT/. <--punct-- is/AUX/VBZ
# will/AUX/MD <--aux-- do/AUX/VB
# he/PRON/PRP <--nsubj-- do/AUX/VB
# do/AUX/VB <--ROOT-- do/AUX/VB
# ladies/NOUN/NNS <--dobj-- do/AUX/VB
# and/CCONJ/CC <--cc-- ladies/NOUN/NNS
# gentlemen/NOUN/NNS <--conj-- ladies/NOUN/NNS
# ./PUNCT/. <--punct-- do/AUX/VB
# this/DET/DT <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--ROOT-- is/AUX/VBZ
# the/DET/DT <--det-- one/NOUN/NN
# small/ADJ/JJ <--amod-- one/NOUN/NN
# one/NOUN/NN <--attr-- is/AUX/VBZ
# I/PRON/PRP <--nsubj-- place/VERB/VB
# will/AUX/MD <--aux-- place/VERB/VB
# just/ADV/RB <--advmod-- place/VERB/VB
# place/VERB/VB <--relcl-- one/NOUN/NN
# that/SCONJ/IN <--mark-- 's/AUX/VBZ
# there/PRON/EX <--expl-- 's/AUX/VBZ
# 's/AUX/VBZ <--ccomp-- place/VERB/VB
# your/PRON/PRP$ <--poss-- comparison/NOUN/NN
# comparison/NOUN/NN <--attr-- 's/AUX/VBZ
# right/ADV/RB <--advmod-- there/ADV/RB
# there/ADV/RB <--advmod-- 's/AUX/VBZ
# big/ADJ/JJ <--acomp-- 's/AUX/VBZ
# and/CCONJ/CC <--cc-- big/ADJ/JJ
# small/ADJ/JJ <--conj-- big/ADJ/JJ
# ./PUNCT/. <--punct-- is/AUX/VBZ
# I/PRON/PRP <--nsubj-- gravitating/VERB/VBG
# 'm/AUX/VBP <--aux-- gravitating/VERB/VBG
# gravitating/VERB/VBG <--ROOT-- gravitating/VERB/VBG
# towards/ADP/IN <--prep-- gravitating/VERB/VBG
# this/DET/DT <--det-- color/NOUN/NN
# color/NOUN/NN <--pobj-- towards/ADP/IN
# there/ADV/RB <--advmod-- gravitating/VERB/VBG
# ./PUNCT/. <--punct-- gravitating/VERB/VBG
# we/PRON/PRP <--nsubj-- go/VERB/VBP
# go/VERB/VBP <--ROOT-- go/VERB/VBP
# put/VERB/VB <--advcl-- go/VERB/VBP
# that/DET/DT <--det-- guy/NOUN/NN
# guy/NOUN/NN <--dobj-- put/VERB/VB
# right/ADV/RB <--advmod-- on/ADP/IN
# on/ADP/IN <--prep-- put/VERB/VB
# top/NOUN/NN <--pobj-- on/ADP/IN
# ./PUNCT/. <--punct-- go/VERB/VBP
# I/PRON/PRP <--nsubj-- look/VERB/VBP
# look/VERB/VBP <--ROOT-- look/VERB/VBP
# down/ADV/RB <--advmod-- look/VERB/VBP
# okay/INTJ/UH <--ROOT-- okay/INTJ/UH
# ./PUNCT/. <--punct-- okay/INTJ/UH
# I/PRON/PRP <--nsubj-- notice/VERB/VBP
# notice/VERB/VBP <--ROOT-- notice/VERB/VBP
# straightaway/NOUN/NN <--dobj-- notice/VERB/VBP
# here/ADV/RB <--advmod-- notice/VERB/VBP
# that/SCONJ/IN <--mark-- is/AUX/VBZ
# the/DET/DT <--det-- emphasis/NOUN/NN
# emphasis/NOUN/NN <--nsubj-- is/AUX/VBZ
# unlike/ADP/IN <--prep-- emphasis/NOUN/NN
# a/DET/DT <--det-- lot/NOUN/NN
# lot/NOUN/NN <--pobj-- unlike/ADP/IN
# of/ADP/IN <--prep-- lot/NOUN/NN
# other/ADJ/JJ <--amod-- makers/NOUN/NNS
# smartphone/NOUN/NN <--compound-- makers/NOUN/NNS
# makers/NOUN/NNS <--pobj-- of/ADP/IN
# is/AUX/VBZ <--ccomp-- notice/VERB/VBP
# not/PART/RB <--neg-- is/AUX/VBZ
# on/ADP/IN <--prep-- is/AUX/VBZ
# screen/NOUN/NN <--pobj-- on/ADP/IN
# to/PART/TO <--prep-- screen/NOUN/NN
# body/NOUN/NN <--compound-- ratio/NOUN/NN
# ratio/NOUN/NN <--pobj-- to/PART/TO
# ./PUNCT/. <--punct-- notice/VERB/VBP
# they/PRON/PRP <--nsubj-- are/AUX/VBP
# are/AUX/VBP <--ROOT-- are/AUX/VBP
# they/PRON/PRP <--nsubj-- are/AUX/VBP
# are/AUX/VBP <--ccomp-- are/AUX/VBP
# cool/ADJ/JJ <--acomp-- are/AUX/VBP
# with/ADP/IN <--prep-- cool/ADJ/JJ
# having/VERB/VBG <--pcomp-- with/ADP/IN
# a/DET/DT <--det-- forehead/NOUN/NN
# forehead/NOUN/NN <--dobj-- having/VERB/VBG
# a/DET/DT <--det-- chin/NOUN/NN
# chin/NOUN/NN <--dobj-- having/VERB/VBG
# on/ADP/IN <--prep-- chin/NOUN/NN
# the/DET/DT <--det-- device/NOUN/NN
# device/NOUN/NN <--pobj-- on/ADP/IN
# not/PART/RB <--neg-- overwhelmingly/ADV/RB
# overwhelmingly/ADV/RB <--advmod-- slim/ADJ/JJ
# slim/ADJ/JJ <--amod-- bezels/NOUN/NNS
# bezels/NOUN/NNS <--appos-- device/NOUN/NN
# ./PUNCT/. <--punct-- are/AUX/VBP
# a/DET/DT <--det-- lot/NOUN/NN
# lot/NOUN/NN <--nsubj-- has/AUX/VBZ
# of/ADP/IN <--prep-- lot/NOUN/NN
# that/DET/DT <--pobj-- of/ADP/IN
# has/AUX/VBZ <--ROOT-- has/AUX/VBZ
# to/PART/TO <--aux-- do/AUX/VB
# do/AUX/VB <--xcomp-- has/AUX/VBZ
# with/ADP/IN <--prep-- do/AUX/VB
# packing/VERB/VBG <--pcomp-- with/ADP/IN
# extra/ADJ/JJ <--amod-- tech/NOUN/NN
# tech/NOUN/NN <--dobj-- packing/VERB/VBG
# into/ADP/IN <--prep-- packing/VERB/VBG
# the/DET/DT <--det-- section/NOUN/NN
# top/ADJ/JJ <--amod-- section/NOUN/NN
# forehead/NOUN/NN <--compound-- section/NOUN/NN
# section/NOUN/NN <--pobj-- into/ADP/IN
# of/ADP/IN <--prep-- section/NOUN/NN
# the/DET/DT <--det-- device/NOUN/NN
# device/NOUN/NN <--pobj-- of/ADP/IN
# to/ADP/IN <--prep-- packing/VERB/VBG
# NIR/PROPN/NNP <--compound-- projector/NOUN/NN
# cameras/NOUN/NNS <--compound-- projector/NOUN/NN
# dot/NOUN/NN <--compound-- projector/NOUN/NN
# projector/NOUN/NN <--compound-- flood/NOUN/NN
# flood/NOUN/NN <--compound-- emitter/PROPN/NNP
# emitter/PROPN/NNP <--pobj-- to/ADP/IN
# a/DET/DT <--det-- camera/NOUN/NN
# camera/NOUN/NN <--appos-- emitter/PROPN/NNP
# as/ADV/RB <--advmod-- well/ADV/RB
# well/ADV/RB <--advmod-- packing/VERB/VBG
# with/ADP/IN <--prep-- packing/VERB/VBG
# ./PUNCT/. <--punct-- has/AUX/VBZ
# a/DET/DT <--det-- field/NOUN/NN
# 90/NUM/CD <--nummod-- degree/NOUN/NN
# degree/NOUN/NN <--compound-- field/NOUN/NN
# field/NOUN/NN <--nsubj-- focus/VERB/VB
# of/ADP/IN <--prep-- field/NOUN/NN
# view/NOUN/NN <--pobj-- of/ADP/IN
# fixed/VERB/VBN <--amod-- focus/VERB/VB
# focus/VERB/VB <--ccomp-- face/VERB/VBP
# the/DET/DT <--det-- andamp/NOUN/NN
# pixel/NOUN/NN <--nmod-- andamp/NOUN/NN
# 4/NUM/CD <--nummod-- andamp/NOUN/NN
# andamp/NOUN/NN <--dobj-- focus/VERB/VB
# ;/PUNCT/: <--punct-- face/VERB/VBP
# 4/NUM/CD <--nummod-- XL/PROPN/NNP
# XL/PROPN/NNP <--nsubjpass-- face/VERB/VBP
# are/AUX/VBP <--auxpass-- face/VERB/VBP
# now/ADV/RB <--advmod-- are/AUX/VBP
# exclusively/ADV/RB <--advmod-- face/VERB/VBP
# face/VERB/VBP <--ROOT-- face/VERB/VBP
# on/ADP/IN <--prep-- face/VERB/VBP
# lock/PROPN/NNP <--pobj-- on/ADP/IN
# no/DET/DT <--det-- fingerprint/NOUN/NN
# fingerprint/NOUN/NN <--dobj-- face/VERB/VBP
# on/ADP/IN <--prep-- fingerprint/NOUN/NN
# the/DET/DT <--det-- fingerprint/NOUN/NN
# back/NOUN/NN <--amod-- fingerprint/NOUN/NN
# no/DET/DT <--det-- fingerprint/NOUN/NN
# fingerprint/NOUN/NN <--pobj-- on/ADP/IN
# in/ADP/IN <--prep-- fingerprint/NOUN/NN
# the/DET/DT <--det-- display/NOUN/NN
# display/NOUN/NN <--pobj-- in/ADP/IN
# ./PUNCT/. <--punct-- face/VERB/VBP
# face/NOUN/NN <--compound-- unlock/NOUN/NN
# unlock/NOUN/NN <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--ROOT-- is/AUX/VBZ
# enough/ADJ/JJ <--acomp-- is/AUX/VBZ
# ./PUNCT/. <--punct-- is/AUX/VBZ
# and/CCONJ/CC <--cc-- guess/VERB/VBP
# I/PRON/PRP <--nsubj-- guess/VERB/VBP
# guess/VERB/VBP <--ROOT-- guess/VERB/VBP
# they/PRON/PRP <--nsubj-- believe/VERB/VBP
# believe/VERB/VBP <--ccomp-- guess/VERB/VBP
# that/DET/DT <--nsubj-- 's/AUX/VBZ
# 's/AUX/VBZ <--ccomp-- believe/VERB/VBP
# the/DET/DT <--det-- future/NOUN/NN
# future/NOUN/NN <--nsubj-- going/VERB/VBG
# going/VERB/VBG <--ccomp-- 's/AUX/VBZ
# forward/ADV/RB <--advmod-- going/VERB/VBG
# with/ADP/IN <--prep-- going/VERB/VBG
# this/DET/DT <--det-- degree/NOUN/NN
# degree/NOUN/NN <--pobj-- with/ADP/IN
# of/ADP/IN <--prep-- degree/NOUN/NN
# technology/NOUN/NN <--pobj-- of/ADP/IN
# being/AUX/VBG <--auxpass-- baked/VERB/VBN
# baked/VERB/VBN <--acl-- degree/NOUN/NN
# in/ADP/RP <--prep-- baked/VERB/VBN
# and/CCONJ/CC <--cc-- baked/VERB/VBN
# giving/VERB/VBG <--conj-- baked/VERB/VBN
# up/ADP/RP <--prt-- giving/VERB/VBG
# so/ADV/RB <--advmod-- much/ADV/RB
# much/ADV/RB <--advmod-- giving/VERB/VBG
# in/ADP/IN <--prep-- giving/VERB/VBG
# the/DET/DT <--det-- screen/NOUN/NN
# screen/NOUN/NN <--pobj-- in/ADP/IN
# to/PART/TO <--dative-- giving/VERB/VBG
# body/VERB/VB <--compound-- ratio/NOUN/NN
# ratio/NOUN/NN <--compound-- department/NOUN/NN
# department/NOUN/NN <--pobj-- to/PART/TO
# they/PRON/PRP <--nsubj-- got/VERB/VBN
# have/AUX/VBP <--aux-- got/VERB/VBN
# got/VERB/VBN <--relcl-- department/NOUN/NN
# to/PART/TO <--aux-- be/AUX/VB
# be/AUX/VB <--xcomp-- got/VERB/VBN
# cool/ADJ/JJ <--acomp-- be/AUX/VB
# with/ADP/IN <--prep-- cool/ADJ/JJ
# it/PRON/PRP <--pobj-- with/ADP/IN
# and/CCONJ/CC <--cc-- got/VERB/VBN
# think/VERB/VB <--conj-- got/VERB/VBN
# that/DET/DT <--nsubj-- 's/AUX/VBZ
# 's/AUX/VBZ <--ccomp-- think/VERB/VB
# the/DET/DT <--det-- way/NOUN/NN
# way/NOUN/NN <--attr-- 's/AUX/VBZ
# to/PART/TO <--aux-- go/VERB/VB
# go/VERB/VB <--relcl-- way/NOUN/NN
# so/ADV/RB <--advmod-- go/VERB/VB
# ./PUNCT/. <--punct-- guess/VERB/VBP
# let/VERB/VB <--ROOT-- let/VERB/VB
# 's/PRON/PRP <--nsubj-- go/VERB/VB
# go/VERB/VB <--ccomp-- let/VERB/VB
# ahead/ADV/RB <--advmod-- go/VERB/VB
# and/CCONJ/CC <--cc-- go/VERB/VB
# give/VERB/VB <--conj-- go/VERB/VB
# it/PRON/PRP <--dative-- give/VERB/VB
# a/DET/DT <--det-- give/NOUN/NN
# give/NOUN/NN <--dobj-- give/VERB/VB
# it/PRON/PRP <--dative-- give/NOUN/NN
# a/DET/DT <--det-- test/NOUN/NN
# test/NOUN/NN <--dobj-- give/NOUN/NN
# I/PRON/PRP <--nsubj-- going/VERB/VBG
# 'm/AUX/VBP <--aux-- going/VERB/VBG
# going/VERB/VBG <--relcl-- test/NOUN/NN
# to/PART/TO <--aux-- scan/VERB/VB
# scan/VERB/VB <--xcomp-- going/VERB/VBG
# my/PRON/PRP$ <--poss-- face/NOUN/NN
# face/NOUN/NN <--dobj-- scan/VERB/VB
# in/ADP/IN <--prep-- scan/VERB/VB
# here/ADV/RB <--pcomp-- in/ADP/IN
# ./PUNCT/. <--punct-- let/VERB/VB
# he/PRON/PRP <--nsubj-- 's/AUX/VBZ
# 's/AUX/VBZ <--ROOT-- 's/AUX/VBZ
# locked/ADJ/JJ <--amod-- phone/NOUN/NN
# phone/NOUN/NN <--nmod-- phone/NOUN/NN
# unlocked/ADJ/JJ <--amod-- phone/NOUN/NN
# phone/NOUN/NN <--nmod-- phone/NOUN/NN
# locked/VERB/VBD <--amod-- phone/NOUN/NN
# phone/NOUN/NN <--nmod-- phone/NOUN/NN
# unlocked/ADJ/JJ <--amod-- phone/NOUN/NN
# phone/NOUN/NN <--attr-- 's/AUX/VBZ
# ./PUNCT/. <--punct-- 's/AUX/VBZ
# I/PRON/PRP <--nsubj-- mean/VERB/VBP
# mean/VERB/VBP <--parataxis-- have/AUX/VBP
# you/PRON/PRP <--nsubj-- have/AUX/VBP
# just/ADV/RB <--advmod-- have/AUX/VBP
# have/AUX/VBP <--ROOT-- have/AUX/VBP
# to/PART/TO <--aux-- commit/VERB/VB
# commit/VERB/VB <--xcomp-- have/AUX/VBP
# more/ADJ/JJR <--amod-- space/NOUN/NN
# space/NOUN/NN <--dobj-- commit/VERB/VB
# to/PART/TO <--aux-- have/AUX/VB
# have/AUX/VB <--xcomp-- commit/VERB/VB
# the/DET/DT <--det-- tech/NOUN/NN
# extra/ADJ/JJ <--amod-- tech/NOUN/NN
# tech/NOUN/NN <--nsubj-- built/VERB/VBN
# built/VERB/VBN <--ccomp-- have/AUX/VB
# -/PUNCT/HYPH <--punct-- built/VERB/VBN
# in/ADP/RP <--prt-- built/VERB/VBN
# ./PUNCT/. <--punct-- have/AUX/VBP
# but/CCONJ/CC <--cc-- get/VERB/VBP
# you/PRON/PRP <--nsubj-- get/VERB/VBP
# get/VERB/VBP <--ROOT-- get/VERB/VBP
# you/PRON/PRP <--nsubj-- get/AUX/VB
# get/AUX/VB <--ccomp-- get/VERB/VBP
# stuff/NOUN/NN <--dobj-- get/AUX/VB
# like/SCONJ/IN <--prep-- stuff/NOUN/NN
# the/DET/DT <--det-- ability/NOUN/NN
# ability/NOUN/NN <--pobj-- like/SCONJ/IN
# to/PART/TO <--aux-- illuminate/VERB/VB
# illuminate/VERB/VB <--acl-- ability/NOUN/NN
# the/DET/DT <--det-- face/NOUN/NN
# face/NOUN/NN <--dobj-- illuminate/VERB/VB
# in/ADP/IN <--prep-- illuminate/VERB/VB
# darker/ADJ/JJR <--amod-- environments/NOUN/NNS
# environments/NOUN/NNS <--pobj-- in/ADP/IN
# which/PRON/WDT <--nsubj-- going/VERB/VBG
# if/SCONJ/IN <--mark-- going/VERB/VBG
# face/NOUN/NN <--compound-- unlock/NOUN/NN
# unlock/NOUN/NN <--nsubj-- going/VERB/VBG
# is/AUX/VBZ <--aux-- going/VERB/VBG
# going/VERB/VBG <--relcl-- environments/NOUN/NNS
# to/PART/TO <--aux-- be/AUX/VB
# be/AUX/VB <--xcomp-- going/VERB/VBG
# the/DET/DT <--det-- unlock/NOUN/NN
# only/ADJ/JJ <--amod-- unlock/NOUN/NN
# unlock/NOUN/NN <--attr-- be/AUX/VB
# available/ADJ/JJ <--amod-- unlock/NOUN/NN
# exclusively/ADV/RB <--advmod-- need/VERB/VBP
# you/PRON/PRP <--nsubj-- need/VERB/VBP
# kind/ADV/RB <--advmod-- of/ADV/RB
# of/ADV/RB <--advmod-- need/VERB/VBP
# need/VERB/VBP <--appos-- unlock/NOUN/NN
# that/PRON/WDT <--mark-- load/VERB/VB
# we/PRON/PRP <--nsubj-- load/VERB/VB
# can/AUX/MD <--aux-- load/VERB/VB
# load/VERB/VB <--relcl-- unlock/NOUN/NN
# up/ADP/RP <--prt-- load/VERB/VB
# the/DET/DT <--det-- camera/NOUN/NN
# front/ADV/RB <--npadvmod-- facing/VERB/VBG
# -/PUNCT/HYPH <--punct-- facing/VERB/VBG
# facing/VERB/VBG <--amod-- camera/NOUN/NN
# camera/NOUN/NN <--dobj-- load/VERB/VB
# real/ADJ/JJ <--advmod-- quick/ADV/RB
# quick/ADV/RB <--advmod-- load/VERB/VB
# now/ADV/RB <--advmod-- load/VERB/VB
# ./PUNCT/. <--punct-- get/VERB/VBP
# you/PRON/PRP <--nsubj-- get/VERB/VBP
# get/VERB/VBP <--ROOT-- get/VERB/VBP
# the/DET/DT <--det-- camera/NOUN/NN
# extra/ADJ/JJ <--amod-- camera/NOUN/NN
# camera/NOUN/NN <--dobj-- get/VERB/VBP
# on/ADP/IN <--prep-- get/VERB/VBP
# the/DET/DT <--det-- back/NOUN/NN
# back/NOUN/NN <--pobj-- on/ADP/IN
# and/CCONJ/CC <--cc-- back/NOUN/NN
# the/DET/DT <--det-- camera/NOUN/NN
# singular/ADJ/JJ <--amod-- camera/NOUN/NN
# camera/NOUN/NN <--conj-- back/NOUN/NN
# on/ADP/IN <--prep-- back/NOUN/NN
# the/DET/DT <--det-- front/NOUN/NN
# front/NOUN/NN <--pobj-- on/ADP/IN
# ./PUNCT/. <--punct-- get/VERB/VBP
# so/ADV/RB <--advmod-- is/AUX/VBZ
# it/PRON/PRP <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--ROOT-- is/AUX/VBZ
# a./NOUN/NN <--attr-- is/AUX/VBZ
# it/PRON/PRP <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--ROOT-- is/AUX/VBZ
# a/DET/DT <--det-- switch/NOUN/NN
# switch/NOUN/NN <--attr-- is/AUX/VBZ
# ./PUNCT/. <--punct-- is/AUX/VBZ
# obviously/ADV/RB <--advmod-- have/AUX/VBP
# you/PRON/PRP <--nsubj-- have/AUX/VBP
# have/AUX/VBP <--ROOT-- have/AUX/VBP
# portrait/NOUN/NN <--dobj-- have/AUX/VBP
# you/PRON/PRP <--nsubj-- have/AUX/VBP
# have/AUX/VBP <--relcl-- portrait/NOUN/NN
# night/NOUN/NN <--compound-- sight/NOUN/NN
# sight/NOUN/NN <--dobj-- have/AUX/VBP
# built/VERB/VBN <--acl-- sight/NOUN/NN
# -/PUNCT/HYPH <--punct-- sight/NOUN/NN
# in/ADP/RP <--ROOT-- in/ADP/RP
# all/ADV/RB <--advmod-- right/INTJ/UH
# right/INTJ/UH <--ROOT-- right/INTJ/UH
# ./PUNCT/. <--punct-- right/INTJ/UH
# this/DET/DT <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--ROOT-- is/AUX/VBZ
# a/DET/DT <--det-- device/NOUN/NN
# fresh/ADJ/JJ <--amod-- device/NOUN/NN
# device/NOUN/NN <--attr-- is/AUX/VBZ
# it/PRON/PRP <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--relcl-- device/NOUN/NN
# possibly/ADV/RB <--advmod-- is/AUX/VBZ
# not/PART/RB <--neg-- is/AUX/VBZ
# even/ADV/RB <--advmod-- number/NOUN/NN
# final/ADJ/JJ <--amod-- number/NOUN/NN
# software/NOUN/NN <--compound-- number/NOUN/NN
# number/NOUN/NN <--attr-- is/AUX/VBZ
# two/NUM/CD <--nummod-- number/NOUN/NN
# ./PUNCT/. <--punct-- is/AUX/VBZ
# all/ADV/RB <--advmod-- right/ADV/RB
# right/ADV/RB <--advmod-- configure/VERB/VB
# so/ADV/RB <--advmod-- within/ADP/IN
# within/ADP/IN <--prep-- configure/VERB/VB
# the/DET/DT <--det-- options/NOUN/NNS
# options/NOUN/NNS <--pobj-- within/ADP/IN
# of/ADP/IN <--prep-- options/NOUN/NNS
# course/NOUN/NN <--pobj-- of/ADP/IN
# you/PRON/PRP <--nsubj-- configure/VERB/VB
# can/AUX/MD <--aux-- configure/VERB/VB
# configure/VERB/VB <--ROOT-- configure/VERB/VB
# the/DET/DT <--det-- amount/NOUN/NN
# amount/NOUN/NN <--dobj-- configure/VERB/VB
# of/ADP/IN <--prep-- amount/NOUN/NN
# processing/NOUN/NN <--pobj-- of/ADP/IN
# that/PRON/WDT <--nsubj-- takes/VERB/VBZ
# takes/VERB/VBZ <--relcl-- amount/NOUN/NN
# place/NOUN/NN <--dobj-- takes/VERB/VBZ
# this/DET/DT <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--ccomp-- takes/VERB/VBZ
# with/ADP/IN <--prep-- is/AUX/VBZ
# some/DET/DT <--nsubj-- turned/VERB/VBD
# of/ADP/IN <--prep-- some/DET/DT
# the/DET/DT <--det-- stuff/NOUN/NN
# natural/ADJ/JJ <--amod-- face/NOUN/NN
# face/NOUN/NN <--compound-- stuff/NOUN/NN
# stuff/NOUN/NN <--pobj-- of/ADP/IN
# turned/VERB/VBD <--conj-- configure/VERB/VB
# off/ADP/RP <--prt-- turned/VERB/VBD
# ./PUNCT/. <--punct-- configure/VERB/VB
# we/PRON/PRP <--nsubj-- have/AUX/VBP
# have/AUX/VBP <--ROOT-- have/AUX/VBP
# an/DET/DT <--det-- abundance/NOUN/NN
# abundance/NOUN/NN <--dobj-- have/AUX/VBP
# of/ADP/IN <--prep-- abundance/NOUN/NN
# boxes/NOUN/NNS <--pobj-- of/ADP/IN
# here/ADV/RB <--advmod-- have/AUX/VBP
# ./PUNCT/. <--punct-- have/AUX/VBP
# so/ADV/RB <--advmod-- let/VERB/VB
# let/VERB/VB <--ROOT-- let/VERB/VB
# 's/PRON/PRP <--nsubj-- give/VERB/VB
# give/VERB/VB <--ccomp-- let/VERB/VB
# that/SCONJ/IN <--dative-- give/VERB/VB
# a/DET/DT <--det-- shot/NOUN/NN
# quick/ADJ/JJ <--amod-- shot/NOUN/NN
# shot/NOUN/NN <--dobj-- give/VERB/VB
# as/SCONJ/IN <--mark-- see/VERB/VB
# you/PRON/PRP <--nsubj-- see/VERB/VB
# can/AUX/MD <--aux-- see/VERB/VB
# see/VERB/VB <--advcl-- shot/NOUN/NN
# here/ADV/RB <--advmod-- see/VERB/VB
# ./PUNCT/. <--punct-- let/VERB/VB
# you/PRON/PRP <--nsubj-- get/VERB/VBP
# get/VERB/VBP <--ROOT-- get/VERB/VBP
# the/DET/DT <--det-- look/NOUN/NN
# wider/ADJ/JJR <--amod-- look/NOUN/NN
# look/NOUN/NN <--dobj-- get/VERB/VBP
# or/CCONJ/CC <--cc-- get/VERB/VBP
# you/PRON/PRP <--nsubj-- move/VERB/VB
# can/AUX/MD <--aux-- move/VERB/VB
# move/VERB/VB <--conj-- get/VERB/VBP
# in/ADP/IN <--prep-- move/VERB/VB
# a/DET/DT <--det-- bit/NOUN/NN
# little/ADJ/JJ <--amod-- bit/NOUN/NN
# bit/NOUN/NN <--npadvmod-- closer/ADV/RBR
# closer/ADV/RBR <--advmod-- move/VERB/VB
# ./PUNCT/. <--punct-- move/VERB/VB
# let/VERB/VB <--ROOT-- let/VERB/VB
# 's/PRON/PRP <--nsubj-- try/VERB/VB
# try/VERB/VB <--ccomp-- let/VERB/VB
# a/DET/DT <--det-- zoom/NOUN/NN
# 4x/ADJ/JJ <--compound-- zoom/NOUN/NN
# zoom/NOUN/NN <--dobj-- try/VERB/VB
# ./PUNCT/. <--punct-- let/VERB/VB
# I/PRON/PRP <--nsubj-- mean/VERB/VBP
# mean/VERB/VBP <--parataxis-- is/AUX/VBZ
# it/PRON/PRP <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--ROOT-- is/AUX/VBZ
# interesting/ADJ/JJ <--acomp-- is/AUX/VBZ
# because/SCONJ/IN <--mark-- see/VERB/VB
# in/ADP/IN <--prep-- see/VERB/VB
# the/DET/DT <--det-- preview/NOUN/NN
# preview/NOUN/NN <--pobj-- in/ADP/IN
# you/PRON/PRP <--nsubj-- see/VERB/VB
# can/AUX/MD <--aux-- see/VERB/VB
# actually/ADV/RB <--advmod-- see/VERB/VB
# see/VERB/VB <--advcl-- is/AUX/VBZ
# some/DET/DT <--dobj-- see/VERB/VB
# of/ADP/IN <--prep-- some/DET/DT
# the/DET/DT <--det-- noise/NOUN/NN
# noise/NOUN/NN <--pobj-- of/ADP/IN
# and/CCONJ/CC <--cc-- some/DET/DT
# stuff/NOUN/NN <--conj-- some/DET/DT
# that/PRON/WDT <--dobj-- have/AUX/VB
# you/PRON/PRP <--nsubj-- have/AUX/VB
# would/AUX/MD <--aux-- have/AUX/VB
# traditionally/ADV/RB <--advmod-- have/AUX/VB
# have/AUX/VB <--relcl-- some/DET/DT
# with/ADP/IN <--prep-- have/AUX/VB
# a/DET/DT <--det-- image/NOUN/NN
# digitally/ADV/RB <--advmod-- zoomed/VERB/VBN
# zoomed/VERB/VBN <--amod-- image/NOUN/NN
# image/NOUN/NN <--pobj-- with/ADP/IN
# ./PUNCT/. <--punct-- is/AUX/VBZ
# but/CCONJ/CC <--cc-- runs/VERB/VBZ
# then/ADV/RB <--advmod-- runs/VERB/VBZ
# in/ADP/IN <--prep-- runs/VERB/VBZ
# the/DET/DT <--det-- product/NOUN/NN
# finished/ADJ/JJ <--amod-- product/NOUN/NN
# product/NOUN/NN <--pobj-- in/ADP/IN
# the/DET/DT <--det-- software/NOUN/NN
# software/NOUN/NN <--nsubj-- runs/VERB/VBZ
# runs/VERB/VBZ <--ROOT-- runs/VERB/VBZ
# such/DET/PDT <--predet-- process/NOUN/NN
# a/DET/DT <--det-- process/NOUN/NN
# process/NOUN/NN <--dobj-- runs/VERB/VBZ
# on/ADP/IN <--prep-- process/NOUN/NN
# it/PRON/PRP <--pobj-- on/ADP/IN
# ./PUNCT/. <--punct-- runs/VERB/VBZ
# it/PRON/PRP <--nsubj-- eliminates/VERB/VBZ
# eliminates/VERB/VBZ <--ROOT-- eliminates/VERB/VBZ
# all/DET/DT <--dobj-- eliminates/VERB/VBZ
# of/ADP/IN <--prep-- all/DET/DT
# that/DET/DT <--pobj-- of/ADP/IN
# ./PUNCT/. <--punct-- eliminates/VERB/VBZ
# you/PRON/PRP <--nsubj-- see/VERB/VB
# can/AUX/MD <--aux-- see/VERB/VB
# see/VERB/VB <--ROOT-- see/VERB/VB
# a/DET/DT <--det-- couple/NOUN/NN
# couple/NOUN/NN <--dobj-- see/VERB/VB
# of/ADP/IN <--prep-- couple/NOUN/NN
# cutouts/NOUN/NNS <--pobj-- of/ADP/IN
# on/ADP/IN <--prep-- couple/NOUN/NN
# the/DET/DT <--det-- bottom/NOUN/NN
# bottom/NOUN/NN <--pobj-- on/ADP/IN
# presumably/ADV/RB <--advmod-- see/VERB/VB
# for/ADP/IN <--prep-- see/VERB/VB
# your/PRON/PRP$ <--poss-- speaker/NOUN/NN
# speaker/NOUN/NN <--pobj-- for/ADP/IN
# and/CCONJ/CC <--cc-- speaker/NOUN/NN
# microphone/NOUN/NN <--conj-- speaker/NOUN/NN
# as/ADV/RB <--advmod-- as/SCONJ/IN
# well/ADV/RB <--advmod-- as/SCONJ/IN
# as/SCONJ/IN <--cc-- speaker/NOUN/NN
# your/PRON/PRP$ <--poss-- connector/NOUN/NN
# type/NOUN/NN <--compound-- c/NOUN/NN
# -/PUNCT/HYPH <--punct-- c/NOUN/NN
# c/NOUN/NN <--compound-- connector/NOUN/NN
# connector/NOUN/NN <--conj-- speaker/NOUN/NN
# interestingly/ADV/RB <--advmod-- in/ADP/IN
# in/ADP/IN <--prep-- see/VERB/VB
# the/DET/DT <--det-- sheet/NOUN/NN
# spec/PROPN/NNP <--amod-- sheet/NOUN/NN
# sheet/NOUN/NN <--pobj-- in/ADP/IN
# it/PRON/PRP <--nsubj-- lists/VERB/VBZ
# lists/VERB/VBZ <--relcl-- sheet/NOUN/NN
# a/DET/DT <--det-- sim/NOUN/NN
# nano/NOUN/NN <--compound-- sim/NOUN/NN
# -/PUNCT/HYPH <--punct-- sim/NOUN/NN
# sim/NOUN/NN <--dobj-- lists/VERB/VBZ
# or/CCONJ/CC <--cc-- sim/NOUN/NN
# an/DET/DT <--det-- configurability/NOUN/NN
# e/ADJ/JJ <--compound-- configurability/NOUN/NN
# sim/NOUN/NN <--compound-- configurability/NOUN/NN
# configurability/NOUN/NN <--conj-- sim/NOUN/NN
# alright/INTJ/UH <--ccomp-- see/VERB/VB
# so/ADV/RB <--mark-- stacked/VERB/VBD
# since/SCONJ/IN <--mark-- have/AUX/VBP
# we/PRON/PRP <--nsubj-- have/AUX/VBP
# have/AUX/VBP <--advcl-- stacked/VERB/VBD
# the/DET/DT <--det-- displays/NOUN/NNS
# two/NUM/CD <--nummod-- displays/NOUN/NNS
# displays/NOUN/NNS <--nsubj-- stacked/VERB/VBD
# stacked/VERB/VBD <--advcl-- alright/INTJ/UH
# up/ADP/RP <--prt-- stacked/VERB/VBD
# ./PUNCT/. <--punct-- see/VERB/VB
# I/PRON/PRP <--nsubj-- think/VERB/VBP
# think/VERB/VBP <--ROOT-- think/VERB/VBP
# that/DET/DT <--nsubj-- gon/VERB/VBG
# 's/AUX/VBZ <--aux-- gon/VERB/VBG
# gon/VERB/VBG <--ccomp-- think/VERB/VBP
# na/PART/TO <--aux-- be/AUX/VB
# be/AUX/VB <--xcomp-- gon/VERB/VBG
# an/DET/DT <--det-- characteristic/NOUN/NN
# interesting/ADJ/JJ <--amod-- characteristic/NOUN/NN
# characteristic/NOUN/NN <--attr-- be/AUX/VB
# for/ADP/IN <--prep-- be/AUX/VB
# a/DET/DT <--det-- lot/NOUN/NN
# lot/NOUN/NN <--pobj-- for/ADP/IN
# of/ADP/IN <--prep-- lot/NOUN/NN
# people/NOUN/NNS <--pobj-- of/ADP/IN
# mostly/ADV/RB <--advmod-- added/VERB/VBN
# because/SCONJ/IN <--mark-- added/VERB/VBN
# they/PRON/PRP <--nsubj-- added/VERB/VBN
# have/AUX/VBP <--aux-- added/VERB/VBN
# added/VERB/VBN <--advcl-- gon/VERB/VBG
# 90/NUM/CD <--nummod-- Hertz/PROPN/NNP
# Hertz/PROPN/NNP <--dobj-- added/VERB/VBN
# to/ADP/IN <--prep-- added/VERB/VBN
# it/PRON/PRP <--pobj-- to/ADP/IN
# now/ADV/RB <--advmod-- added/VERB/VBN
# ./PUNCT/. <--punct-- think/VERB/VBP
# so/ADV/RB <--advmod-- is/AUX/VBZ
# what/PRON/WP <--dobj-- means/VERB/VBZ
# that/DET/DT <--nsubj-- means/VERB/VBZ
# means/VERB/VBZ <--csubj-- is/AUX/VBZ
# for/ADP/IN <--prep-- means/VERB/VBZ
# people/NOUN/NNS <--pobj-- for/ADP/IN
# that/PRON/WDT <--nsubj-- are/AUX/VBP
# are/AUX/VBP <--relcl-- people/NOUN/NNS
# unfamiliar/ADJ/JJ <--acomp-- are/AUX/VBP
# is/AUX/VBZ <--ROOT-- is/AUX/VBZ
# you/PRON/PRP <--nsubj-- get/VERB/VBP
# get/VERB/VBP <--ccomp-- is/AUX/VBZ
# this/DET/DT <--det-- kind/NOUN/NN
# really/ADV/RB <--advmod-- twitchy/ADJ/JJ
# twitchy/ADJ/JJ <--amod-- kind/NOUN/NN
# kind/NOUN/NN <--dobj-- get/VERB/VBP
# of/ADP/IN <--prep-- kind/NOUN/NN
# input/NOUN/NN <--pobj-- of/ADP/IN
# really/ADV/RB <--advmod-- responsive/ADJ/JJ
# responsive/ADJ/JJ <--amod-- field/NOUN/NN
# field/NOUN/NN <--appos-- kind/NOUN/NN
# ./PUNCT/. <--punct-- is/AUX/VBZ
# in/ADP/IN <--prep-- makes/VERB/VBZ
# fact/NOUN/NN <--pobj-- in/ADP/IN
# it/PRON/PRP <--nsubj-- makes/VERB/VBZ
# makes/VERB/VBZ <--ROOT-- makes/VERB/VBZ
# the/DET/DT <--det-- phone/NOUN/NN
# entire/ADJ/JJ <--amod-- phone/NOUN/NN
# phone/NOUN/NN <--nsubj-- feel/VERB/VBP
# feel/VERB/VBP <--ccomp-- makes/VERB/VBZ
# faster/ADV/RBR <--advmod-- alright/INTJ/UH
# alright/INTJ/UH <--acomp-- feel/VERB/VBP
# maybe/ADV/RB <--advmod-- play/VERB/VB
# we/PRON/PRP <--nsubj-- play/VERB/VB
# should/AUX/MD <--aux-- play/VERB/VB
# play/VERB/VB <--ccomp-- alright/INTJ/UH
# a/DET/DT <--det-- video/NOUN/NN
# video/NOUN/NN <--dobj-- play/VERB/VB
# ./PUNCT/. <--punct-- makes/VERB/VBZ
# let/VERB/VB <--ROOT-- let/VERB/VB
# 's/PRON/PRP <--nsubj-- compare/VERB/VB
# just/ADV/RB <--advmod-- compare/VERB/VB
# compare/VERB/VB <--ccomp-- let/VERB/VB
# the/DET/DT <--det-- speakers/NOUN/NNS
# speakers/NOUN/NNS <--dobj-- compare/VERB/VB
# on/ADP/IN <--prep-- compare/VERB/VB
# the/DET/DT <--det-- units/NOUN/NNS
# two/NUM/CD <--nummod-- units/NOUN/NNS
# units/NOUN/NNS <--pobj-- on/ADP/IN
# here/ADV/RB <--advmod-- units/NOUN/NNS
# ./PUNCT/. <--punct-- let/VERB/VB
# I/PRON/PRP <--nsubj-- got/VERB/VBN
# have/AUX/VBP <--aux-- got/VERB/VBN
# got/VERB/VBN <--ROOT-- got/VERB/VBN
# one/NUM/CD <--nsubj-- coming/VERB/VBG
# of/ADP/IN <--prep-- one/NUM/CD
# these/DET/DT <--det-- threes/NOUN/NNS
# surface/NOUN/NN <--compound-- threes/NOUN/NNS
# laptop/NOUN/NN <--compound-- threes/NOUN/NNS
# threes/NOUN/NNS <--pobj-- of/ADP/IN
# coming/VERB/VBG <--ccomp-- got/VERB/VBN
# in/ADV/RB <--prt-- coming/VERB/VBG
# ./PUNCT/. <--punct-- got/VERB/VBN
# well/INTJ/UH <--intj-- know/VERB/VB
# you/PRON/PRP <--nsubj-- know/VERB/VB
# did/AUX/VBD <--aux-- know/VERB/VB
# not/PART/RB <--neg-- know/VERB/VB
# know/VERB/VB <--ROOT-- know/VERB/VB
# that/SCONJ/IN <--mark-- caught/VERB/VBD
# Jack/PROPN/NNP <--nsubj-- caught/VERB/VBD
# caught/VERB/VBD <--ccomp-- know/VERB/VB
# you/PRON/PRP <--dobj-- caught/VERB/VBD
# off/ADP/IN <--prep-- caught/VERB/VBD
# -/PUNCT/HYPH <--punct-- guard/NOUN/NN
# guard/NOUN/NN <--pobj-- off/ADP/IN
# ./PUNCT/. <--punct-- know/VERB/VB
# you/PRON/PRP <--nsubj-- know/VERB/VBP
# know/VERB/VBP <--ROOT-- know/VERB/VBP
# that/SCONJ/IN <--mark-- coming/VERB/VBG
# a/DET/DT <--det-- amount/NOUN/NN
# significant/ADJ/JJ <--amod-- amount/NOUN/NN
# amount/NOUN/NN <--nsubj-- coming/VERB/VBG
# of/ADP/IN <--prep-- amount/NOUN/NN
# sound/NOUN/NN <--pobj-- of/ADP/IN
# is/AUX/VBZ <--aux-- coming/VERB/VBG
# coming/VERB/VBG <--ccomp-- know/VERB/VBP
# out/SCONJ/IN <--prep-- coming/VERB/VBG
# of/ADP/IN <--prep-- out/SCONJ/IN
# two/NUM/CD <--nummod-- ports/NOUN/NNS
# different/ADJ/JJ <--amod-- ports/NOUN/NNS
# ports/NOUN/NNS <--nmod-- sound/NOUN/NN
# substantial/ADJ/JJ <--amod-- sound/NOUN/NN
# sound/NOUN/NN <--pobj-- of/ADP/IN
# from/ADP/IN <--prep-- sound/NOUN/NN
# each/DET/DT <--det-- area/NOUN/NN
# area/NOUN/NN <--pobj-- from/ADP/IN
# ./PUNCT/. <--punct-- know/VERB/VBP
# it/PRON/PRP <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--ROOT-- is/AUX/VBZ
# more/ADJ/JJR <--amod-- volume/NOUN/NN
# volume/NOUN/NN <--attr-- is/AUX/VBZ
# than/SCONJ/IN <--mark-- used/VERB/VBN
# you/PRON/PRP <--nsubjpass-- used/VERB/VBN
# might/AUX/MD <--aux-- used/VERB/VBN
# be/AUX/VB <--auxpass-- used/VERB/VBN
# used/VERB/VBN <--advcl-- volume/NOUN/NN
# to/ADP/IN <--prep-- used/VERB/VBN
# out/SCONJ/IN <--prep-- used/VERB/VBN
# of/ADP/IN <--prep-- out/SCONJ/IN
# the/DET/DT <--det-- both/DET/DT
# both/DET/DT <--pobj-- of/ADP/IN
# of/ADP/IN <--prep-- both/DET/DT
# them/PRON/PRP <--pobj-- of/ADP/IN
# ./PUNCT/. <--punct-- is/AUX/VBZ
# balanced/PROPN/NNP <--intj-- let/VERB/VBD
# let/VERB/VBD <--ROOT-- let/VERB/VBD
# 's/PRON/PRP <--nsubj-- compare/VERB/VB
# compare/VERB/VB <--ccomp-- let/VERB/VBD
# it/PRON/PRP <--dobj-- compare/VERB/VB
# to/ADP/IN <--prep-- compare/VERB/VB
# the/DET/DT <--det-- phone/NOUN/NN
# little/ADJ/JJ <--amod-- phone/NOUN/NN
# phone/NOUN/NN <--pobj-- to/ADP/IN
# ./PUNCT/. <--punct-- let/VERB/VBD
# it/PRON/PRP <--nsubj-- sounds/VERB/VBZ
# all/DET/DT <--appos-- it/PRON/PRP
# sounds/VERB/VBZ <--ROOT-- sounds/VERB/VBZ
# very/ADV/RB <--advmod-- good/ADJ/JJ
# good/ADJ/JJ <--acomp-- sounds/VERB/VBZ
# on/ADP/IN <--prep-- sounds/VERB/VBZ
# paper/NOUN/NN <--pobj-- on/ADP/IN
# of/ADP/IN <--prep-- wait/VERB/VB
# course/NOUN/NN <--pobj-- of/ADP/IN
# the/DET/DT <--det-- marketplace/NOUN/NN
# marketplace/NOUN/NN <--nsubj-- wait/VERB/VB
# will/AUX/MD <--aux-- wait/VERB/VB
# wait/VERB/VB <--advcl-- sounds/VERB/VBZ
# but/CCONJ/CC <--cc-- wait/VERB/VB
# talking/VERB/VBG <--conj-- wait/VERB/VB
# a/DET/DT <--det-- lot/NOUN/NN
# lot/NOUN/NN <--dobj-- talking/VERB/VBG
# recently/ADV/RB <--advmod-- talking/VERB/VBG
# about/ADP/IN <--prep-- talking/VERB/VBG
# trying/VERB/VBG <--pcomp-- about/ADP/IN
# to/PART/TO <--aux-- nail/VERB/VB
# nail/VERB/VB <--xcomp-- trying/VERB/VBG
# down/ADP/RP <--prt-- nail/VERB/VB
# the/DET/DT <--det-- laptop/NOUN/NN
# perfect/ADJ/JJ <--amod-- laptop/NOUN/NN
# laptop/NOUN/NN <--dobj-- nail/VERB/VB
# ./PUNCT/. <--punct-- sounds/VERB/VBZ
# it/PRON/PRP <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--ROOT-- is/AUX/VBZ
# a/DET/DT <--det-- mission/NOUN/NN
# real/ADJ/JJ <--amod-- mission/NOUN/NN
# mission/NOUN/NN <--attr-- is/AUX/VBZ
# of/ADP/IN <--prep-- mission/NOUN/NN
# mine/PRON/PRP <--pobj-- of/ADP/IN
# ./PUNCT/. <--punct-- is/AUX/VBZ
# so/ADV/RB <--advmod-- 's/AUX/VBZ
# the/DET/DT <--det-- forehead/NOUN/NN
# larger/ADJ/JJR <--amod-- forehead/NOUN/NN
# than/SCONJ/IN <--prep-- larger/ADJ/JJR
# usual/ADJ/JJ <--amod-- forehead/NOUN/NN
# forehead/NOUN/NN <--nsubj-- 's/AUX/VBZ
# there/PRON/EX <--expl-- 's/AUX/VBZ
# 's/AUX/VBZ <--ROOT-- 's/AUX/VBZ
# also/ADV/RB <--advmod-- 's/AUX/VBZ
# sensors/NOUN/NNS <--attr-- 's/AUX/VBZ
# in/ADP/IN <--advmod-- there/ADV/RB
# there/ADV/RB <--advmod-- sensors/NOUN/NNS
# capable/ADJ/JJ <--amod-- sensors/NOUN/NNS
# of/ADP/IN <--prep-- capable/ADJ/JJ
# motion/NOUN/NN <--compound-- tracking/NOUN/NN
# tracking/NOUN/NN <--amod-- tracking/NOUN/NN
# tracking/NOUN/NN <--pobj-- of/ADP/IN
# of/ADP/IN <--prep-- tracking/NOUN/NN
# a/DET/DT <--det-- gestures/NOUN/NNS
# hand/NOUN/NN <--compound-- gestures/NOUN/NNS
# gestures/NOUN/NNS <--pobj-- of/ADP/IN
# Google/PROPN/NNP <--nsubj-- calling/VERB/VBG
# 's/PART/POS <--case-- Google/PROPN/NNP
# calling/VERB/VBG <--relcl-- gestures/NOUN/NNS
# it/PRON/PRP <--dobj-- calling/VERB/VBG
# motion/NOUN/NN <--compound-- sense/NOUN/NN
# sense/NOUN/NN <--oprd-- calling/VERB/VBG
# because/SCONJ/IN <--mark-- is/AUX/VBZ
# this/DET/DT <--det-- software/NOUN/NN
# software/NOUN/NN <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--advcl-- 's/AUX/VBZ
# early/ADJ/JJ <--acomp-- is/AUX/VBZ
# ./PUNCT/. <--punct-- 's/AUX/VBZ
# I/PRON/PRP <--nsubj-- showcase/VERB/VB
# can/AUX/MD <--aux-- showcase/VERB/VB
# not/PART/RB <--neg-- showcase/VERB/VB
# showcase/VERB/VB <--ROOT-- showcase/VERB/VB
# it/PRON/PRP <--dobj-- showcase/VERB/VB
# to/ADP/IN <--dative-- showcase/VERB/VB
# you/PRON/PRP <--pobj-- to/ADP/IN
# at/ADP/IN <--prep-- showcase/VERB/VB
# the/DET/DT <--det-- moment/NOUN/NN
# moment/NOUN/NN <--pobj-- at/ADP/IN
# ./PUNCT/. <--punct-- showcase/VERB/VB
# but/CCONJ/CC <--cc-- is/AUX/VBZ
# it/PRON/PRP <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--ROOT-- is/AUX/VBZ
# another/DET/DT <--det-- off/NOUN/NN
# trade/NOUN/NN <--compound-- off/NOUN/NN
# -/PUNCT/HYPH <--punct-- off/NOUN/NN
# off/NOUN/NN <--attr-- is/AUX/VBZ
# ./PUNCT/. <--punct-- is/AUX/VBZ
# I/PRON/PRP <--nsubj-- mean/VERB/VBP
# mean/VERB/VBP <--parataxis-- packing/VERB/VBG
# you/PRON/PRP <--nsubj-- packing/VERB/VBG
# 're/AUX/VBP <--aux-- packing/VERB/VBG
# packing/VERB/VBG <--ROOT-- packing/VERB/VBG
# in/ADP/IN <--prep-- packing/VERB/VBG
# some/DET/DT <--det-- hardware/NOUN/NN
# extra/ADJ/JJ <--amod-- hardware/NOUN/NN
# hardware/NOUN/NN <--pobj-- in/ADP/IN
# for/ADP/IN <--prep-- packing/VERB/VBG
# the/DET/DT <--det-- potential/NOUN/NN
# potential/NOUN/NN <--pobj-- for/ADP/IN
# to/PART/TO <--aux-- interact/VERB/VB
# interact/VERB/VB <--acl-- potential/NOUN/NN
# with/ADP/IN <--prep-- interact/VERB/VB
# your/PRON/PRP$ <--poss-- device/NOUN/NN
# device/NOUN/NN <--pobj-- with/ADP/IN
# without/ADP/IN <--prep-- interact/VERB/VB
# touching/VERB/VBG <--pcomp-- without/ADP/IN
# it/PRON/PRP <--dobj-- touching/VERB/VBG
# beyond/ADP/IN <--prep-- touching/VERB/VBG
# just/ADV/RB <--advmod-- assistant/NOUN/NN
# assistant/NOUN/NN <--pobj-- beyond/ADP/IN
# in/ADP/IN <--prep-- assistant/NOUN/NN
# your/PRON/PRP$ <--poss-- voice/NOUN/NN
# voice/NOUN/NN <--pobj-- in/ADP/IN
# now/ADV/RB <--advmod-- touching/VERB/VBG
# potentially/ADV/RB <--advmod-- touching/VERB/VBG
# ./PUNCT/. <--punct-- packing/VERB/VBG
# I/PRON/PRP <--nsubj-- scrolling/VERB/VBG
# 'm/AUX/VBP <--aux-- scrolling/VERB/VBG
# scrolling/VERB/VBG <--ROOT-- scrolling/VERB/VBG
# and/CCONJ/CC <--cc-- scrolling/VERB/VBG
# swiping/VERB/VBG <--conj-- scrolling/VERB/VBG
# without/ADP/IN <--prep-- swiping/VERB/VBG
# even/ADV/RB <--advmod-- touching/VERB/VBG
# touching/VERB/VBG <--pcomp-- without/ADP/IN
# it/PRON/PRP <--dobj-- touching/VERB/VBG
# on/ADP/IN <--prep-- touching/VERB/VBG
# the/DET/DT <--det-- version/NOUN/NN
# final/ADJ/JJ <--amod-- version/NOUN/NN
# version/NOUN/NN <--pobj-- on/ADP/IN
# of/ADP/IN <--prep-- version/NOUN/NN
# the/DET/DT <--det-- software/NOUN/NN
# software/NOUN/NN <--pobj-- of/ADP/IN
# ./PUNCT/. <--punct-- scrolling/VERB/VBG
# it/PRON/PRP <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--ROOT-- is/AUX/VBZ
# also/ADV/RB <--advmod-- is/AUX/VBZ
# important/ADJ/JJ <--acomp-- is/AUX/VBZ
# to/PART/TO <--aux-- know/VERB/VB
# know/VERB/VB <--xcomp-- important/ADJ/JJ
# ./PUNCT/. <--punct-- is/AUX/VBZ
# I/PRON/PRP <--nsubj-- mean/VERB/VBP
# mean/VERB/VBP <--ROOT-- mean/VERB/VBP
# with/ADP/IN <--prep-- mean/VERB/VBP
# the/DET/DT <--det-- devices/NOUN/NNS
# pixel/NOUN/NN <--compound-- devices/NOUN/NNS
# devices/NOUN/NNS <--pobj-- with/ADP/IN
# in/ADP/IN <--prep-- devices/NOUN/NNS
# general/ADJ/JJ <--amod-- in/ADP/IN
# ./PUNCT/. <--punct-- mean/VERB/VBP
# it/PRON/PRP <--nsubj-- means/VERB/VBZ
# means/VERB/VBZ <--ROOT-- means/VERB/VBZ
# you/PRON/PRP <--nsubj-- getting/VERB/VBG
# 're/AUX/VBP <--aux-- getting/VERB/VBG
# getting/VERB/VBG <--ccomp-- means/VERB/VBZ
# the/DET/DT <--det-- software/NOUN/NN
# latest/ADJ/JJS <--amod-- software/NOUN/NN
# software/NOUN/NN <--dobj-- getting/VERB/VBG
# that/PRON/WDT <--nsubj-- means/VERB/VBZ
# means/VERB/VBZ <--relcl-- software/NOUN/NN
# you/PRON/PRP <--nsubj-- getting/VERB/VBG
# 're/AUX/VBP <--aux-- getting/VERB/VBG
# getting/VERB/VBG <--ccomp-- means/VERB/VBZ
# features/NOUN/NNS <--dobj-- getting/VERB/VBG
# first/ADV/RB <--advmod-- features/NOUN/NNS
# including/VERB/VBG <--prep-- features/NOUN/NNS
# the/DET/DT <--det-- latest/ADJ/JJS
# latest/ADJ/JJS <--pobj-- including/VERB/VBG
# when/ADV/WRB <--advmod-- comes/VERB/VBZ
# it/PRON/PRP <--nsubj-- comes/VERB/VBZ
# comes/VERB/VBZ <--advcl-- getting/VERB/VBG
# to/ADP/IN <--prep-- comes/VERB/VBZ
# assistant/NOUN/NN <--pobj-- to/ADP/IN
# ok/INTJ/UH <--prep-- getting/VERB/VBG
# Google/PROPN/NNP <--ROOT-- Google/PROPN/NNP
# ./PUNCT/. <--punct-- Google/PROPN/NNP
# what/PRON/WP <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--ROOT-- is/AUX/VBZ
# unbox/ADJ/JJ <--amod-- therapy/NOUN/NN
# therapy/NOUN/NN <--attr-- is/AUX/VBZ
# ./PUNCT/. <--punct-- is/AUX/VBZ
# and/CCONJ/CC <--cc-- see/VERB/VB
# you/PRON/PRP <--nsubj-- see/VERB/VB
# can/AUX/MD <--aux-- see/VERB/VB
# see/VERB/VB <--ROOT-- see/VERB/VB
# the/DET/DT <--det-- way/NOUN/NN
# way/NOUN/NN <--dobj-- see/VERB/VB
# that/PRON/WDT <--mark-- is/AUX/VBZ
# its/PRON/PRP$ <--nsubj-- installed/VERB/VBN
# installed/VERB/VBN <--nsubj-- is/AUX/VBZ
# the/DET/DT <--det-- way/NOUN/NN
# way/NOUN/NN <--npadvmod-- installed/VERB/VBN
# that/SCONJ/IN <--mark-- implemented/VERB/VBN
# it/PRON/PRP <--nsubjpass-- implemented/VERB/VBN
# is/AUX/VBZ <--auxpass-- implemented/VERB/VBN
# implemented/VERB/VBN <--relcl-- way/NOUN/NN
# is/AUX/VBZ <--relcl-- way/NOUN/NN
# different/ADJ/JJ <--acomp-- is/AUX/VBZ
# than/SCONJ/IN <--mark-- used/VERB/VBD
# it/PRON/PRP <--nsubj-- used/VERB/VBD
# used/VERB/VBD <--advcl-- different/ADJ/JJ
# to/PART/TO <--aux-- be/AUX/VB
# be/AUX/VB <--xcomp-- used/VERB/VBD
# a/DET/DT <--det-- lot/NOUN/NN
# lot/NOUN/NN <--attr-- be/AUX/VB
# happens/VERB/VBZ <--ccomp-- see/VERB/VB
# now/ADV/RB <--advmod-- happens/VERB/VBZ
# right/ADV/RB <--advmod-- within/ADP/IN
# within/ADP/IN <--prep-- happens/VERB/VBZ
# the/DET/DT <--det-- screen/NOUN/NN
# main/ADJ/JJ <--amod-- screen/NOUN/NN
# screen/NOUN/NN <--pobj-- within/ADP/IN
# ./PUNCT/. <--punct-- see/VERB/VB
# so/ADV/RB <--advmod-- jump/VERB/VB
# you/PRON/PRP <--nsubj-- jump/VERB/VB
# do/AUX/VBP <--aux-- jump/VERB/VB
# not/PART/RB <--neg-- jump/VERB/VB
# jump/VERB/VB <--ROOT-- jump/VERB/VB
# over/ADP/RP <--prt-- jump/VERB/VB
# to/ADP/IN <--prep-- jump/VERB/VB
# a/DET/DT <--det-- app/NOUN/NN
# different/ADJ/JJ <--amod-- app/NOUN/NN
# app/NOUN/NN <--pobj-- to/ADP/IN
# in/ADP/IN <--prep-- jump/VERB/VB
# order/NOUN/NN <--pobj-- in/ADP/IN
# to/PART/TO <--aux-- engage/VERB/VB
# engage/VERB/VB <--acl-- order/NOUN/NN
# it/PRON/PRP <--dobj-- engage/VERB/VB
# and/CCONJ/CC <--cc-- jump/VERB/VB
# of/ADV/RB <--prep-- is/AUX/VBZ
# course/NOUN/NN <--pobj-- of/ADV/RB
# the/DET/DT <--det-- version/NOUN/NN
# advanced/ADJ/JJ <--amod-- version/NOUN/NN
# version/NOUN/NN <--nsubj-- is/AUX/VBZ
# of/ADP/IN <--prep-- version/NOUN/NN
# that/DET/DT <--pobj-- of/ADP/IN
# is/AUX/VBZ <--conj-- jump/VERB/VB
# the/DET/DT <--det-- continuation/NOUN/NN
# continuation/NOUN/NN <--nsubj-- is/AUX/VBZ
# of/ADP/IN <--prep-- continuation/NOUN/NN
# conversation/NOUN/NN <--pobj-- of/ADP/IN
# which/PRON/WDT <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--relcl-- conversation/NOUN/NN
# the/DET/DT <--det-- instruction/NOUN/NN
# initial/ADJ/JJ <--amod-- instruction/NOUN/NN
# instruction/NOUN/NN <--attr-- is/AUX/VBZ
# and/CCONJ/CC <--cc-- is/AUX/VBZ
# then/ADV/RB <--advmod-- dive/NOUN/NN
# the/DET/DT <--det-- dive/NOUN/NN
# deeper/ADJ/JJR <--amod-- dive/NOUN/NN
# dive/NOUN/NN <--conj-- is/AUX/VBZ
# with/ADP/IN <--prep-- dive/NOUN/NN
# assistant/ADJ/JJ <--amod-- understanding/NOUN/NN
# understanding/NOUN/NN <--compound-- context/NOUN/NN
# context/NOUN/NN <--pobj-- with/ADP/IN
# ./PUNCT/. <--punct-- is/AUX/VBZ
# so/ADV/RB <--advmod-- want/VERB/VBP
# you/PRON/PRP <--nsubj-- want/VERB/VBP
# want/VERB/VBP <--ROOT-- want/VERB/VBP
# to/PART/TO <--aux-- say/VERB/VB
# say/VERB/VB <--xcomp-- want/VERB/VBP
# okay/INTJ/UH <--intj-- say/VERB/VB
# ./PUNCT/. <--punct-- want/VERB/VBP
# Google/PROPN/NNP <--compound-- Siri/PROPN/NNP
# hey/INTJ/UH <--compound-- Siri/PROPN/NNP
# Siri/PROPN/NNP <--nsubj-- is/AUX/VBZ
# merely/ADV/RB <--advmod-- is/AUX/VBZ
# is/AUX/VBZ <--ROOT-- is/AUX/VBZ
# often/ADV/RB <--advmod-- is/AUX/VBZ
# I/PRON/PRP <--nsubj-- think/VERB/VBP
# think/VERB/VBP <--ccomp-- is/AUX/VBZ
# the/DET/DT <--det-- takeaway/NOUN/NN
# biggest/ADJ/JJS <--amod-- takeaway/NOUN/NN
# takeaway/NOUN/NN <--nsubj-- going/VERB/VBG
# here/ADV/RB <--advmod-- takeaway/NOUN/NN
# is/AUX/VBZ <--aux-- going/VERB/VBG
# going/VERB/VBG <--ccomp-- think/VERB/VBP
# to/PART/TO <--aux-- be/AUX/VB
# be/AUX/VB <--xcomp-- going/VERB/VBG
# Google/PROPN/NNP <--nsubj-- moving/VERB/VBG
# moving/VERB/VBG <--ccomp-- be/AUX/VB
# towards/ADP/IN <--prep-- moving/VERB/VBG
# 90/NUM/CD <--nummod-- display/NOUN/NN
# Hertz/PROPN/NNP <--compound-- display/NOUN/NN
# display/NOUN/NN <--pobj-- towards/ADP/IN
# for/ADP/IN <--prep-- display/NOUN/NN
# one/NUM/CD <--pobj-- for/ADP/IN
# and/CCONJ/CC <--cc-- moving/VERB/VBG
# then/ADV/RB <--advmod-- secondary/ADJ/JJ
# secondary/ADJ/JJ <--conj-- moving/VERB/VBG
# it/PRON/PRP <--nsubj-- going/VERB/VBG
# is/AUX/VBZ <--aux-- going/VERB/VBG
# going/VERB/VBG <--ccomp-- secondary/ADJ/JJ
# to/PART/TO <--aux-- be/AUX/VB
# be/AUX/VB <--xcomp-- going/VERB/VBG
# camera/NOUN/NN <--compound-- performance/NOUN/NN
# performance/NOUN/NN <--attr-- be/AUX/VB
# eventually/ADV/RB <--advmod-- on/ADP/IN
# on/ADP/IN <--prep-- be/AUX/VB
# final/ADJ/JJ <--amod-- software/NOUN/NN
# software/NOUN/NN <--pobj-- on/ADP/IN
# what/PRON/WP <--pobj-- of/ADP/IN
# it/PRON/PRP <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--ccomp-- be/AUX/VB
# capable/ADJ/JJ <--acomp-- is/AUX/VBZ
# of/ADP/IN <--prep-- capable/ADJ/JJ
# from/ADP/IN <--prep-- capable/ADJ/JJ
# a/DET/DT <--det-- perspective/NOUN/NN
# computational/ADJ/JJ <--amod-- perspective/NOUN/NN
# perspective/NOUN/NN <--pobj-- from/ADP/IN
# that/PRON/WDT <--nsubj-- 's/AUX/VBZ
# 's/AUX/VBZ <--relcl-- perspective/NOUN/NN
# every/DET/DT <--det-- one/NOUN/NN
# single/ADJ/JJ <--amod-- one/NOUN/NN
# one/NOUN/NN <--attr-- 's/AUX/VBZ
# on/ADP/IN <--prep-- one/NOUN/NN
# box/NOUN/NN <--pobj-- on/ADP/IN
# as/SCONJ/IN <--mark-- mentioned/VERB/VBD
# I/PRON/PRP <--nsubj-- mentioned/VERB/VBD
# mentioned/VERB/VBD <--advcl-- 's/AUX/VBZ
# this/DET/DT <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--ccomp-- mentioned/VERB/VBD
# just/ADV/RB <--advmod-- type/NOUN/NN
# a/DET/DT <--det-- type/NOUN/NN
# first/ADJ/JJ <--amod-- look/NOUN/NN
# -/PUNCT/HYPH <--punct-- look/NOUN/NN
# look/NOUN/NN <--compound-- type/NOUN/NN
# type/NOUN/NN <--attr-- is/AUX/VBZ
# of/ADP/IN <--prep-- type/NOUN/NN
# video/NOUN/NN <--pobj-- of/ADP/IN
# I/PRON/PRP <--nsubj-- have/AUX/VB
# will/AUX/MD <--aux-- have/AUX/VB
# have/AUX/VB <--relcl-- type/NOUN/NN
# a/DET/DT <--det-- up/ADP/RP
# follow/NOUN/NN <--compound-- up/ADP/RP
# -/PUNCT/HYPH <--punct-- up/ADP/RP
# up/ADP/RP <--dobj-- have/AUX/VB
# today/NOUN/NN <--poss-- day/NOUN/NN
# 's/PART/POS <--case-- today/NOUN/NN
# pixel/NOUN/NN <--compound-- day/NOUN/NN
# day/NOUN/NN <--npadvmod-- have/AUX/VB
# ./PUNCT/. <--punct-- is/AUX/VBZ
# it/PRON/PRP <--nsubj-- came/VERB/VBD
# just/ADV/RB <--advmod-- came/VERB/VBD
# came/VERB/VBD <--ROOT-- came/VERB/VBD
# out/ADP/RP <--prt-- came/VERB/VBD
# ./PUNCT/. <--punct-- came/VERB/VBD
# so/ADV/RB <--advmod-- have/AUX/VBP
# you/PRON/PRP <--nsubj-- have/AUX/VBP
# have/AUX/VBP <--ROOT-- have/AUX/VBP
# two/NUM/CD <--nummod-- excel/NOUN/NN
# clearly/ADV/RB <--advmod-- white/ADJ/JJ
# white/ADJ/JJ <--amod-- excel/NOUN/NN
# excel/NOUN/NN <--dobj-- have/AUX/VBP
# ./PUNCT/. <--punct-- have/AUX/VBP
# oh/INTJ/UH <--intj-- mention/VERB/VB
# I/PRON/PRP <--nsubj-- mention/VERB/VB
# should/AUX/MD <--aux-- mention/VERB/VB
# also/ADV/RB <--advmod-- mention/VERB/VB
# mention/VERB/VB <--ROOT-- mention/VERB/VB
# that/DET/DT <--mark-- is/AUX/VBZ
# oh/INTJ/UH <--intj-- is/AUX/VBZ
# so/ADV/RB <--advmod-- is/AUX/VBZ
# orange/ADJ/JJ <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--ccomp-- mention/VERB/VB
# apparently/ADV/RB <--advmod-- is/AUX/VBZ
# limited/ADJ/JJ <--amod-- edition/NOUN/NN
# edition/NOUN/NN <--attr-- is/AUX/VBZ
# so/SCONJ/IN <--mark-- know/VERB/VB
# if/SCONJ/IN <--mark-- 're/AUX/VBP
# you/PRON/PRP <--nsubj-- 're/AUX/VBP
# 're/AUX/VBP <--advcl-- know/VERB/VB
# interested/ADJ/JJ <--acomp-- 're/AUX/VBP
# I/PRON/PRP <--nsubj-- know/VERB/VB
# do/AUX/VBP <--aux-- know/VERB/VB
# not/PART/RB <--neg-- know/VERB/VB
# know/VERB/VB <--advcl-- is/AUX/VBZ
# what/PRON/WP <--dobj-- line/NOUN/NN
# you/PRON/PRP <--nmod-- guys/NOUN/NNS
# guys/NOUN/NNS <--nsubj-- line/NOUN/NN
# do/AUX/VBP <--aux-- line/NOUN/NN
# line/NOUN/NN <--csubj-- get/AUX/VB
# up/ADP/RP <--prt-- line/NOUN/NN
# get/AUX/VB <--ccomp-- know/VERB/VB
# your/PRON/PRP$ <--poss-- order/NOUN/NN
# order/NOUN/NN <--dobj-- get/AUX/VB
# in/ADP/IN <--prep-- order/NOUN/NN
# go/VERB/VB <--nmod-- version/NOUN/NN
# black/ADJ/JJ <--amod-- version/NOUN/NN
# version/NOUN/NN <--pobj-- in/ADP/IN
# which/PRON/WDT <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--relcl-- version/NOUN/NN
# the/DET/DT <--det-- one/NUM/CD
# only/ADV/RB <--amod-- one/NUM/CD
# glossy/ADJ/JJ <--amod-- one/NUM/CD
# one/NUM/CD <--attr-- is/AUX/VBZ
# of/ADP/IN <--prep-- one/NUM/CD
# the/DET/DT <--det-- bunch/NOUN/NN
# bunch/NOUN/NN <--pobj-- of/ADP/IN
# if/SCONJ/IN <--mark-- 's/AUX/VBZ
# that/DET/DT <--nsubj-- 's/AUX/VBZ
# 's/AUX/VBZ <--advcl-- get/AUX/VB
# what/PRON/WP <--attr-- 're/AUX/VBP
# you/PRON/PRP <--nsubj-- 're/AUX/VBP
# 're/AUX/VBP <--ccomp-- 's/AUX/VBZ
# into/ADP/IN <--prep-- 're/AUX/VBP
# polished/VERB/VBN <--amod-- type/NOUN/NN
# fancy/ADJ/JJ <--amod-- type/NOUN/NN
# type/NOUN/NN <--pobj-- into/ADP/IN
# of/ADP/IN <--prep-- type/NOUN/NN
# lifestyle/NOUN/NN <--pobj-- of/ADP/IN
# you/PRON/PRP <--nsubj-- go/VERB/VB
# can/AUX/MD <--aux-- go/VERB/VB
# go/VERB/VB <--relcl-- type/NOUN/NN
# for/ADP/IN <--prep-- go/VERB/VB
# that/DET/DT <--nsubj-- look/NOUN/NN
# look/NOUN/NN <--pobj-- for/ADP/IN
# as/ADV/RB <--advmod-- well/ADV/RB
# well/ADV/RB <--advmod-- go/VERB/VB
# ./PUNCT/. <--punct-- mention/VERB/VB
# I/PRON/PRP <--nsubj-- think/VERB/VBP
# think/VERB/VBP <--ROOT-- think/VERB/VBP
# I/PRON/PRP <--nsubj-- leaning/VERB/VBG
# 'm/AUX/VBP <--aux-- leaning/VERB/VBG
# leaning/VERB/VBG <--ccomp-- think/VERB/VBP
# towards/ADP/IN <--prep-- leaning/VERB/VBG
# this/DET/DT <--det-- right/NOUN/NN
# one/NUM/CD <--nummod-- right/NOUN/NN
# right/NOUN/NN <--pobj-- towards/ADP/IN
# ./PUNCT/. <--punct-- think/VERB/VBP

# %%
def sentenceSentiment(text):
    comprehend = boto3.client(service_name='comprehend', region_name='us-west-2')
    sentiment_json = comprehend.detect_sentiment(Text=text, LanguageCode='en')
    sent = sentiment_json['Sentiment']
    sent_pos = sentiment_json['SentimentScore']['Positive']
    sent_neg = sentiment_json['SentimentScore']['Negative']
    sent_neu = sentiment_json['SentimentScore']['Neutral']
    sent_mix = sentiment_json['SentimentScore']['Mixed']

    return sent, sent_pos, sent_neg, sent_neu, sent_mix

# %%
for statement in statements:
    sentiment = sentenceSentiment(statement)
    if sentiment[3] > 0.5:
        print(statement)
        print(sentiment)
# Out:
# the iPhone 11 is the phone most people in the iOS ecosystem
# ('NEUTRAL', 0.20601189136505127, 0.011957553215324879, 0.782002866268158, 2.7693422453012317e-05)
# this is the Pro review
# ('NEUTRAL', 0.01755661517381668, 0.001429559662938118, 0.9810057878494263, 8.045630238484591e-06)
# The iPhone 11 is the reverse
# ('NEUTRAL', 0.058414336293935776, 0.0018085332121700048, 0.9397744536399841, 2.7406601930124452e-06)
# There are three cameras on the iPhone 11
# ('NEUTRAL', 0.010222614742815495, 0.0004610633768606931, 0.9893151521682739, 1.121065338338667e-06)
# This improvement is due to something Apple 's calling semantic rendering
# ('NEUTRAL', 0.4001956284046173, 0.027828281745314598, 0.5719702243804932, 5.85056523050298e-06)
# This is all basically the same as the iPhone XS and the Pixel 3
# ('NEUTRAL', 0.015904804691672325, 0.08045540004968643, 0.903616189956665, 2.3550483092549257e-05)
# The improvements to Smart HDR are applicable across cameras
# ('NEUTRAL', 0.47931650280952454, 0.00026124357827939093, 0.5204174518585205, 4.8193091970460955e-06)
# Apple is not afraid of underexposing the blacks
# ('NEUTRAL', 0.4289695918560028, 0.029202084988355637, 0.5417895913124084, 3.874185495078564e-05)
# chances are you
# ('NEUTRAL', 0.1772502362728119, 0.019331132993102074, 0.803133487701416, 0.0002851523458957672)
# It is basically a surround decoder
# ('NEUTRAL', 0.05668151006102562, 0.282632440328598, 0.6606785655021667, 7.471414392057341e-06)
# it is there
# ('NEUTRAL', 0.11981705576181412, 0.029468011111021042, 0.8506970405578613, 1.7865433619590476e-05)
# iOS 13.1 is already in beta and scheduled for wide release by the end of this month
# ('NEUTRAL', 0.020909203216433525, 0.015859263017773628, 0.9632288813591003, 2.6049945063277846e-06)
# it is time to upgrade
# ('NEUTRAL', 0.10264958441257477, 0.2566056251525879, 0.6403980255126953, 0.00034671855974011123)
# they are both on the channel
# ('NEUTRAL', 0.05452942103147507, 0.024270256981253624, 0.9211307764053345, 6.946762005100027e-05)

# %%
def Score(extracted_statements,statements_list):
    """Use number of matches/ (total number of guesses + number of missed)
    as  a  criteria to see how our statement extractor is performing"""
    useful_statements = statements_list.copy()
    num_matches = 0
    total_useful = len(useful_statements)
    num_guesses = len(extracted_statements)
    for guess in extracted_statements:
        for actual in  useful_statements:
            A = set(guess.lower().split())
            B = set(actual.lower().split())
            if A.issubset(B) or B.issubset(A):
                num_matches += 1
                useful_statements.remove(actual)
                break
    num_missed = len(useful_statements)
    return num_matches/(num_guesses + num_missed), total_useful, num_matches, num_missed, num_guesses

# %%
#file = open("EvaluationText/mkbhdPixel.txt")
#file = open("EvaluationText/unboxPixel.txt")
#file = open("EvaluationText/Chromebook.txt")
#file = open("EvaluationText/GoPro.txt")
#file = open("EvaluationText/Airpods.txt")
file = open("EvaluationText/iphone11.txt")
f = file.readlines()
file.close()

# %%
Score(statements,useful)
# Out:
# (0.7849462365591398, 78, 73, 5, 88)

# %%
df1 = pd.DataFrame({'video':['mkbhdPixel','unboxPixel','Chromebook','GoPro','Airpods','iphone11'],'useful_sentences':[a,b,c,d,e,f]})

# %%
df1.to_csv('EvaluationText/evaluationText.csv',index=False)

# %%
df = pd.read_csv('EvaluationText/evaluationText.csv')
evaluation = list(df['useful_sentences'])

# %%
df
# Out:
#         video                                   useful_sentences
# 0  mkbhdPixel  ['this is one of the phones I was looking forw...
# 1  unboxPixel  ['it is the for excel in the three different c...
# 2  Chromebook  ['it is still a lot of money for a Chromebook ...
# 3       GoPro  ["And it is GoPro 's second attempt at a consu...
# 4     Airpods  ['it is a little bit bigger than before , but ...
# 5    iphone11  ['the iPhone 11 is the phone most people in th...
