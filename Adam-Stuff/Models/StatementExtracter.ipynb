# %%
# !pip install -U spacy
# !python -m spacy download en_core_web_sm

# %%
import nltk
import numpy as np
from itertools import groupby, chain
from collections import Counter, defaultdict
import spacy
spacy_nlp = spacy.load("en_core_web_sm")
import re
import boto3

class StatementExtracter(object):
    """
    As part of key word extraction and sentiment summarization, this code will be
    able to extract certain types of statements from a block of text.
    """
    
    def __init__(self, stopwords = None, punctuations = None):
        self.stopwords = stopwords
        self.punctuations = punctuations
        if self.stopwords == None:
            self.stopwords = []
        if self.punctuations == None:
            self.punctuations = list('!"#%&\'()*+,./:;<=>?@[\\]^_`{|}~♪')
        self.phrase_breaks = set(self.stopwords + self.punctuations)
        
    def replace_contraction(self, text):
        """
        Takes in text and replaces certain contractions
        """
        contraction_patterns = [(r'won\'t', 'will not'), (r'can\'t', 'can not'), (r'i\'m', 'i am'), 
                                (r'ain\'t', 'is not'), (r'(\w+)\'ll', '\g<1> will'), (r'(\w+)n\'t', '\g<1> not'),
                                (r'(\w+)\'ve', '\g<1> have'), (r'(\w+)\'d', '\g<1> would'), (r'&', 'and'),
                                (r'dammit', 'damn it'), (r'dont', 'do not'), (r'wont', 'will not'),
                                (r'they\'re', 'they are'), (r'They\'re', 'They are'), (r'it\'s', 'it is'), (r'It\'s', 'It is')]
        patterns = [(re.compile(regex), repl) for (regex, repl) in contraction_patterns]
        for (pattern, repl) in patterns:
            (text, count) = re.subn(pattern, repl, text)
        return text
    
    def add_periods(self, text):
        """
        Takes in a string of text with no punctuation, uses Spacy's method of breaking up sentences to 
        add periods to the end of these sentences. Returns text with periods.
        """
        doc = spacy_nlp(text)
        sentence_tokens = [sents.text for sents in doc.sents]
        new_sentence_tokens = []
        add_on = None
        for i in range(len(sentence_tokens)-1,-1,-1):
            if " " in sentence_tokens[i]:
                if add_on == None:
                    # Add a period to the end of the sentence
                    new_sentence_tokens.append(sentence_tokens[i]+'.')
                else:
                    # Add 1 word and period to the end of the sentence.
                    new_sentence_tokens.append(sentence_tokens[i]+' '+add_on+'.')
                    add_on = None
            else:
                # If there is a sentence which is just one word, add it to the end of the previous sentence.
                add_on = sentence_tokens[i]
        new_text = " ".join(new_sentence_tokens[::-1])
        return new_text
        
    def spacy_POS_phrase_breaks(self, doc, POS_we_want, tag_we_want, dep_we_want):
        """
        Inputs a string of text, a list of POS, and a list of Spacy Tags that we want to keep in.
        This method parses the text and adds words that do not fall into POS and TAGS to phrase breaks list.
        """
        # Initialize the set with our existing phrase breaks
        temp_phrase_breaks = self.phrase_breaks.copy()

        for token in doc:
            if token.pos_ not in POS_we_want and token.tag_ not in tag_we_want and token.dep_ not in dep_we_want:
                temp_phrase_breaks.add(token.text.lower())
        return temp_phrase_breaks
    
    def visualize_POS(self, text, punctuation = False):
        """Visualize the POS of each word in the text"""
        if punctuation == False:
            text = self.add_periods(text)
            text = self.replace_contraction(text)
        else:
            text = self.replace_contraction(text)
        doc = spacy_nlp(text)
        for token in doc:
            print("{0}/{1}/{2} <--{3}-- {4}/{5}/{6}".format(
                    token.text,token.pos_,token.tag_,token.dep_,token.head.text,token.head.pos_,token.head.tag_))        
    
    def is_statements(self, text):
        # Situation where text contains sentences/punctuation
        if ", " in text:
            text = self.replace_contraction(text)
            statements = self.statementExtraction(text, withPunctuation = True)
            output = self.orderSentiment(statements)
            return output
        # Situation where text does not contain sentences/punctuation
        else:
            text = self.add_periods(text)
            text = self.replace_contraction(text)
            statements = self.statementExtraction(text, withPunctuation = False)
            output = self.orderSentiment(statements)
            return output
        
    def statementExtraction(self, text, withPunctuation = False):
        doc = spacy_nlp(text)
        statements = list()
        for token in doc:
            # If the token is "is" or "are", we want to look at the subtree
            if token.text in ['is','are']:
                # Pull the subtree as token objects and as pure text
                subtree = [i for i in token.subtree]

                # Split the subtree up into left and right groups
                left_subtree = [word for word in subtree if word.i < token.i]
                right_subtree = [word for word in subtree if word.i > token.i]

                if withPunctuation == True:
                    # Create a temporary set of break words based on the Part of Speech
                    left_POS = ['ADJ','DET','NOUN','NUM','PART','PROPN','PUNCT','ADP','PRON','AUX','SYM','SCONJ']
                    left_tags = []
                    left_dep = []
                    right_POS = ['ADJ','DET','NOUN','NUM','PART','PROPN','ADV','PUNCT','ADP','AUX','SYM','SCONJ','CCONJ','PRON']
                    right_tags = ['VBG','VBZ','VBP','VB','VBD','VBN']
                    right_dep = []
                if withPunctuation == False:
                    left_POS = ['NOUN']
                    left_tags = ['NNP','PRP','HYPH','JJ']
                    left_dep = ['advmod','amod','neg', 'nsubj']
                    right_POS = ['ADJ','DET','NOUN','NUM','PART','PROPN','ADV','ADP']
                    right_tags = ['VB','VBG','HYPH','VBN','UH']
                    right_dep = ['intj','prep','neg','pobj']
                left_phrase_breaks = self.spacy_POS_phrase_breaks(subtree, left_POS, left_tags, left_dep)
                right_phrase_breaks = self.spacy_POS_phrase_breaks(subtree, right_POS, right_tags, right_dep)

                # group words together using phrase breaks and a separator 
                left_phrase_groups = groupby(left_subtree, lambda word: word.text.lower() not in left_phrase_breaks)
                # Pull out the groups of words that do not include any of the phrase breaks   
                left_phrase_tuples = [tuple(group[1]) for group in left_phrase_groups if group[0] == True]

                # group words together using phrase breaks and a separator 
                right_phrase_groups = groupby(right_subtree, lambda word: word.text.lower() not in right_phrase_breaks)
                # Pull out the groups of words that do not include any of the phrase breaks   
                right_phrase_tuples = [tuple(group[1]) for group in right_phrase_groups if group[0] == True]

                subject = []
                description = []
                
                if withPunctuation == True:
                    # For the subjects on the left side of "is/are"
                    subject_word = None
                    for tuple_ in left_phrase_tuples:
                        for word in tuple_:
                            # if any of the words inside the tuple is a 'nsubj', it is potentially what we want
                            if word.dep_ in ['nsubj', 'expl']:
                                # check if we already have a good candidate for subject
                                if len(subject) < 1:
                                    subject_word = word
                                    subject = tuple_
                                    break
                                elif subject_word.pos_ in ['NOUN'] and word.pos_ not in ['NOUN']:
                                    pass
                                # if the existing candidate is not a noun, then we can update it.
                                else:
                                    subject_word = word
                                    subject = tuple_
                                    break
                    # Look at right text, if it includes adj, keep it + or just take the first phrase in the tuple.
                    if len(right_phrase_tuples) > 0:
                        description = right_phrase_tuples[0]
                if withPunctuation == False:
                    # For the subjects on the left side of "is/are"
                    subject_word = None
                    for tuple_ in left_phrase_tuples:
                        for word in tuple_:
                            # if any of the words inside the tuple is a 'nsubj', it is potentially what we want
                            if word.dep_ in ['nsubj', 'expl'] and word.pos_ in ['NOUN','DET','PRON']:
                                # check if we already have a good candidate for subject
                                if len(subject) < 1:
                                    subject_word = word
                                    subject = tuple_
                                    break
                                elif subject_word.pos_ in ['NOUN','DET'] and word.pos_ not in ['NOUN','DET']:
                                    pass
                                # if the existing candidate is not a noun, then we can update it.
                                else:
                                    subject_word = word
                                    subject = tuple_
                                    break
                    # Look at right text to get a description.
                    if len(right_phrase_tuples) > 0  and len(subtree) < 30:
                        for word in right_phrase_tuples[0]:
                            if word.pos_ == "ADJ":
                                description = right_phrase_tuples[0]

                    
                # Create the statements
#                 print(" ".join([word.text for word in subtree]))
#                 print([(word.text,word.pos_,word.tag_,word.dep_) for word in left_subtree])
#                 print([(word.text,word.pos_,word.tag_,word.dep_) for word in right_subtree])
#                 print('\n')
                #print(" ".join([word.text for word in subtree]))
                if len(subject) > 0 and len(description) > 0:
                    output = " ".join([word.text for word in subject]) + " " + token.text + " " + " ".join([word.text for word in description])
                    #print(output+"\n")
                    if output not in statements:
                        statements.append(output)
        return statements
    
    def sentenceSentiment(self,text):
        """
        Takes in a line of text and uses amazon's comprehend to obtain the sentiment of the text.
        Returns the text and the score, as well as the sentiment of the text
        """
        comprehend = boto3.client(service_name='comprehend', region_name='us-west-2')
        sentiment_json = comprehend.detect_sentiment(Text=text, LanguageCode='en')
        sent = sentiment_json['Sentiment']
        sent_pos = sentiment_json['SentimentScore']['Positive']
        sent_neg = sentiment_json['SentimentScore']['Negative']
        sent_neu = sentiment_json['SentimentScore']['Neutral']
        sent_mix = sentiment_json['SentimentScore']['Mixed']
        
        #return sent, sent_pos, sent_neg, sent_neu, sent_mix
        if sent == "POSITIVE":
            return (text,sent_pos), sent
        elif sent == "NEGATIVE":
            return (text,sent_neg), sent
        elif sent == "NEUTRAL":
            return (text, sent_neu), sent
        elif sent == "MIXED":
            return (text, sent_mix), sent
        
    def orderSentiment(self, statements):
        """
        Takes in a list of statements and outputs a dictionary of lists of phrases ordered by score
        """
        positive = []
        negative = []
        neutral = []
        mixed = []
        for statement in statements:
            text, sentiment = self.sentenceSentiment(statement)
            if sentiment == "POSITIVE":
                positive.append(text)
            elif sentiment == "NEGATIVE":
                negative.append(text)
            elif sentiment == "NEUTRAL":
                neutral.append(text)
            elif sentiment == "MIXED":
                mixed.append(text)
            
        # Return a dict in the format of {pos:[list of positive phrases sorted by score], etc.}
        output = {"pos":[positive[j][0] for j in np.argsort([i[1] for i in positive])[::-1]],
                  "neg":[negative[j][0] for j in np.argsort([i[1] for i in negative])[::-1]],
                  "neu":[neutral[j][0] for j in np.argsort([i[1] for i in neutral])[::-1]],
                  "mixed":[mixed[j][0] for j in np.argsort([i[1] for i in mixed])[::-1]]
                 }
        return output

# %%
import pandas as pd
df = pd.read_csv("ExampleTexts/videoExamples.csv")
examples = list(df.captions)

# %%
se = StatementExtracter()

# %%
output = se.is_statements(examples[5])

# %%
output
# Out:
# {'pos': ['This is the best camera I have ever seen on a phone',
#   'The video from the rear cameras is really good',
#   'it is really impressive',
#   'it is a great phone',
#   'which is very nice',
#   "it is a huge and obvious improvement when you 're watching HDR movies",
#   "the cameras on the iPhone 11 are so improved that I think they are worth the year - over - year upgrade from last year 's models for the first time in a long time",
#   'it is really nice',
#   'all these comparisons are great',
#   'That is a huge improvement over my XS Max',
#   'it is honestly just impressive',
#   'this is the best kind of iterative update',
#   'The iPhone 11 cameras are an enormous improvement over the XS',
#   'the video on the 11 Pro is the best I have seen on a smartphone to date',
#   'It is a lot better than the XS was last year',
#   "they are worth the year - over - year upgrade from last year 's models for the first time in a long time",
#   'the rear glass is now stronger and it comes in this frosted matte finish',
#   'Face ID is a little bit faster and works at more angles',
#   "Siri 's voice is slightly smoother",
#   'anything is better than the slow 5W brick it is been including for years',
#   'anything that is great',
#   'They are basically just nice updates to the iPhone XS',
#   'it is a little better to my eye than the Pixel 3',
#   'while the 11 is a definite improvement',
#   'the iPhone is not bad',
#   'The big upgrades to the screen are around brightness and power efficiency',
#   'The iPhone 11 is way sharper',
#   "which is a testament to how powerful Apple 's A13 processor really is",
#   'Smart HDR is also less aggressive in flattening the photos',
#   'the 11 is just a much sharper photo with more detail',
#   'the biggest new feature in iOS 13 is Dark Mode',
#   'Reminders is a much better app',
#   'Pro is a new OLED that Apple is calling the Super Retina XDR display',
#   'it is iPhone time'],
#  'neg': ['there is no image stabilization',
#   'It is not intuitive and it is just time - consuming',
#   'it is not particularly dramatic',
#   'It is hard to capture this on video',
#   'which is a little silly for stereo speakers',
#   'it is a waste of time to argue about names',
#   'There are better photo editing tools and you',
#   'no camera is good enough to make you switch',
#   'it is not like the A12 Bionic in the iPhone XS is slow',
#   'It is a little heavier and thicker',
#   'it is surprisingly hard to check that number',
#   'which is basically just long pressing on things with haptic feedback',
#   "this video is not in 4 K if you 're watching on an iPhone",
#   'the A12 Bionic in the iPhone XS is slow',
#   "the bump is a single piece of glass that 's milled out",
#   'that the only hard numbers Apple publishes are like hours of video playback',
#   'Pro Max is a bad name',
#   'it is just a lot brighter and punchier on the 11 Pro display compared to the XS',
#   'some things are actually a little easier to figure out',
#   "if the trade - off is that there 's more room inside the case for a bigger battery",
#   'this photo is really blue',
#   'it is also a little simpler',
#   'it is just time - consuming',
#   'the camera bump is matte',
#   'which is basically twice as wide as the main lens and f/2.4',
#   'this is a lot of tiny little updates',
#   'the iPhone 11 Pro is a little bit smaller than the iPhone 11',
#   'it is a pretty tough choice this year',
#   'Those bezels are still pretty big',
#   'it is really hard to test those claims',
#   'there are places where the iPhone 11 did not win in our tests',
#   'which is not how anyone uses a phone'],
#  'neu': ['There are three cameras on the iPhone 11',
#   'this is the Pro review',
#   'iOS 13.1 is already in beta and scheduled for wide release by the end of this month',
#   'The iPhone 11 is the reverse',
#   'they are both on the channel',
#   'This is all basically the same as the iPhone XS and the Pixel 3',
#   'the f/2.2 front camera is now 12 megapixels',
#   'it is there',
#   'chances are you',
#   'the iPhone 11 is the phone most people in the iOS ecosystem',
#   'It is a lot of little things that add up into a big update',
#   'It is basically a surround decoder',
#   'it is time to upgrade',
#   "This improvement is due to something Apple 's calling semantic rendering",
#   'Apple is not afraid of underexposing the blacks',
#   'The improvements to Smart HDR are applicable across cameras',
#   'Apple are still in a fight over video codecs',
#   'The entire lineup is still pretty big',
#   "This is the third year of the basic iPhone X design and Apple 's competitors have not been sitting still in trying to beat it",
#   "Apple 's USB - C charger is not the smallest or prettiest charger out there"],
#  'mixed': ['The color is punchy and pretty saturated and in perfect lighting']}

# %%
se.visualize_POS(examples[0])
# Out:
#  /SPACE/_SP <---- [/PUNCT/-LRB-
# [/PUNCT/-LRB- <--punct-- Music/NOUN/NN
# Music/NOUN/NN <--ROOT-- Music/NOUN/NN
# ]/PUNCT/-RRB- <--punct-- Music/NOUN/NN
# hey/INTJ/UH <--ROOT-- hey/INTJ/UH
# ./PUNCT/. <--punct-- hey/INTJ/UH
# what/PRON/WP <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--csubj-- is/AUX/VBZ
# up/ADV/RB <--prep-- is/AUX/VBZ
# guys/NOUN/NNS <--compound-- mkbhd/NOUN/NNS
# mkbhd/NOUN/NNS <--nsubj-- is/AUX/VBZ
# here/ADV/RB <--advmod-- mkbhd/NOUN/NNS
# this/DET/DT <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--ROOT-- is/AUX/VBZ
# the/DET/DT <--det-- pixel/NOUN/NN
# pixel/NOUN/NN <--attr-- is/AUX/VBZ
# for/ADP/IN <--prep-- pixel/NOUN/NN
# excel/PROPN/NNP <--pobj-- for/ADP/IN
# ./PUNCT/. <--punct-- is/AUX/VBZ
# this/DET/DT <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--ROOT-- is/AUX/VBZ
# one/NUM/CD <--attr-- is/AUX/VBZ
# of/ADP/IN <--prep-- one/NUM/CD
# the/DET/DT <--det-- phones/NOUN/NNS
# phones/NOUN/NNS <--pobj-- of/ADP/IN
# I/PRON/PRP <--nsubj-- looking/VERB/VBG
# was/AUX/VBD <--aux-- looking/VERB/VBG
# looking/VERB/VBG <--relcl-- phones/NOUN/NNS
# forward/ADV/RB <--advmod-- looking/VERB/VBG
# to/ADP/IN <--prep-- looking/VERB/VBG
# the/DET/DT <--det-- year/NOUN/NN
# most/ADV/RBS <--amod-- year/NOUN/NN
# this/DET/DT <--det-- year/NOUN/NN
# entire/ADJ/JJ <--amod-- year/NOUN/NN
# year/NOUN/NN <--pobj-- to/ADP/IN
# for/ADP/IN <--prep-- year/NOUN/NN
# 2019/NUM/CD <--pobj-- for/ADP/IN
# for/ADP/IN <--prep-- looking/VERB/VBG
# a/DET/DT <--det-- couple/NOUN/NN
# couple/NOUN/NN <--pobj-- for/ADP/IN
# of/ADP/IN <--prep-- couple/NOUN/NN
# reasons/NOUN/NNS <--pobj-- of/ADP/IN
# ./PUNCT/. <--punct-- is/AUX/VBZ
# and/CCONJ/CC <--cc-- using/VERB/VBG
# so/ADV/RB <--advmod-- using/VERB/VBG
# now/ADV/RB <--advmod-- using/VERB/VBG
# I/PRON/PRP <--nsubj-- using/VERB/VBG
# have/AUX/VBP <--aux-- using/VERB/VBG
# been/AUX/VBN <--aux-- using/VERB/VBG
# using/VERB/VBG <--ROOT-- using/VERB/VBG
# it/PRON/PRP <--dobj-- using/VERB/VBG
# daily/ADV/RB <--advmod-- using/VERB/VBG
# since/SCONJ/IN <--prep-- using/VERB/VBG
# its/PRON/PRP$ <--poss-- unveiling/NOUN/NN
# unveiling/NOUN/NN <--pobj-- since/SCONJ/IN
# ./PUNCT/. <--punct-- using/VERB/VBG
# this/DET/DT <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--ROOT-- is/AUX/VBZ
# my/PRON/PRP$ <--poss-- review/NOUN/NN
# honest/ADJ/JJ <--amod-- review/NOUN/NN
# review/NOUN/NN <--attr-- is/AUX/VBZ
# ./PUNCT/. <--punct-- is/AUX/VBZ
# so/ADV/RB <--advmod-- let/VERB/VB
# let/VERB/VB <--ROOT-- let/VERB/VB
# 's/PRON/PRP <--nsubj-- start/VERB/VB
# just/ADV/RB <--advmod-- start/VERB/VB
# start/VERB/VB <--ccomp-- let/VERB/VB
# with/ADP/IN <--prep-- start/VERB/VB
# the/DET/DT <--det-- wait/NOUN/NN
# wait/NOUN/NN <--pobj-- with/ADP/IN
# ./PUNCT/. <--punct-- let/VERB/VB
# looks/VERB/VBZ <--ROOT-- looks/VERB/VBZ
# I/PRON/PRP <--nsubj-- think/VERB/VBP
# honestly/ADV/RB <--advmod-- think/VERB/VBP
# think/VERB/VBP <--ccomp-- looks/VERB/VBZ
# it/PRON/PRP <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--ccomp-- think/VERB/VBP
# a/DET/DT <--det-- phone/NOUN/NN
# pretty/ADV/RB <--advmod-- decent/ADJ/JJ
# decent/ADJ/JJ <--amod-- phone/NOUN/NN
# looking/VERB/VBG <--amod-- phone/NOUN/NN
# phone/NOUN/NN <--attr-- is/AUX/VBZ
# ./PUNCT/. <--punct-- looks/VERB/VBZ
# it/PRON/PRP <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--ROOT-- is/AUX/VBZ
# low/ADJ/JJ <--amod-- key/NOUN/NN
# -/PUNCT/HYPH <--punct-- key/NOUN/NN
# key/NOUN/NN <--acomp-- is/AUX/VBZ
# really/ADV/RB <--advmod-- clean/ADJ/JJ
# clean/ADJ/JJ <--acomp-- is/AUX/VBZ
# ./PUNCT/. <--punct-- is/AUX/VBZ
# there/PRON/EX <--expl-- 's/AUX/VBZ
# 's/AUX/VBZ <--ROOT-- 's/AUX/VBZ
# almost/ADV/RB <--advmod-- no/DET/DT
# no/DET/DT <--nummod-- markings/NOUN/NNS
# markings/NOUN/NNS <--attr-- 's/AUX/VBZ
# along/ADP/IN <--prep-- markings/NOUN/NNS
# the/DET/DT <--det-- back/NOUN/NN
# back/NOUN/NN <--pobj-- along/ADP/IN
# ./PUNCT/. <--punct-- 's/AUX/VBZ
# just/ADV/RB <--advmod-- G/PROPN/NNP
# the/DET/DT <--det-- G/PROPN/NNP
# Google/PROPN/NNP <--compound-- G/PROPN/NNP
# G/PROPN/NNP <--nsubj-- rails/NOUN/NNS
# at/ADP/IN <--prep-- G/PROPN/NNP
# the/DET/DT <--det-- aluminum/NOUN/NN
# bottom/ADJ/JJ <--amod-- aluminum/NOUN/NN
# matte/ADJ/JJ <--nmod-- aluminum/NOUN/NN
# black/ADJ/JJ <--amod-- aluminum/NOUN/NN
# aluminum/NOUN/NN <--pobj-- at/ADP/IN
# rails/NOUN/NNS <--nsubj-- is/AUX/VBZ
# as/SCONJ/IN <--prep-- rails/NOUN/NNS
# part/NOUN/NN <--pobj-- as/SCONJ/IN
# of/ADP/IN <--prep-- part/NOUN/NN
# the/DET/DT <--det-- design/NOUN/NN
# design/NOUN/NN <--pobj-- of/ADP/IN
# all/DET/PDT <--predet-- way/NOUN/NN
# the/DET/DT <--det-- way/NOUN/NN
# way/NOUN/NN <--npadvmod-- around/ADP/IN
# around/ADP/IN <--prep-- rails/NOUN/NNS
# the/DET/DT <--det-- slots/NOUN/NNS
# phone/NOUN/NN <--compound-- speaker/NOUN/NN
# speaker/NOUN/NN <--compound-- slots/NOUN/NNS
# slots/NOUN/NNS <--pobj-- around/ADP/IN
# at/ADP/IN <--prep-- slots/NOUN/NNS
# the/DET/DT <--det-- bottom/NOUN/NN
# bottom/NOUN/NN <--pobj-- at/ADP/IN
# lined/VERB/VBN <--advcl-- rails/NOUN/NNS
# up/ADP/RP <--prt-- lined/VERB/VBN
# with/ADP/IN <--prep-- lined/VERB/VBN
# the/DET/DT <--det-- port/NOUN/NN
# USB/NOUN/NN <--compound-- port/NOUN/NN
# type/NOUN/NN <--compound-- c/NOUN/NN
# -/PUNCT/HYPH <--punct-- c/NOUN/NN
# c/NOUN/NN <--compound-- port/NOUN/NN
# port/NOUN/NN <--pobj-- with/ADP/IN
# and/CCONJ/CC <--cc-- port/NOUN/NN
# the/DET/DT <--det-- button/NOUN/NN
# colored/ADJ/JJ <--amod-- button/NOUN/NN
# power/NOUN/NN <--compound-- button/NOUN/NN
# button/NOUN/NN <--conj-- port/NOUN/NN
# of/ADP/IN <--prep-- on/ADP/IN
# course/NOUN/NN <--pobj-- of/ADP/IN
# on/ADP/IN <--prep-- rails/NOUN/NNS
# every/DET/DT <--det-- version/NOUN/NN
# version/NOUN/NN <--pobj-- on/ADP/IN
# and/CCONJ/CC <--cc-- version/NOUN/NN
# the/DET/DT <--det-- whole/ADJ/JJ
# whole/ADJ/JJ <--conj-- version/NOUN/NN
# back/NOUN/NN <--advmod-- version/NOUN/NN
# of/ADP/IN <--prep-- back/NOUN/NN
# the/DET/DT <--det-- phone/NOUN/NN
# phone/NOUN/NN <--pobj-- of/ADP/IN
# on/ADP/IN <--prep-- version/NOUN/NN
# two/NUM/CD <--pobj-- on/ADP/IN
# of/ADP/IN <--prep-- two/NUM/CD
# the/DET/DT <--det-- colors/NOUN/NNS
# colors/NOUN/NNS <--pobj-- of/ADP/IN
# is/AUX/VBZ <--ROOT-- is/AUX/VBZ
# this/DET/DT <--det-- finish/NOUN/NN
# soft/ADJ/JJ <--amod-- touch/NOUN/NN
# touch/NOUN/NN <--compound-- finish/NOUN/NN
# matte/ADJ/JJ <--compound-- finish/NOUN/NN
# finish/NOUN/NN <--attr-- is/AUX/VBZ
# which/PRON/WDT <--nsubj-- does/AUX/VBZ
# does/AUX/VBZ <--relcl-- finish/NOUN/NN
# a/DET/DT <--det-- job/NOUN/NN
# great/ADJ/JJ <--amod-- job/NOUN/NN
# job/NOUN/NN <--dobj-- does/AUX/VBZ
# of/ADP/IN <--prep-- job/NOUN/NN
# not/PART/RB <--neg-- showing/VERB/VBG
# showing/VERB/VBG <--pcomp-- of/ADP/IN
# fingerprints/NOUN/NNS <--dobj-- showing/VERB/VBG
# it/PRON/PRP <--nsubj-- seem/VERB/VB
# does/AUX/VBZ <--aux-- seem/VERB/VB
# not/PART/RB <--neg-- seem/VERB/VB
# seem/VERB/VB <--relcl-- finish/NOUN/NN
# to/PART/TO <--aux-- scratch/VERB/VB
# scratch/VERB/VB <--xcomp-- seem/VERB/VB
# very/ADV/RB <--advmod-- easily/ADV/RB
# easily/ADV/RB <--advmod-- scratch/VERB/VB
# at/ADV/RB <--advmod-- all/ADV/RB
# all/ADV/RB <--advmod-- scratch/VERB/VB
# so/ADV/RB <--advmod-- scratch/VERB/VB
# of/ADP/IN <--prep-- so/ADV/RB
# the/DET/DT <--det-- colors/NOUN/NNS
# three/NUM/CD <--nummod-- colors/NOUN/NNS
# colors/NOUN/NNS <--pobj-- of/ADP/IN
# ./PUNCT/. <--punct-- is/AUX/VBZ
# available/ADJ/JJ <--ROOT-- available/ADJ/JJ
# I/PRON/PRP <--nsubj-- gon/VERB/VBG
# 'm/AUX/VBP <--aux-- gon/VERB/VBG
# gon/VERB/VBG <--ROOT-- gon/VERB/VBG
# na/PART/TO <--aux-- say/VERB/VB
# say/VERB/VB <--xcomp-- gon/VERB/VBG
# this/DET/DT <--nsubj-- white/ADJ/JJ
# white/ADJ/JJ <--ccomp-- say/VERB/VB
# ./PUNCT/. <--punct-- gon/VERB/VBG
# this/DET/DT <--det-- version/NOUN/NN
# Panda/PROPN/NNP <--compound-- version/NOUN/NN
# version/NOUN/NN <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--ROOT-- is/AUX/VBZ
# the/DET/DT <--det-- one/NUM/CD
# best/ADJ/JJS <--amod-- one/NUM/CD
# one/NUM/CD <--attr-- is/AUX/VBZ
# that/PRON/WDT <--dobj-- buttons/NOUN/NNS
# power/NOUN/NN <--compound-- buttons/NOUN/NNS
# buttons/NOUN/NNS <--nsubj-- sweet/ADJ/JJ
# pretty/ADV/RB <--advmod-- sweet/ADJ/JJ
# sweet/ADJ/JJ <--relcl-- one/NUM/CD
# ./PUNCT/. <--punct-- is/AUX/VBZ
# then/ADV/RB <--advmod-- gon/VERB/VBG
# I/PRON/PRP <--nsubj-- gon/VERB/VBG
# 'm/AUX/VBP <--aux-- gon/VERB/VBG
# gon/VERB/VBG <--ROOT-- gon/VERB/VBG
# na/PART/TO <--aux-- say/VERB/VB
# say/VERB/VB <--xcomp-- gon/VERB/VBG
# ./PUNCT/. <--punct-- gon/VERB/VBG
# oh/INTJ/UH <--intj-- is/AUX/VBZ
# so/ADV/RB <--advmod-- is/AUX/VBZ
# orange/PROPN/NNP <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--ROOT-- is/AUX/VBZ
# in/ADP/IN <--prep-- is/AUX/VBZ
# second/ADJ/JJ <--amod-- place/NOUN/NN
# place/NOUN/NN <--pobj-- in/ADP/IN
# ./PUNCT/. <--punct-- is/AUX/VBZ
# not/PART/RB <--neg-- so/ADV/RB
# so/ADV/RB <--advmod-- great/ADJ/JJ
# great/ADJ/JJ <--amod-- button/NOUN/NN
# power/NOUN/NN <--compound-- button/NOUN/NN
# button/NOUN/NN <--ROOT-- button/NOUN/NN
# ./PUNCT/. <--punct-- button/NOUN/NN
# but/CCONJ/CC <--cc-- is/AUX/VBZ
# at/ADP/IN <--advmod-- least/ADJ/JJS
# least/ADJ/JJS <--advmod-- is/AUX/VBZ
# it/PRON/PRP <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--ROOT-- is/AUX/VBZ
# matte/ADJ/JJ <--attr-- is/AUX/VBZ
# and/CCONJ/CC <--cc-- is/AUX/VBZ
# then/ADV/RB <--advmod-- is/AUX/VBZ
# that/DET/DT <--det-- version/NOUN/NN
# jet/NOUN/NN <--compound-- black/NOUN/NN
# -/PUNCT/HYPH <--punct-- black/NOUN/NN
# black/NOUN/NN <--amod-- version/NOUN/NN
# weirdly/ADV/RB <--advmod-- glossy/ADJ/JJ
# very/ADV/RB <--advmod-- glossy/ADJ/JJ
# glossy/ADJ/JJ <--amod-- version/NOUN/NN
# version/NOUN/NN <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--conj-- is/AUX/VBZ
# in/ADP/IN <--prep-- is/AUX/VBZ
# third/ADJ/JJ <--amod-- place/NOUN/NN
# place/NOUN/NN <--pobj-- in/ADP/IN
# fun/ADJ/JJ <--compound-- fact/NOUN/NN
# fact/NOUN/NN <--ROOT-- fact/NOUN/NN
# though/SCONJ/IN <--mark-- slap/VERB/VB
# since/SCONJ/IN <--mark-- are/AUX/VBP
# the/DET/DT <--det-- rails/NOUN/NNS
# rails/NOUN/NNS <--nsubj-- are/AUX/VBP
# are/AUX/VBP <--advcl-- slap/VERB/VB
# still/ADV/RB <--advmod-- are/AUX/VBP
# matte/ADJ/JJ <--amod-- black/ADJ/JJ
# black/ADJ/JJ <--acomp-- are/AUX/VBP
# you/PRON/PRP <--nsubj-- slap/VERB/VB
# can/AUX/MD <--aux-- slap/VERB/VB
# slap/VERB/VB <--advcl-- fact/NOUN/NN
# a/DET/DT <--det-- skin/NOUN/NN
# matte/ADJ/JJ <--nmod-- skin/NOUN/NN
# black/ADJ/JJ <--amod-- D/NOUN/NN
# D/NOUN/NN <--amod-- skin/NOUN/NN
# brand/NOUN/NN <--compound-- skin/NOUN/NN
# skin/NOUN/NN <--dobj-- slap/VERB/VB
# on/ADP/IN <--prep-- slap/VERB/VB
# the/DET/DT <--det-- back/NOUN/NN
# back/NOUN/NN <--pobj-- on/ADP/IN
# of/ADP/IN <--prep-- back/NOUN/NN
# any/DET/DT <--pobj-- of/ADP/IN
# of/ADP/IN <--prep-- any/DET/DT
# these/DET/DT <--det-- phones/NOUN/NNS
# phones/NOUN/NNS <--pobj-- of/ADP/IN
# and/CCONJ/CC <--cc-- slap/VERB/VB
# you/PRON/PRP <--nsubj-- created/VERB/VBD
# just/ADV/RB <--advmod-- created/VERB/VBD
# created/VERB/VBD <--conj-- slap/VERB/VB
# the/DET/DT <--det-- matte/ADJ/JJ
# matte/ADJ/JJ <--nmod-- everything/PRON/NN
# black/ADJ/JJ <--amod-- everything/PRON/NN
# everything/PRON/NN <--dobj-- created/VERB/VBD
# ./PUNCT/. <--punct-- fact/NOUN/NN
# phone/NOUN/NN <--compound-- Google/PROPN/NNP
# Google/PROPN/NNP <--nsubj-- made/VERB/VBN
# should/AUX/MD <--aux-- made/VERB/VBN
# have/AUX/VB <--aux-- made/VERB/VBN
# made/VERB/VBN <--ROOT-- made/VERB/VBN
# in/ADP/IN <--prep-- made/VERB/VBN
# the/DET/DT <--det-- place/NOUN/NN
# first/ADJ/JJ <--amod-- place/NOUN/NN
# place/NOUN/NN <--pobj-- in/ADP/IN
# so/ADV/RB <--advmod-- link/VERB/VB
# link/VERB/VB <--advcl-- made/VERB/VBN
# to/ADP/IN <--prep-- link/VERB/VB
# that/DET/DT <--pobj-- to/ADP/IN
# below/ADV/RB <--prep-- link/VERB/VB
# and/CCONJ/CC <--cc-- below/ADV/RB
# of/ADP/IN <--prep-- shout/VERB/VB
# course/NOUN/NN <--pobj-- of/ADP/IN
# shout/VERB/VB <--conj-- made/VERB/VBN
# out/ADP/RP <--prt-- shout/VERB/VB
# to/ADP/IN <--prep-- shout/VERB/VB
# D/NUM/CD <--amod-- brand/NOUN/NN
# brand/NOUN/NN <--pobj-- to/ADP/IN
# for/ADP/IN <--prep-- shout/VERB/VB
# sponsoring/VERB/VBG <--pcomp-- for/ADP/IN
# this/DET/DT <--det-- video/NOUN/NN
# video/NOUN/NN <--dobj-- sponsoring/VERB/VBG
# the/DET/DT <--det-- bump/NOUN/NN
# pixels/PROPN/NNP <--nmod-- bump/NOUN/NN
# square/ADJ/JJ <--amod-- bump/NOUN/NN
# camera/NOUN/NN <--compound-- bump/NOUN/NN
# bump/NOUN/NN <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--conj-- made/VERB/VBN
# again/ADV/RB <--advmod-- is/AUX/VBZ
# annoyingly/ADV/RB <--advmod-- is/AUX/VBZ
# a/DET/DT <--det-- bit/NOUN/NN
# little/ADJ/JJ <--amod-- bit/NOUN/NN
# bit/NOUN/NN <--npadvmod-- raised/VERB/VBN
# raised/VERB/VBN <--acomp-- is/AUX/VBZ
# ./PUNCT/. <--punct-- is/AUX/VBZ
# but/CCONJ/CC <--cc-- find/VERB/VB
# I/PRON/PRP <--nsubj-- find/VERB/VB
# do/AUX/VBP <--aux-- find/VERB/VB
# not/PART/RB <--neg-- find/VERB/VB
# find/VERB/VB <--ROOT-- find/VERB/VB
# this/DET/DT <--dobj-- find/VERB/VB
# as/ADV/RB <--advmod-- drastic/ADJ/JJ
# drastic/ADJ/JJ <--advmod-- find/VERB/VB
# as/SCONJ/IN <--mark-- say/VERB/VBP
# say/VERB/VBP <--advcl-- drastic/ADJ/JJ
# Apple/PROPN/NNP <--poss-- bump/NOUN/NN
# 's/PART/POS <--case-- Apple/PROPN/NNP
# larger/ADV/RBR <--amod-- bump/NOUN/NN
# double/ADV/RB <--advmod-- raised/VERB/VBN
# raised/VERB/VBN <--amod-- bump/NOUN/NN
# triple/ADJ/JJ <--amod-- bump/NOUN/NN
# camera/NOUN/NN <--compound-- bump/NOUN/NN
# bump/NOUN/NN <--nsubj-- say/VERB/VBP
# but/CCONJ/CC <--cc-- say/VERB/VBP
# more/ADV/RBR <--conj-- say/VERB/VBP
# on/ADP/IN <--prep-- more/ADV/RBR
# the/DET/DT <--det-- cameras/NOUN/NNS
# cameras/NOUN/NNS <--pobj-- on/ADP/IN
# ./PUNCT/. <--punct-- find/VERB/VB
# later/ADV/RBR <--advmod-- so/ADV/RB
# so/ADV/RB <--advmod-- yeah/INTJ/UH
# yeah/INTJ/UH <--ROOT-- yeah/INTJ/UH
# ./PUNCT/. <--punct-- yeah/INTJ/UH
# you/PRON/PRP <--nsubj-- know/VERB/VBP
# know/VERB/VBP <--ROOT-- know/VERB/VBP
# what/PRON/WP <--dobj-- grown/VERB/VBN
# generally/ADV/RB <--advmod-- grown/VERB/VBN
# it/PRON/PRP <--nsubjpass-- grown/VERB/VBN
# is/AUX/VBZ <--auxpass-- grown/VERB/VBN
# grown/VERB/VBN <--ccomp-- know/VERB/VBP
# on/ADP/IN <--prep-- grown/VERB/VBN
# me/PRON/PRP <--pobj-- on/ADP/IN
# pretty/ADV/RB <--advmod-- decent/ADJ/JJ
# decent/ADJ/JJ <--amod-- phone/NOUN/NN
# looking/VERB/VBG <--amod-- phone/NOUN/NN
# phone/NOUN/NN <--npadvmod-- grown/VERB/VBN
# ./PUNCT/. <--punct-- know/VERB/VBP
# I/PRON/PRP <--nsubj-- was/AUX/VBD
# was/AUX/VBD <--ROOT-- was/AUX/VBD
# though/ADV/RB <--advmod-- let/VERB/VB
# let/VERB/VB <--advcl-- was/AUX/VBD
# a/DET/DT <--det-- bit/NOUN/NN
# little/ADJ/JJ <--amod-- bit/NOUN/NN
# bit/NOUN/NN <--npadvmod-- down/ADP/RP
# down/ADP/RP <--advmod-- let/VERB/VB
# by/ADP/IN <--prep-- let/VERB/VB
# the/DET/DT <--det-- buttons/NOUN/NNS
# not/PART/RB <--neg-- buttons/NOUN/NNS
# super/ADJ/JJ <--advmod-- clicky/ADJ/JJ
# clicky/ADJ/JJ <--amod-- buttons/NOUN/NNS
# buttons/NOUN/NNS <--pobj-- by/ADP/IN
# just/ADV/RB <--advmod-- ones/NOUN/NNS
# the/DET/DT <--det-- ones/NOUN/NNS
# volume/NOUN/NN <--compound-- ones/NOUN/NNS
# ones/NOUN/NNS <--ccomp-- let/VERB/VB
# mainly/ADV/RB <--advmod-- something/PRON/NN
# but/CCONJ/CC <--cc-- mainly/ADV/RB
# on/ADP/IN <--prep-- something/PRON/NN
# the/DET/DT <--det-- hand/NOUN/NN
# other/ADJ/JJ <--amod-- hand/NOUN/NN
# hand/NOUN/NN <--pobj-- on/ADP/IN
# something/PRON/NN <--advcl-- let/VERB/VB
# a/DET/DT <--det-- lot/NOUN/NN
# lot/NOUN/NN <--nsubj-- missed/VERB/VBN
# of/ADP/IN <--prep-- lot/NOUN/NN
# people/NOUN/NNS <--pobj-- of/ADP/IN
# have/AUX/VBP <--aux-- missed/VERB/VBN
# missed/VERB/VBN <--relcl-- something/PRON/NN
# ./PUNCT/. <--punct-- was/AUX/VBD
# that/DET/DT <--nsubj-- 's/AUX/VBZ
# 's/AUX/VBZ <--ROOT-- 's/AUX/VBZ
# good/ADJ/JJ <--acomp-- 's/AUX/VBZ
# to/PART/TO <--aux-- know/VERB/VB
# know/VERB/VB <--xcomp-- 's/AUX/VBZ
# the/DET/DT <--det-- phone/NOUN/NN
# phone/NOUN/NN <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--ccomp-- know/VERB/VB
# now/ADV/RB <--advmod-- is/AUX/VBZ
# ip68/PROPN/NNP <--compound-- resistant/ADJ/JJ
# water/NOUN/NN <--npadvmod-- resistant/ADJ/JJ
# -/PUNCT/HYPH <--punct-- resistant/ADJ/JJ
# resistant/ADJ/JJ <--acomp-- is/AUX/VBZ
# it/PRON/PRP <--nsubj-- has/AUX/VBZ
# still/ADV/RB <--advmod-- has/AUX/VBZ
# has/AUX/VBZ <--ccomp-- resistant/ADJ/JJ
# the/DET/DT <--det-- sensitivity/NOUN/NN
# squeeze/NOUN/NN <--compound-- sensitivity/NOUN/NN
# sensitivity/NOUN/NN <--dobj-- has/AUX/VBZ
# for/ADP/IN <--prep-- sensitivity/NOUN/NN
# the/DET/DT <--det-- assistant/NOUN/NN
# assistant/NOUN/NN <--pobj-- for/ADP/IN
# and/CCONJ/CC <--cc-- is/AUX/VBZ
# ./PUNCT/. <--punct-- 's/AUX/VBZ
# it/PRON/PRP <--nsubj-- has/AUX/VBZ
# still/ADV/RB <--advmod-- has/AUX/VBZ
# has/AUX/VBZ <--ROOT-- has/AUX/VBZ
# stereo/ADJ/JJ <--compound-- speakers/NOUN/NNS
# speakers/NOUN/NNS <--dobj-- has/AUX/VBZ
# ./PUNCT/. <--punct-- has/AUX/VBZ
# so/ADV/RB <--advmod-- are/AUX/VBP
# they/PRON/PRP <--nsubj-- are/AUX/VBP
# are/AUX/VBP <--ROOT-- are/AUX/VBP
# not/PART/RB <--neg-- are/AUX/VBP
# front/ADJ/JJ <--advmod-- facing/VERB/VBG
# -/PUNCT/HYPH <--punct-- facing/VERB/VBG
# facing/VERB/VBG <--amod-- pair/NOUN/NN
# pair/NOUN/NN <--attr-- are/AUX/VBP
# ./PUNCT/. <--punct-- are/AUX/VBP
# like/INTJ/UH <--intj-- were/AUX/VBD
# they/PRON/PRP <--nsubj-- were/AUX/VBD
# were/AUX/VBD <--ROOT-- were/AUX/VBD
# last/ADJ/JJ <--amod-- year/NOUN/NN
# year/NOUN/NN <--npadvmod-- were/AUX/VBD
# ./PUNCT/. <--punct-- were/AUX/VBD
# but/CCONJ/CC <--cc-- are/AUX/VBP
# they/PRON/PRP <--nsubj-- are/AUX/VBP
# are/AUX/VBP <--ROOT-- are/AUX/VBP
# still/ADV/RB <--advmod-- are/AUX/VBP
# a/DET/DT <--det-- pair/NOUN/NN
# good/ADJ/JJ <--amod-- sounding/VERB/VBG
# sounding/VERB/VBG <--amod-- pair/NOUN/NN
# solid/ADJ/JJ <--amod-- pair/NOUN/NN
# pair/NOUN/NN <--attr-- are/AUX/VBP
# with/ADP/IN <--prep-- pair/NOUN/NN
# the/DET/DT <--det-- slots/NOUN/NNS
# slots/NOUN/NNS <--pobj-- with/ADP/IN
# at/ADP/IN <--prep-- slots/NOUN/NNS
# the/DET/DT <--det-- bottom/NOUN/NN
# bottom/NOUN/NN <--pobj-- at/ADP/IN
# and/CCONJ/CC <--cc-- bottom/NOUN/NN
# the/DET/DT <--det-- speaker/NOUN/NN
# earpiece/NOUN/NN <--compound-- speaker/NOUN/NN
# speaker/NOUN/NN <--nsubj-- combined/VERB/VBD
# combined/VERB/VBD <--relcl-- pair/NOUN/NN
# the/DET/DT <--det-- part/NOUN/NN
# worst/ADJ/JJS <--amod-- part/NOUN/NN
# part/NOUN/NN <--dobj-- combined/VERB/VBD
# about/ADP/IN <--prep-- part/NOUN/NN
# the/DET/DT <--det-- way/NOUN/NN
# way/NOUN/NN <--pobj-- about/ADP/IN
# this/DET/DT <--det-- phone/NOUN/NN
# phone/NOUN/NN <--nsubj-- looks/VERB/VBZ
# looks/VERB/VBZ <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--relcl-- way/NOUN/NN
# the/DET/DT <--det-- front/NOUN/NN
# front/NOUN/NN <--attr-- is/AUX/VBZ
# the/DET/DT <--det-- part/NOUN/NN
# part/NOUN/NN <--attr-- is/AUX/VBZ
# you/PRON/PRP <--nsubj-- look/VERB/VBP
# look/VERB/VBP <--relcl-- part/NOUN/NN
# at/ADP/IN <--prep-- look/VERB/VBP
# most/ADJ/JJS <--pobj-- at/ADP/IN
# of/ADP/IN <--prep-- most/ADJ/JJS
# the/DET/DT <--det-- time/NOUN/NN
# time/NOUN/NN <--pobj-- of/ADP/IN
# I/PRON/PRP <--nsubj-- 'm/AUX/VBP
# 'm/AUX/VBP <--relcl-- time/NOUN/NN
# not/PART/RB <--neg-- 'm/AUX/VBP
# a/DET/DT <--det-- fan/NOUN/NN
# fan/NOUN/NN <--attr-- 'm/AUX/VBP
# of/ADP/IN <--prep-- fan/NOUN/NN
# the/DET/DT <--det-- forehead/NOUN/NN
# forehead/NOUN/NN <--pobj-- of/ADP/IN
# it/PRON/PRP <--nsubj-- has/AUX/VBZ
# has/AUX/VBZ <--relcl-- part/NOUN/NN
# a/DET/DT <--det-- chin/NOUN/NN
# smaller/ADJ/JJR <--amod-- chin/NOUN/NN
# chin/NOUN/NN <--dobj-- has/AUX/VBZ
# at/ADP/IN <--prep-- chin/NOUN/NN
# the/DET/DT <--det-- bottom/NOUN/NN
# bottom/NOUN/NN <--pobj-- at/ADP/IN
# than/SCONJ/IN <--prep-- part/NOUN/NN
# before/ADV/RB <--pcomp-- than/SCONJ/IN
# ./PUNCT/. <--punct-- are/AUX/VBP
# but/CCONJ/CC <--cc-- yeah/INTJ/UH
# yeah/INTJ/UH <--ROOT-- yeah/INTJ/UH
# ./PUNCT/. <--punct-- yeah/INTJ/UH
# that/DET/DT <--det-- forehead/NOUN/NN
# big/ADJ/JJ <--amod-- forehead/NOUN/NN
# forehead/NOUN/NN <--ROOT-- forehead/NOUN/NN
# ./PUNCT/. <--punct-- forehead/NOUN/NN
# I/PRON/PRP <--nsubj-- like/VERB/VB
# do/AUX/VBP <--aux-- like/VERB/VB
# not/PART/RB <--neg-- like/VERB/VB
# like/VERB/VB <--ROOT-- like/VERB/VB
# it/PRON/PRP <--dobj-- like/VERB/VB
# ./PUNCT/. <--punct-- like/VERB/VB
# I/PRON/PRP <--nsubj-- 'm/AUX/VBP
# 'm/AUX/VBP <--ROOT-- 'm/AUX/VBP
# still/ADV/RB <--advmod-- 'm/AUX/VBP
# kind/ADV/RB <--advmod-- of/ADV/RB
# of/ADV/RB <--advmod-- used/VERB/VBN
# barely/ADV/RB <--advmod-- used/VERB/VBN
# getting/VERB/VBG <--auxpass-- used/VERB/VBN
# used/VERB/VBN <--acomp-- 'm/AUX/VBP
# to/ADP/IN <--prep-- used/VERB/VBN
# it/PRON/PRP <--pobj-- to/ADP/IN
# and/CCONJ/CC <--cc-- to/ADP/IN
# overall/ADV/RB <--conj-- to/ADP/IN
# ./PUNCT/. <--punct-- 'm/AUX/VBP
# the/DET/DT <--det-- reason/NOUN/NN
# reason/NOUN/NN <--nsubj-- have/AUX/VB
# for/ADP/IN <--prep-- reason/NOUN/NN
# the/DET/DT <--det-- forehead/NOUN/NN
# forehead/NOUN/NN <--pobj-- for/ADP/IN
# does/AUX/VBZ <--aux-- have/AUX/VB
# not/PART/RB <--neg-- have/AUX/VB
# really/ADV/RB <--advmod-- have/AUX/VB
# have/AUX/VB <--ROOT-- have/AUX/VB
# me/PRON/PRP <--nsubj-- convinced/VERB/VBN
# convinced/VERB/VBN <--ccomp-- have/AUX/VB
# so/ADV/RB <--mark-- 's/AUX/VBZ
# there/PRON/EX <--expl-- 's/AUX/VBZ
# 's/AUX/VBZ <--advcl-- convinced/VERB/VBN
# a/DET/DT <--det-- cluster/NOUN/NN
# cluster/NOUN/NN <--attr-- 's/AUX/VBZ
# of/ADP/IN <--prep-- cluster/NOUN/NN
# new/ADJ/JJ <--amod-- sensors/NOUN/NNS
# sensors/NOUN/NNS <--pobj-- of/ADP/IN
# up/ADV/RB <--advmod-- here/ADV/RB
# here/ADV/RB <--advmod-- 's/AUX/VBZ
# in/ADP/IN <--prep-- here/ADV/RB
# the/DET/DT <--det-- top/NOUN/NN
# top/NOUN/NN <--pobj-- in/ADP/IN
# including/VERB/VBG <--prep-- top/NOUN/NN
# the/DET/DT <--det-- camera/NOUN/NN
# selfie/ADJ/JJ <--compound-- camera/NOUN/NN
# camera/NOUN/NN <--pobj-- including/VERB/VBG
# then/ADV/RB <--advmod-- infrared/VERB/VBD
# also/ADV/RB <--advmod-- infrared/VERB/VBD
# infrared/VERB/VBD <--conj-- have/AUX/VB
# projector/NOUN/NN <--compound-- receiver/NOUN/NN
# receiver/NOUN/NN <--dobj-- infrared/VERB/VBD
# and/CCONJ/CC <--cc-- receiver/NOUN/NN
# radar/NOUN/NN <--conj-- receiver/NOUN/NN
# which/PRON/WDT <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--relcl-- receiver/NOUN/NN
# new/ADJ/JJ <--acomp-- is/AUX/VBZ
# in/ADP/IN <--prep-- is/AUX/VBZ
# any/DET/DT <--det-- smartphone/NOUN/NN
# smartphone/NOUN/NN <--pobj-- in/ADP/IN
# and/CCONJ/CC <--cc-- receiver/NOUN/NN
# this/DET/DT <--det-- suite/NOUN/NN
# new/ADJ/JJ <--amod-- sensor/NOUN/NN
# sensor/NOUN/NN <--compound-- suite/NOUN/NN
# suite/NOUN/NN <--conj-- receiver/NOUN/NN
# up/ADV/RB <--advmod-- here/ADV/RB
# here/ADV/RB <--advmod-- suite/NOUN/NN
# is/AUX/VBZ <--conj-- infrared/VERB/VBD
# good/ADJ/JJ <--acomp-- is/AUX/VBZ
# for/ADP/IN <--prep-- good/ADJ/JJ
# two/NUM/CD <--nummod-- things/NOUN/NNS
# things/NOUN/NNS <--pobj-- for/ADP/IN
# the/DET/DT <--det-- unlock/NOUN/NN
# fastest/ADJ/JJS <--amod-- unlock/NOUN/NN
# face/NOUN/NN <--compound-- unlock/NOUN/NN
# unlock/NOUN/NN <--dobj-- infrared/VERB/VBD
# in/ADP/IN <--prep-- unlock/NOUN/NN
# any/DET/DT <--det-- smartphone/NOUN/NN
# smartphone/NOUN/NN <--pobj-- in/ADP/IN
# and/CCONJ/CC <--cc-- smartphone/NOUN/NN
# some/DET/DT <--det-- gestures/NOUN/NNS
# gestures/NOUN/NNS <--conj-- smartphone/NOUN/NN
# ./PUNCT/. <--punct-- have/AUX/VB
# okay/INTJ/UH <--intj-- makes/VERB/VBZ
# maybe/ADV/RB <--advmod-- makes/VERB/VBZ
# it/PRON/PRP <--nsubj-- makes/VERB/VBZ
# makes/VERB/VBZ <--ROOT-- makes/VERB/VBZ
# me/PRON/PRP <--nsubj-- little/ADJ/JJ
# a/DET/DT <--det-- little/ADJ/JJ
# little/ADJ/JJ <--nsubj-- thinking/NOUN/NN
# not/PART/RB <--neg-- thinking/NOUN/NN
# forward/ADV/RB <--advmod-- thinking/NOUN/NN
# -/PUNCT/HYPH <--punct-- thinking/NOUN/NN
# thinking/NOUN/NN <--ccomp-- makes/VERB/VBZ
# ./PUNCT/. <--punct-- makes/VERB/VBZ
# but/CCONJ/CC <--cc-- like/SCONJ/IN
# I/PRON/PRP <--nsubj-- like/SCONJ/IN
# still/ADV/RB <--advmod-- like/SCONJ/IN
# like/SCONJ/IN <--ROOT-- like/SCONJ/IN
# fingerprint/NOUN/NN <--compound-- sensors/NOUN/NNS
# sensors/NOUN/NNS <--pobj-- like/SCONJ/IN
# and/CCONJ/CC <--cc-- sensors/NOUN/NNS
# this/DET/DT <--det-- phone/NOUN/NN
# phone/NOUN/NN <--conj-- sensors/NOUN/NNS
# ./PUNCT/. <--punct-- like/SCONJ/IN
# has/AUX/VBZ <--ROOT-- has/AUX/VBZ
# none/NOUN/NN <--dobj-- has/AUX/VBZ
# of/ADP/IN <--prep-- none/NOUN/NN
# that/SCONJ/IN <--pobj-- of/ADP/IN
# the/DET/DT <--det-- unlock/NOUN/NN
# face/NOUN/NN <--compound-- unlock/NOUN/NN
# unlock/NOUN/NN <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--ccomp-- has/AUX/VBZ
# the/DET/DT <--det-- unlock/NOUN/NN
# only/ADJ/JJ <--amod-- unlock/NOUN/NN
# biometric/ADJ/JJ <--amod-- unlock/NOUN/NN
# unlock/NOUN/NN <--attr-- is/AUX/VBZ
# ./PUNCT/. <--punct-- is/AUX/VBZ
# this/DET/DT <--det-- phone/NOUN/NN
# phone/NOUN/NN <--nsubj-- has/AUX/VBZ
# has/AUX/VBZ <--ROOT-- has/AUX/VBZ
# ./PUNCT/. <--punct-- has/AUX/VBZ
# and/CCONJ/CC <--cc-- find/VERB/VBP
# I/PRON/PRP <--nsubj-- find/VERB/VBP
# find/VERB/VBP <--ROOT-- find/VERB/VBP
# myself/PRON/PRP <--nsubj-- missing/VERB/VBG
# missing/VERB/VBG <--ccomp-- find/VERB/VBP
# a/DET/DT <--det-- sensor/NOUN/NN
# fingerprint/NOUN/NN <--compound-- sensor/NOUN/NN
# sensor/NOUN/NN <--dobj-- missing/VERB/VBG
# and/CCONJ/CC <--cc-- sensor/NOUN/NN
# the/DET/DT <--det-- rate/NOUN/NN
# rate/NOUN/NN <--conj-- sensor/NOUN/NN
# of/ADP/IN <--prep-- rate/NOUN/NN
# improvement/NOUN/NN <--pobj-- of/ADP/IN
# for/ADP/IN <--prep-- rate/NOUN/NN
# fingerprint/NOUN/NN <--compound-- sensors/NOUN/NNS
# sensors/NOUN/NNS <--pobj-- for/ADP/IN
# under/ADP/IN <--prep-- rate/NOUN/NN
# the/DET/DT <--det-- glass/NOUN/NN
# glass/NOUN/NN <--pobj-- under/ADP/IN
# ./PUNCT/. <--punct-- find/VERB/VBP
# has/AUX/VBZ <--aux-- been/AUX/VBN
# been/AUX/VBN <--ROOT-- been/AUX/VBN
# pretty/ADV/RB <--advmod-- good/ADJ/JJ
# good/ADJ/JJ <--acomp-- been/AUX/VBN
# so/SCONJ/IN <--mark-- was/AUX/VBD
# that/DET/DT <--det-- move/NOUN/NN
# move/NOUN/NN <--nsubj-- was/AUX/VBD
# was/AUX/VBD <--advcl-- been/AUX/VBN
# not/PART/RB <--neg-- was/AUX/VBD
# my/PRON/PRP$ <--poss-- pixel/NOUN/NN
# favorite/ADJ/JJ <--amod-- pixel/NOUN/NN
# pixel/NOUN/NN <--nsubj-- want/VERB/VBP
# for/ADP/IN <--prep-- pixel/NOUN/NN
# uses/NOUN/NNS <--pcomp-- for/ADP/IN
# a/DET/DT <--det-- sensor/NOUN/NN
# radar/NOUN/NN <--compound-- sensor/NOUN/NN
# sensor/NOUN/NN <--dobj-- uses/NOUN/NNS
# to/PART/TO <--aux-- project/VERB/VB
# essentially/ADV/RB <--advmod-- project/VERB/VB
# project/VERB/VB <--xcomp-- uses/NOUN/NNS
# a/DET/DT <--det-- bubble/NOUN/NN
# little/ADJ/JJ <--amod-- bubble/NOUN/NN
# bubble/NOUN/NN <--dobj-- project/VERB/VB
# around/ADP/IN <--prep-- bubble/NOUN/NN
# the/DET/DT <--det-- phone/NOUN/NN
# phone/NOUN/NN <--pobj-- around/ADP/IN
# to/PART/TO <--aux-- see/VERB/VB
# see/VERB/VB <--advcl-- project/VERB/VB
# when/ADV/WRB <--advmod-- are/AUX/VBP
# things/NOUN/NNS <--nsubj-- are/AUX/VBP
# are/AUX/VBP <--ccomp-- see/VERB/VB
# near/SCONJ/IN <--prep-- are/AUX/VBP
# it/PRON/PRP <--pobj-- near/SCONJ/IN
# when/ADV/WRB <--advmod-- are/AUX/VBP
# things/NOUN/NNS <--nsubj-- are/AUX/VBP
# are/AUX/VBP <--advcl-- are/AUX/VBP
# in/ADP/IN <--prep-- are/AUX/VBP
# the/DET/DT <--det-- bubble/NOUN/NN
# bubble/NOUN/NN <--pobj-- in/ADP/IN
# want/VERB/VBP <--ccomp-- was/AUX/VBD
# to/PART/TO <--aux-- enter/VERB/VB
# enter/VERB/VB <--xcomp-- want/VERB/VBP
# ./PUNCT/. <--punct-- been/AUX/VBN
# it/PRON/PRP <--nsubj-- exit/VERB/VBP
# exit/VERB/VBP <--ROOT-- exit/VERB/VBP
# it/PRON/PRP <--dobj-- exit/VERB/VBP
# etc/X/FW <--dep-- exit/VERB/VBP
# ./PUNCT/. <--punct-- exit/VERB/VBP
# so/ADV/RB <--advmod-- enters/VERB/VBZ
# when/ADV/WRB <--advmod-- reach/VERB/VBP
# you/PRON/PRP <--nsubj-- reach/VERB/VBP
# reach/VERB/VBP <--advcl-- enters/VERB/VBZ
# for/ADP/IN <--prep-- reach/VERB/VBP
# your/PRON/PRP$ <--poss-- phone/NOUN/NN
# phone/NOUN/NN <--pobj-- for/ADP/IN
# basically/ADV/RB <--advmod-- enters/VERB/VBZ
# your/PRON/PRP$ <--poss-- hand/NOUN/NN
# hand/NOUN/NN <--nsubj-- enters/VERB/VBZ
# enters/VERB/VBZ <--ROOT-- enters/VERB/VBZ
# the/DET/DT <--det-- bubble/NOUN/NN
# bubble/NOUN/NN <--dobj-- enters/VERB/VBZ
# and/CCONJ/CC <--cc-- enters/VERB/VBZ
# it/PRON/PRP <--nsubj-- starts/VERB/VBZ
# starts/VERB/VBZ <--conj-- enters/VERB/VBZ
# firing/VERB/VBG <--xcomp-- starts/VERB/VBZ
# up/ADP/RP <--prt-- firing/VERB/VBG
# the/DET/DT <--det-- infrared/ADJ/JJ
# infrared/ADJ/JJ <--dobj-- firing/VERB/VBG
# and/CCONJ/CC <--cc-- firing/VERB/VBG
# face/VERB/VB <--conj-- firing/VERB/VBG
# unlock/NOUN/NN <--compound-- sensors/NOUN/NNS
# sensors/NOUN/NNS <--dobj-- face/VERB/VB
# early/ADV/RB <--advmod-- so/ADV/RB
# so/ADV/RB <--advmod-- face/VERB/VB
# by/ADP/IN <--prep-- face/VERB/VB
# the/DET/DT <--det-- time/NOUN/NN
# time/NOUN/NN <--pobj-- by/ADP/IN
# you/PRON/PRP <--nsubj-- pick/VERB/VBP
# pick/VERB/VBP <--relcl-- time/NOUN/NN
# the/DET/DT <--det-- phone/NOUN/NN
# phone/NOUN/NN <--dobj-- pick/VERB/VBP
# up/ADP/RP <--prt-- pick/VERB/VBP
# ./PUNCT/. <--punct-- starts/VERB/VBZ
# it/PRON/PRP <--nsubj-- reading/VERB/VBG
# is/AUX/VBZ <--aux-- reading/VERB/VBG
# already/ADV/RB <--advmod-- reading/VERB/VBG
# reading/VERB/VBG <--ROOT-- reading/VERB/VBG
# your/PRON/PRP$ <--poss-- face/NOUN/NN
# face/NOUN/NN <--dobj-- reading/VERB/VBG
# and/CCONJ/CC <--cc-- reading/VERB/VBG
# logging/VERB/VBG <--conj-- reading/VERB/VBG
# you/PRON/PRP <--dobj-- logging/VERB/VBG
# in/ADP/RP <--prt-- logging/VERB/VBG
# and/CCONJ/CC <--cc-- reading/VERB/VBG
# it/PRON/PRP <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--conj-- reading/VERB/VBG
# incredibly/ADV/RB <--advmod-- fast/ADV/RB
# fast/ADV/RB <--acomp-- is/AUX/VBZ
# over/ADV/RB <--advmod-- is/AUX/VBZ
# and/CCONJ/CC <--cc-- is/AUX/VBZ
# ./PUNCT/. <--punct-- is/AUX/VBZ
# over/ADV/RB <--advmod-- again/ADV/RB
# again/ADV/RB <--advmod-- is/AUX/VBZ
# it/PRON/PRP <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--ROOT-- is/AUX/VBZ
# super/ADV/RB <--advmod-- impressive/ADJ/JJ
# impressive/ADJ/JJ <--acomp-- is/AUX/VBZ
# possibly/ADV/RB <--advmod-- fast/ADV/RB
# too/ADV/RB <--advmod-- fast/ADV/RB
# fast/ADV/RB <--advmod-- is/AUX/VBZ
# this/DET/DT <--det-- kind/NOUN/NN
# kind/NOUN/NN <--nsubj-- reminds/VERB/VBZ
# of/ADP/IN <--prep-- kind/NOUN/NN
# reminds/VERB/VBZ <--xcomp-- is/AUX/VBZ
# me/PRON/PRP <--dobj-- reminds/VERB/VBZ
# of/ADP/IN <--prep-- reminds/VERB/VBZ
# the/DET/DT <--det-- 1/NUM/CD
# 1/NUM/CD <--nummod-- phones/NOUN/NNS
# plus/CCONJ/CC <--cc-- 1/NUM/CD
# 6/NUM/CD <--conj-- 1/NUM/CD
# and/CCONJ/CC <--cc-- 1/NUM/CD
# other/ADJ/JJ <--amod-- phones/NOUN/NNS
# phones/NOUN/NNS <--pobj-- of/ADP/IN
# that/PRON/WDT <--nsubj-- face/NOUN/NN
# would/AUX/MD <--aux-- face/NOUN/NN
# just/ADV/RB <--advmod-- face/NOUN/NN
# do/AUX/VB <--aux-- face/NOUN/NN
# face/NOUN/NN <--relcl-- phones/NOUN/NNS
# unlock/NOUN/NN <--dobj-- face/NOUN/NN
# with/ADP/IN <--prep-- face/NOUN/NN
# just/ADV/RB <--advmod-- cameras/NOUN/NNS
# the/DET/DT <--det-- cameras/NOUN/NNS
# RGB/PROPN/NNP <--compound-- cameras/NOUN/NNS
# cameras/NOUN/NNS <--pobj-- with/ADP/IN
# so/SCONJ/IN <--mark-- be/AUX/VB
# they/PRON/PRP <--nsubj-- be/AUX/VB
# would/AUX/MD <--aux-- be/AUX/VB
# be/AUX/VB <--advcl-- reminds/VERB/VBZ
# insanely/ADV/RB <--advmod-- fast/ADJ/JJ
# fast/ADJ/JJ <--acomp-- be/AUX/VB
# ./PUNCT/. <--punct-- is/AUX/VBZ
# they/PRON/PRP <--nsubj-- see/VERB/VB
# would/AUX/MD <--aux-- see/VERB/VB
# just/ADV/RB <--advmod-- see/VERB/VB
# see/VERB/VB <--ROOT-- see/VERB/VB
# anything/PRON/NN <--dobj-- see/VERB/VB
# that/PRON/WDT <--nsubj-- looks/VERB/VBZ
# looks/VERB/VBZ <--relcl-- anything/PRON/NN
# like/SCONJ/IN <--prep-- looks/VERB/VBZ
# you/PRON/PRP <--pobj-- like/SCONJ/IN
# and/CCONJ/CC <--cc-- you/PRON/PRP
# just/ADV/RB <--advmod-- unlock/VERB/VB
# unlock/VERB/VB <--conj-- you/PRON/PRP
# as/ADV/RB <--advmod-- soon/ADV/RB
# soon/ADV/RB <--advmod-- looks/VERB/VBZ
# as/SCONJ/IN <--mark-- glanced/VERB/VBD
# you/PRON/PRP <--nsubj-- glanced/VERB/VBD
# glanced/VERB/VBD <--advcl-- soon/ADV/RB
# at/ADP/IN <--prep-- glanced/VERB/VBD
# it/PRON/PRP <--pobj-- at/ADP/IN
# ./PUNCT/. <--punct-- see/VERB/VB
# so/ADV/RB <--advmod-- is/AUX/VBZ
# this/DET/DT <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--ROOT-- is/AUX/VBZ
# not/PART/RB <--neg-- is/AUX/VBZ
# that/SCONJ/IN <--mark-- infrared/VERB/VBN
# it/PRON/PRP <--nsubjpass-- infrared/VERB/VBN
# is/AUX/VBZ <--auxpass-- infrared/VERB/VBN
# still/ADV/RB <--advmod-- infrared/VERB/VBN
# infrared/VERB/VBN <--ccomp-- is/AUX/VBZ
# so/SCONJ/IN <--mark-- fooled/VERB/VBN
# it/PRON/PRP <--nsubjpass-- fooled/VERB/VBN
# still/ADV/RB <--advmod-- fooled/VERB/VBN
# can/AUX/MD <--aux-- fooled/VERB/VBN
# not/PART/RB <--neg-- fooled/VERB/VBN
# be/AUX/VB <--auxpass-- fooled/VERB/VBN
# fooled/VERB/VBN <--advcl-- infrared/VERB/VBN
# by/ADP/IN <--agent-- fooled/VERB/VBN
# a/DET/DT <--det-- photo/NOUN/NN
# photo/NOUN/NN <--pobj-- by/ADP/IN
# or/CCONJ/CC <--cc-- photo/NOUN/NN
# video/NOUN/NN <--conj-- photo/NOUN/NN
# of/ADP/IN <--prep-- photo/NOUN/NN
# you/PRON/PRP <--pobj-- of/ADP/IN
# it/PRON/PRP <--nsubj-- works/VERB/VBZ
# still/ADV/RB <--advmod-- works/VERB/VBZ
# works/VERB/VBZ <--relcl-- photo/NOUN/NN
# in/ADP/IN <--prep-- works/VERB/VBZ
# the/DET/DT <--det-- dark/NOUN/NN
# dark/NOUN/NN <--pobj-- in/ADP/IN
# and/CCONJ/CC <--cc-- photo/NOUN/NN
# things/NOUN/NNS <--conj-- photo/NOUN/NN
# like/SCONJ/IN <--prep-- things/NOUN/NNS
# that/DET/DT <--pobj-- like/SCONJ/IN
# ./PUNCT/. <--punct-- is/AUX/VBZ
# so/ADV/RB <--advmod-- got/VERB/VBN
# it/PRON/PRP <--nsubjpass-- got/VERB/VBN
# is/AUX/VBZ <--auxpass-- got/VERB/VBN
# got/VERB/VBN <--ROOT-- got/VERB/VBN
# advantages/NOUN/NNS <--dobj-- got/VERB/VBN
# ./PUNCT/. <--punct-- got/VERB/VBN
# but/CCONJ/CC <--cc-- is/AUX/VBZ
# it/PRON/PRP <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--ROOT-- is/AUX/VBZ
# still/ADV/RB <--advmod-- is/AUX/VBZ
# a/DET/DT <--det-- bit/NOUN/NN
# little/ADJ/JJ <--amod-- bit/NOUN/NN
# bit/NOUN/NN <--npadvmod-- wild/ADJ/JJ
# wild/ADJ/JJ <--acomp-- is/AUX/VBZ
# ./PUNCT/. <--punct-- is/AUX/VBZ
# I/PRON/PRP <--nsubj-- find/VERB/VBP
# find/VERB/VBP <--ROOT-- find/VERB/VBP
# myself/PRON/PRP <--nsubj-- unlocking/VERB/VBG
# just/ADV/RB <--advmod-- unlocking/VERB/VBG
# unlocking/VERB/VBG <--ccomp-- find/VERB/VBP
# this/DET/DT <--det-- phone/NOUN/NN
# phone/NOUN/NN <--dobj-- unlocking/VERB/VBG
# left/VERB/VBD <--advcl-- unlocking/VERB/VBG
# and/CCONJ/CC <--cc-- left/VERB/VBD
# right/ADV/RB <--conj-- left/VERB/VBD
# all/DET/PDT <--predet-- time/NOUN/NN
# the/DET/DT <--det-- time/NOUN/NN
# time/NOUN/NN <--npadvmod-- left/VERB/VBD
# ./PUNCT/. <--punct-- find/VERB/VBP
# anytime/ADV/RB <--advmod-- look/VERB/VBP
# I/PRON/PRP <--nsubj-- look/VERB/VBP
# even/ADV/RB <--advmod-- look/VERB/VBP
# just/ADV/RB <--advmod-- look/VERB/VBP
# look/VERB/VBP <--ROOT-- look/VERB/VBP
# at/ADP/IN <--prep-- look/VERB/VBP
# it/PRON/PRP <--pobj-- at/ADP/IN
# ./PUNCT/. <--punct-- look/VERB/VBP
# sometimes/ADV/RB <--advmod-- pick/VERB/VBP
# I/PRON/PRP <--nsubj-- pick/VERB/VBP
# pick/VERB/VBP <--ROOT-- pick/VERB/VBP
# up/ADP/RP <--prt-- pick/VERB/VBP
# the/DET/DT <--det-- phone/NOUN/NN
# phone/NOUN/NN <--dobj-- pick/VERB/VBP
# just/ADV/RB <--advmod-- move/VERB/VB
# to/PART/TO <--aux-- move/VERB/VB
# move/VERB/VB <--advcl-- pick/VERB/VBP
# it/PRON/PRP <--dobj-- move/VERB/VB
# across/ADP/IN <--prep-- move/VERB/VB
# my/PRON/PRP$ <--poss-- desk/NOUN/NN
# desk/NOUN/NN <--pobj-- across/ADP/IN
# and/CCONJ/CC <--cc-- pick/VERB/VBP
# I/PRON/PRP <--nsubj-- glance/VERB/VB
# will/AUX/MD <--aux-- glance/VERB/VB
# just/ADV/RB <--advmod-- glance/VERB/VB
# glance/VERB/VB <--conj-- pick/VERB/VBP
# at/ADP/IN <--prep-- glance/VERB/VB
# the/DET/DT <--det-- time/NOUN/NN
# time/NOUN/NN <--pobj-- at/ADP/IN
# and/CCONJ/CC <--cc-- glance/VERB/VB
# it/PRON/PRP <--nsubj-- unlocks/VERB/VBZ
# unlocks/VERB/VBZ <--conj-- glance/VERB/VB
# the/DET/DT <--det-- phone/NOUN/NN
# phone/NOUN/NN <--dobj-- unlocks/VERB/VBZ
# it/PRON/PRP <--nsubj-- require/VERB/VB
# also/ADV/RB <--advmod-- require/VERB/VB
# does/AUX/VBZ <--aux-- require/VERB/VB
# not/PART/RB <--neg-- require/VERB/VB
# require/VERB/VB <--relcl-- phone/NOUN/NN
# your/PRON/PRP$ <--poss-- attention/NOUN/NN
# attention/NOUN/NN <--dobj-- require/VERB/VB
# so/SCONJ/IN <--mark-- unlock/VERB/VB
# it/PRON/PRP <--nsubj-- unlock/VERB/VB
# will/AUX/MD <--aux-- unlock/VERB/VB
# unlock/VERB/VB <--advcl-- unlocks/VERB/VBZ
# with/ADP/IN <--prep-- unlock/VERB/VB
# your/PRON/PRP$ <--poss-- eyes/NOUN/NNS
# eyes/NOUN/NNS <--pobj-- with/ADP/IN
# closed/VERB/VBN <--advcl-- unlock/VERB/VB
# ./PUNCT/. <--punct-- glance/VERB/VB
# that/DET/DT <--nsubj-- 's/AUX/VBZ
# 's/AUX/VBZ <--ROOT-- 's/AUX/VBZ
# a./NOUN/NN <--attr-- 's/AUX/VBZ
# that/DET/DT <--nsubj-- 's/AUX/VBZ
# 's/AUX/VBZ <--ROOT-- 's/AUX/VBZ
# a/DET/DT <--det-- bit/NOUN/NN
# bit/NOUN/NN <--attr-- 's/AUX/VBZ
# of/ADP/IN <--prep-- bit/NOUN/NN
# a/DET/DT <--det-- quirk/NOUN/NN
# weird/ADJ/JJ <--amod-- quirk/NOUN/NN
# security/NOUN/NN <--compound-- quirk/NOUN/NN
# quirk/NOUN/NN <--pobj-- of/ADP/IN
# ./PUNCT/. <--punct-- 's/AUX/VBZ
# and/CCONJ/CC <--cc-- tells/VERB/VBZ
# it/PRON/PRP <--nsubj-- tells/VERB/VBZ
# actually/ADV/RB <--advmod-- tells/VERB/VBZ
# even/ADV/RB <--advmod-- tells/VERB/VBZ
# tells/VERB/VBZ <--ROOT-- tells/VERB/VBZ
# you/PRON/PRP <--dobj-- tells/VERB/VBZ
# it/PRON/PRP <--nsubj-- do/AUX/VB
# will/AUX/MD <--aux-- do/AUX/VB
# do/AUX/VB <--ccomp-- tells/VERB/VBZ
# this/DET/DT <--dobj-- do/AUX/VB
# in/ADP/IN <--prep-- do/AUX/VB
# the/DET/DT <--det-- settings/NOUN/NNS
# settings/NOUN/NNS <--pobj-- in/ADP/IN
# when/ADV/WRB <--advmod-- turn/VERB/VBP
# you/PRON/PRP <--nsubj-- turn/VERB/VBP
# turn/VERB/VBP <--advcl-- do/AUX/VB
# this/DET/DT <--dobj-- turn/VERB/VBP
# on/ADP/RP <--prt-- turn/VERB/VBP
# ./PUNCT/. <--punct-- tells/VERB/VBZ
# it/PRON/PRP <--nsubj-- says/VERB/VBZ
# says/VERB/VBZ <--ROOT-- says/VERB/VBZ
# looking/VERB/VBG <--csubj-- unlock/VERB/VB
# at/ADP/IN <--prep-- looking/VERB/VBG
# the/DET/DT <--det-- phone/NOUN/NN
# phone/NOUN/NN <--pobj-- at/ADP/IN
# can/AUX/MD <--aux-- unlock/VERB/VB
# unlock/VERB/VB <--ccomp-- says/VERB/VBZ
# it/PRON/PRP <--dobj-- unlock/VERB/VB
# when/ADV/WRB <--advmod-- intend/VERB/VB
# you/PRON/PRP <--nsubj-- intend/VERB/VB
# do/AUX/VBP <--aux-- intend/VERB/VB
# not/PART/RB <--neg-- intend/VERB/VB
# intend/VERB/VB <--advcl-- unlock/VERB/VB
# it/PRON/PRP <--dobj-- intend/VERB/VB
# to/ADP/IN <--prep-- intend/VERB/VB
# and/CCONJ/CC <--cc-- unlock/VERB/VB
# your/PRON/PRP$ <--poss-- device/NOUN/NN
# device/NOUN/NN <--nsubjpass-- unlocked/VERB/VBN
# can/AUX/MD <--aux-- unlocked/VERB/VBN
# be/AUX/VB <--auxpass-- unlocked/VERB/VBN
# unlocked/VERB/VBN <--conj-- unlock/VERB/VB
# by/ADP/IN <--agent-- unlocked/VERB/VBN
# someone/PRON/NN <--pobj-- by/ADP/IN
# even/ADV/RB <--advmod-- held/VERB/VBN
# if/SCONJ/IN <--mark-- held/VERB/VBN
# it/PRON/PRP <--nsubjpass-- held/VERB/VBN
# is/AUX/VBZ <--auxpass-- held/VERB/VBN
# held/VERB/VBN <--advcl-- unlocked/VERB/VBN
# up/ADP/RP <--prt-- held/VERB/VBN
# to/ADP/IN <--prep-- held/VERB/VBN
# your/PRON/PRP$ <--poss-- face/NOUN/NN
# face/NOUN/NN <--pobj-- to/ADP/IN
# even/ADV/RB <--advmod-- are/AUX/VBP
# if/SCONJ/IN <--mark-- are/AUX/VBP
# your/PRON/PRP$ <--poss-- eyes/NOUN/NNS
# eyes/NOUN/NNS <--nsubj-- are/AUX/VBP
# are/AUX/VBP <--advcl-- held/VERB/VBN
# closed/ADJ/JJ <--acomp-- are/AUX/VBP
# and/CCONJ/CC <--cc-- are/AUX/VBP
# potentially/ADV/RB <--advmod-- unlocked/VERB/VBN
# could/AUX/MD <--aux-- unlocked/VERB/VBN
# be/AUX/VB <--auxpass-- unlocked/VERB/VBN
# unlocked/VERB/VBN <--conj-- are/AUX/VBP
# by/ADP/IN <--agent-- unlocked/VERB/VBN
# someone/PRON/NN <--pobj-- by/ADP/IN
# who/PRON/WP <--nsubj-- looks/VERB/VBZ
# just/ADV/RB <--advmod-- looks/VERB/VBZ
# looks/VERB/VBZ <--relcl-- someone/PRON/NN
# a/DET/DT <--det-- lot/NOUN/NN
# lot/NOUN/NN <--dobj-- looks/VERB/VBZ
# like/SCONJ/IN <--prep-- lot/NOUN/NN
# you/PRON/PRP <--pobj-- like/SCONJ/IN
# ./PUNCT/. <--punct-- says/VERB/VBZ
# these/DET/DT <--nsubj-- are/AUX/VBP
# are/AUX/VBP <--ROOT-- are/AUX/VBP
# things/NOUN/NNS <--attr-- are/AUX/VBP
# that/PRON/WDT <--nsubj-- pretend/VERB/VB
# could/AUX/MD <--aux-- pretend/VERB/VB
# pretend/VERB/VB <--relcl-- things/NOUN/NNS
# chillie/NOUN/NN <--nsubjpass-- fixed/VERB/VBN
# be/AUX/VB <--auxpass-- fixed/VERB/VBN
# fixed/VERB/VBN <--acl-- these/DET/DT
# or/CCONJ/CC <--cc-- fixed/VERB/VBN
# improved/VERB/VBN <--conj-- fixed/VERB/VBN
# with/ADP/IN <--prep-- improved/VERB/VBN
# a/DET/DT <--det-- update/NOUN/NN
# software/NOUN/NN <--compound-- update/NOUN/NN
# update/NOUN/NN <--pobj-- with/ADP/IN
# and/CCONJ/CC <--cc-- fixed/VERB/VBN
# Google/PROPN/NNP <--nsubj-- been/AUX/VBN
# 's/AUX/VBZ <--case-- Google/PROPN/NNP
# been/AUX/VBN <--conj-- fixed/VERB/VBN
# pretty/ADV/RB <--advmod-- good/ADJ/JJ
# good/ADJ/JJ <--acomp-- been/AUX/VBN
# about/ADP/IN <--prep-- good/ADJ/JJ
# software/NOUN/NN <--compound-- updates/VERB/VBZ
# updates/VERB/VBZ <--pobj-- about/ADP/IN
# but/CCONJ/CC <--cc-- been/AUX/VBN
# as/SCONJ/IN <--prep-- are/AUX/VBP
# of/ADP/IN <--pcomp-- as/SCONJ/IN
# right/ADV/RB <--advmod-- now/ADV/RB
# now/ADV/RB <--pcomp-- as/SCONJ/IN
# they/PRON/PRP <--nsubj-- are/AUX/VBP
# are/AUX/VBP <--conj-- been/AUX/VBN
# just/ADV/RB <--advmod-- annoying/ADJ/JJ
# pretty/ADV/RB <--advmod-- annoying/ADJ/JJ
# annoying/ADJ/JJ <--acomp-- are/AUX/VBP
# my/PRON/PRP$ <--poss-- solution/NOUN/NN
# solution/NOUN/NN <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--auxpass-- turn/VERB/VB
# turn/VERB/VB <--conj-- are/AUX/VBP
# off/ADP/RP <--prt-- turn/VERB/VB
# the/DET/DT <--det-- skip/NOUN/NNS
# skip/NOUN/NNS <--dobj-- turn/VERB/VB
# lockscreen/ADP/IN <--compound-- option/NOUN/NN
# option/NOUN/NN <--oprd-- turn/VERB/VB
# so/ADV/RB <--mark-- be/AUX/VB
# if/SCONJ/IN <--mark-- unlock/VERB/VB
# I/PRON/PRP <--nsubj-- unlock/VERB/VB
# do/AUX/VBP <--aux-- unlock/VERB/VB
# accidentally/ADV/RB <--advmod-- unlock/VERB/VB
# unlock/VERB/VB <--advcl-- be/AUX/VB
# it/PRON/PRP <--dobj-- unlock/VERB/VB
# at/ADP/IN <--advmod-- least/ADJ/JJS
# least/ADJ/JJS <--advmod-- be/AUX/VB
# it/PRON/PRP <--nsubj-- be/AUX/VB
# will/AUX/MD <--aux-- be/AUX/VB
# not/PART/RB <--neg-- be/AUX/VB
# be/AUX/VB <--ROOT-- be/AUX/VB
# awake/ADJ/JJ <--acomp-- be/AUX/VB
# for/ADP/IN <--prep-- be/AUX/VB
# a/DET/DT <--det-- while/NOUN/NN
# while/NOUN/NN <--pobj-- for/ADP/IN
# ./PUNCT/. <--punct-- be/AUX/VB
# it/PRON/PRP <--nsubj-- sits/VERB/VBZ
# just/ADV/RB <--advmod-- sits/VERB/VBZ
# sits/VERB/VBZ <--ROOT-- sits/VERB/VBZ
# on/ADP/IN <--prep-- sits/VERB/VBZ
# the/DET/DT <--det-- lockscreen/NOUN/NN
# lockscreen/NOUN/NN <--pobj-- on/ADP/IN
# and/CCONJ/CC <--cc-- sits/VERB/VBZ
# then/ADV/RB <--advmod-- go/VERB/VB
# it/PRON/PRP <--nsubj-- go/VERB/VB
# will/AUX/MD <--aux-- go/VERB/VB
# go/VERB/VB <--conj-- sits/VERB/VBZ
# back/ADV/RB <--advmod-- go/VERB/VB
# to/ADP/IN <--prep-- back/ADV/RB
# sleep/NOUN/NN <--pobj-- to/ADP/IN
# but/CCONJ/CC <--ROOT-- but/CCONJ/CC
# ./PUNCT/. <--punct-- but/CCONJ/CC
# I/PRON/PRP <--nsubj-- mean/VERB/VBP
# mean/VERB/VBP <--parataxis-- 's/AUX/VBZ
# that/DET/DT <--nsubj-- 's/AUX/VBZ
# 's/AUX/VBZ <--ROOT-- 's/AUX/VBZ
# what/PRON/WP <--dobj-- think/VERB/VBP
# I/PRON/PRP <--nsubj-- think/VERB/VBP
# think/VERB/VBP <--ccomp-- 's/AUX/VBZ
# ./PUNCT/. <--punct-- 's/AUX/VBZ
# I/PRON/PRP <--nsubj-- mean/VERB/VBP
# mean/VERB/VBP <--ROOT-- mean/VERB/VBP
# when/ADV/WRB <--advmod-- say/VERB/VBP
# I/PRON/PRP <--nsubj-- say/VERB/VBP
# say/VERB/VBP <--advcl-- mean/VERB/VBP
# I/PRON/PRP <--nsubj-- liked/VERB/VBN
# would/AUX/MD <--aux-- liked/VERB/VBN
# have/AUX/VB <--aux-- liked/VERB/VBN
# liked/VERB/VBN <--ccomp-- say/VERB/VBP
# a/DET/DT <--det-- option/NOUN/NN
# fingerprint/NOUN/NN <--compound-- reader/NOUN/NN
# reader/NOUN/NN <--compound-- option/NOUN/NN
# option/NOUN/NN <--dobj-- liked/VERB/VBN
# it/PRON/PRP <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--relcl-- option/NOUN/NN
# a/DET/DT <--det-- little/ADJ/JJ
# little/ADJ/JJ <--npadvmod-- safer/ADJ/JJR
# safer/ADJ/JJR <--acomp-- is/AUX/VBZ
# ./PUNCT/. <--punct-- mean/VERB/VBP
# we/PRON/PRP <--nsubj-- 're/AUX/VBP
# 're/AUX/VBP <--ROOT-- 're/AUX/VBP
# a/DET/DT <--det-- little/ADV/RB
# little/ADV/RB <--npadvmod-- more/ADV/RBR
# more/ADV/RBR <--advmod-- used/ADJ/JJ
# used/ADJ/JJ <--acomp-- 're/AUX/VBP
# to/ADP/IN <--prep-- used/ADJ/JJ
# it/PRON/PRP <--pobj-- to/ADP/IN
# ./PUNCT/. <--punct-- 're/AUX/VBP
# and/CCONJ/CC <--cc-- works/VERB/VBZ
# it/PRON/PRP <--nsubj-- works/VERB/VBZ
# just/ADV/RB <--advmod-- works/VERB/VBZ
# sort/ADV/RB <--advmod-- of/ADV/RB
# of/ADV/RB <--advmod-- works/VERB/VBZ
# works/VERB/VBZ <--ROOT-- works/VERB/VBZ
# when/ADV/WRB <--advmod-- need/VERB/VBP
# we/PRON/PRP <--nsubj-- need/VERB/VBP
# need/VERB/VBP <--advcl-- works/VERB/VBZ
# it/PRON/PRP <--dobj-- need/VERB/VBP
# ./PUNCT/. <--punct-- works/VERB/VBZ
# does/AUX/VBZ <--ROOT-- does/AUX/VBZ
# not/PART/RB <--neg-- does/AUX/VBZ
# when/ADV/WRB <--advmod-- do/AUX/VBP
# we/PRON/PRP <--nsubj-- do/AUX/VBP
# do/AUX/VBP <--advcl-- does/AUX/VBZ
# not/PART/RB <--neg-- do/AUX/VBP
# ./PUNCT/. <--punct-- does/AUX/VBZ
# so/ADV/RB <--advmod-- 's/AUX/VBZ
# that/DET/DT <--nsubj-- 's/AUX/VBZ
# 's/AUX/VBZ <--ROOT-- 's/AUX/VBZ
# face/NOUN/NN <--compound-- unlock/NOUN/NN
# unlock/NOUN/NN <--attr-- 's/AUX/VBZ
# ./PUNCT/. <--punct-- 's/AUX/VBZ
# but/CCONJ/CC <--cc-- enable/VERB/VBP
# then/ADV/RB <--advmod-- enable/VERB/VBP
# these/DET/DT <--det-- sensors/NOUN/NNS
# sensors/NOUN/NNS <--nsubj-- enable/VERB/VBP
# also/ADV/RB <--advmod-- enable/VERB/VBP
# enable/VERB/VBP <--ROOT-- enable/VERB/VBP
# a/DET/DT <--quantmod-- couple/NOUN/NN
# couple/NOUN/NN <--nummod-- gestures/NOUN/NNS
# very/ADV/RB <--advmod-- specific/ADJ/JJ
# specific/ADJ/JJ <--amod-- gestures/NOUN/NNS
# gestures/NOUN/NNS <--dobj-- enable/VERB/VBP
# ./PUNCT/. <--punct-- enable/VERB/VBP
# so/ADV/RB <--advmod-- 're/AUX/VBP
# anytime/ADV/RB <--advmod-- 're/AUX/VBP
# you/PRON/PRP <--nsubj-- 're/AUX/VBP
# 're/AUX/VBP <--ROOT-- 're/AUX/VBP
# in/ADP/IN <--prep-- 're/AUX/VBP
# a/DET/DT <--det-- situation/NOUN/NN
# situation/NOUN/NN <--pobj-- in/ADP/IN
# you/PRON/PRP <--nsubj-- wave/VERB/VB
# can/AUX/MD <--aux-- wave/VERB/VB
# wave/VERB/VB <--relcl-- situation/NOUN/NN
# over/ADP/IN <--prep-- wave/VERB/VB
# your/PRON/PRP$ <--poss-- phone/NOUN/NN
# phone/NOUN/NN <--pobj-- over/ADP/IN
# and/CCONJ/CC <--cc-- wave/VERB/VB
# use/VERB/VB <--conj-- wave/VERB/VB
# the/DET/DT <--det-- gesture/NOUN/NN
# gesture/NOUN/NN <--dobj-- use/VERB/VB
# the/DET/DT <--det-- sort/NOUN/NN
# status/NOUN/NN <--compound-- bar/NOUN/NN
# bar/NOUN/NN <--compound-- sort/NOUN/NN
# sort/NOUN/NN <--dobj-- use/VERB/VB
# of/ADV/RB <--prep-- sort/NOUN/NN
# lights/VERB/VBZ <--pobj-- of/ADV/RB
# up/ADP/RP <--prt-- use/VERB/VB
# ./PUNCT/. <--punct-- 're/AUX/VBP
# it/PRON/PRP <--nsubj-- starts/VERB/VBZ
# starts/VERB/VBZ <--ROOT-- starts/VERB/VBZ
# glowing/VERB/VBG <--xcomp-- starts/VERB/VBZ
# and/CCONJ/CC <--cc-- starts/VERB/VBZ
# that/DET/DT <--nsubj-- means/VERB/VBZ
# means/VERB/VBZ <--conj-- starts/VERB/VBZ
# it/PRON/PRP <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--ccomp-- means/VERB/VBZ
# ready/ADJ/JJ <--acomp-- is/AUX/VBZ
# so/SCONJ/IN <--mark-- are/AUX/VBP
# those/DET/DT <--det-- situations/NOUN/NNS
# situations/NOUN/NNS <--nsubj-- are/AUX/VBP
# are/AUX/VBP <--advcl-- is/AUX/VBZ
# alarm/NOUN/NN <--compound-- timers/NOUN/NNS
# clocks/VERB/VBZ <--compound-- timers/NOUN/NNS
# timers/NOUN/NNS <--compound-- controls/NOUN/NNS
# media/NOUN/NNS <--compound-- controls/NOUN/NNS
# controls/NOUN/NNS <--attr-- are/AUX/VBP
# and/CCONJ/CC <--cc-- controls/NOUN/NNS
# a/DET/DT <--det-- wallpaper/NOUN/NN
# Pikachu/PROPN/NNP <--nmod-- wallpaper/NOUN/NN
# live/ADJ/JJ <--amod-- wallpaper/NOUN/NN
# wallpaper/NOUN/NN <--conj-- controls/NOUN/NNS
# and/CCONJ/CC <--cc-- are/AUX/VBP
# there/PRON/EX <--expl-- are/AUX/VBP
# are/AUX/VBP <--conj-- are/AUX/VBP
# no/DET/DT <--det-- instructions/NOUN/NNS
# instructions/NOUN/NNS <--attr-- are/AUX/VBP
# like/SCONJ/IN <--intj-- 's/AUX/VBZ
# really/ADV/RB <--advmod-- built/VERB/VBN
# built/VERB/VBN <--pcomp-- like/SCONJ/IN
# into/ADP/IN <--prep-- built/VERB/VBN
# Android/PROPN/NNP <--pobj-- into/ADP/IN
# there/PRON/EX <--expl-- 's/AUX/VBZ
# 's/AUX/VBZ <--relcl-- instructions/NOUN/NNS
# none/NOUN/NN <--attr-- 's/AUX/VBZ
# in/ADP/IN <--prep-- none/NOUN/NN
# the/DET/DT <--det-- setup/NOUN/NN
# Android/PROPN/NNP <--nmod-- setup/NOUN/NN
# 10/NUM/CD <--nummod-- setup/NOUN/NN
# setup/NOUN/NN <--pobj-- in/ADP/IN
# for/ADP/IN <--prep-- setup/NOUN/NN
# example/NOUN/NN <--pobj-- for/ADP/IN
# ./PUNCT/. <--punct-- are/AUX/VBP
# nothing/PRON/NN <--nsubj-- tells/VERB/VBZ
# really/ADV/RB <--advmod-- tells/VERB/VBZ
# tells/VERB/VBZ <--ROOT-- tells/VERB/VBZ
# you/PRON/PRP <--dobj-- tells/VERB/VBZ
# what/PRON/WP <--nsubj-- going/VERB/VBG
# 's/AUX/VBZ <--aux-- going/VERB/VBG
# going/VERB/VBG <--ccomp-- tells/VERB/VBZ
# on/ADP/RP <--prt-- going/VERB/VBG
# when/ADV/WRB <--advmod-- get/VERB/VBP
# you/PRON/PRP <--nsubj-- get/VERB/VBP
# first/ADV/RB <--advmod-- get/VERB/VBP
# get/VERB/VBP <--advcl-- going/VERB/VBG
# that/DET/DT <--det-- bar/NOUN/NN
# glowing/VERB/VBG <--amod-- bar/NOUN/NN
# bar/NOUN/NN <--dobj-- get/VERB/VBP
# ./PUNCT/. <--punct-- tells/VERB/VBZ
# you/PRON/PRP <--nsubj-- have/AUX/VBP
# just/ADV/RB <--advmod-- have/AUX/VBP
# kind/ADV/RB <--advmod-- of/ADV/RB
# of/ADV/RB <--advmod-- have/AUX/VBP
# have/AUX/VBP <--ROOT-- have/AUX/VBP
# to/PART/TO <--aux-- know/VERB/VB
# know/VERB/VB <--xcomp-- have/AUX/VBP
# so/ADV/RB <--advmod-- know/VERB/VB
# when/ADV/WRB <--advmod-- going/VERB/VBG
# an/DET/DT <--det-- alarm/NOUN/NN
# alarm/NOUN/NN <--nsubj-- going/VERB/VBG
# or/CCONJ/CC <--cc-- alarm/NOUN/NN
# a/DET/DT <--det-- timers/NOUN/NNS
# timers/NOUN/NNS <--conj-- alarm/NOUN/NN
# going/VERB/VBG <--advcl-- know/VERB/VB
# off/ADP/RP <--prt-- going/VERB/VBG
# as/SCONJ/IN <--mark-- enters/VERB/VBZ
# your/PRON/PRP$ <--poss-- hand/NOUN/NN
# hand/NOUN/NN <--nsubj-- enters/VERB/VBZ
# enters/VERB/VBZ <--advcl-- going/VERB/VBG
# that/PRON/WDT <--det-- bubble/NOUN/NN
# radar/NOUN/NN <--compound-- bubble/NOUN/NN
# bubble/NOUN/NN <--dobj-- enters/VERB/VBZ
# ./PUNCT/. <--punct-- have/AUX/VBP
# it/PRON/PRP <--nsubj-- quiets/VERB/VBZ
# quiets/VERB/VBZ <--ROOT-- quiets/VERB/VBZ
# the/DET/DT <--det-- alarm/NOUN/NN
# alarm/NOUN/NN <--dobj-- quiets/VERB/VBZ
# ./PUNCT/. <--punct-- quiets/VERB/VBZ
# and/CCONJ/CC <--cc-- dismiss/VERB/VB
# then/ADV/RB <--advmod-- dismiss/VERB/VB
# you/PRON/PRP <--nsubj-- dismiss/VERB/VB
# can/AUX/MD <--aux-- dismiss/VERB/VB
# dismiss/VERB/VB <--ROOT-- dismiss/VERB/VB
# it/PRON/PRP <--dobj-- dismiss/VERB/VB
# by/ADP/IN <--prep-- dismiss/VERB/VB
# tapping/VERB/VBG <--pcomp-- by/ADP/IN
# or/CCONJ/CC <--cc-- tapping/VERB/VBG
# swiping/VERB/VBG <--conj-- tapping/VERB/VBG
# away/ADV/RB <--advmod-- swiping/VERB/VBG
# over/ADP/IN <--prep-- away/ADV/RB
# the/DET/DT <--det-- phone/NOUN/NN
# phone/NOUN/NN <--pobj-- over/ADP/IN
# ./PUNCT/. <--punct-- dismiss/VERB/VB
# that/DET/DT <--mark-- was/AUX/VBD
# for/ADP/IN <--prep-- was/AUX/VBD
# me/PRON/PRP <--pobj-- for/ADP/IN
# was/AUX/VBD <--ROOT-- was/AUX/VBD
# my/PRON/PRP$ <--poss-- favorite/ADJ/JJ
# favorite/ADJ/JJ <--attr-- was/AUX/VBD
# ./PUNCT/. <--punct-- was/AUX/VBD
# it/PRON/PRP <--nsubj-- worked/VERB/VBD
# worked/VERB/VBD <--ROOT-- worked/VERB/VBD
# ...
# S/PROPN/NNP <--compound-- Pen/NOUN/NN
# Pen/NOUN/NN <--compound-- level/NOUN/NN
# level/NOUN/NN <--compound-- feature/NOUN/NN
# feature/NOUN/NN <--pobj-- like/SCONJ/IN
# I/PRON/PRP <--nsubj-- use/VERB/VB
# personally/ADV/RB <--advmod-- use/VERB/VB
# probably/ADV/RB <--advmod-- use/VERB/VB
# will/AUX/MD <--aux-- use/VERB/VB
# not/PART/RB <--neg-- use/VERB/VB
# use/VERB/VB <--relcl-- feature/NOUN/NN
# it/PRON/PRP <--dobj-- use/VERB/VB
# too/ADV/RB <--advmod-- much/ADV/RB
# much/ADV/RB <--advmod-- use/VERB/VB
# ./PUNCT/. <--punct-- is/AUX/VBZ
# but/CCONJ/CC <--cc-- see/VERB/VB
# I/PRON/PRP <--nsubj-- see/VERB/VB
# can/AUX/MD <--aux-- see/VERB/VB
# see/VERB/VB <--ROOT-- see/VERB/VB
# how/ADV/WRB <--advmod-- find/VERB/VB
# people/NOUN/NNS <--nsubj-- find/VERB/VB
# who/PRON/WP <--nsubj-- use/VERB/VBP
# use/VERB/VBP <--relcl-- people/NOUN/NNS
# that/PRON/WDT <--dobj-- use/VERB/VBP
# would/AUX/MD <--aux-- find/VERB/VB
# find/VERB/VB <--ccomp-- see/VERB/VB
# it/PRON/PRP <--nsubj-- deal/NOUN/NN
# a/DET/DT <--det-- deal/NOUN/NN
# really/ADV/RB <--advmod-- big/ADJ/JJ
# big/ADJ/JJ <--amod-- deal/NOUN/NN
# deal/NOUN/NN <--ccomp-- find/VERB/VB
# ./PUNCT/. <--punct-- see/VERB/VB
# but/CCONJ/CC <--cc-- yeah/INTJ/UH
# yeah/INTJ/UH <--ROOT-- yeah/INTJ/UH
# ./PUNCT/. <--punct-- yeah/INTJ/UH
# the/DET/DT <--det-- part/NOUN/NN
# best/ADJ/JJS <--amod-- part/NOUN/NN
# part/NOUN/NN <--nsubj-- is/AUX/VBZ
# of/ADP/IN <--prep-- part/NOUN/NN
# a/DET/DT <--det-- pixel/NOUN/NN
# pixel/NOUN/NN <--pobj-- of/ADP/IN
# again/ADV/RB <--advmod-- part/NOUN/NN
# is/AUX/VBZ <--ROOT-- is/AUX/VBZ
# how/ADV/WRB <--advmod-- refined/ADJ/JJ
# refined/ADJ/JJ <--acomp-- is/AUX/VBZ
# Android/PROPN/NNP <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--ccomp-- is/AUX/VBZ
# if/SCONJ/IN <--mark-- want/VERB/VBP
# you/PRON/PRP <--nsubj-- want/VERB/VBP
# want/VERB/VBP <--advcl-- is/AUX/VBZ
# the/DET/DT <--det-- version/NOUN/NN
# latest/ADJ/JJS <--amod-- version/NOUN/NN
# version/NOUN/NN <--dobj-- want/VERB/VBP
# of/ADP/IN <--prep-- version/NOUN/NN
# Android/PROPN/NNP <--pobj-- of/ADP/IN
# ./PUNCT/. <--punct-- is/AUX/VBZ
# if/SCONJ/IN <--mark-- want/VERB/VBP
# you/PRON/PRP <--nsubj-- want/VERB/VBP
# want/VERB/VBP <--advcl-- are/AUX/VBP
# to/PART/TO <--aux-- be/AUX/VB
# be/AUX/VB <--xcomp-- want/VERB/VBP
# first/ADJ/JJ <--acomp-- be/AUX/VB
# with/ADP/IN <--prep-- first/ADJ/JJ
# updates/NOUN/NNS <--pobj-- with/ADP/IN
# if/SCONJ/IN <--mark-- want/VERB/VBP
# you/PRON/PRP <--nsubj-- want/VERB/VBP
# want/VERB/VBP <--advcl-- want/VERB/VBP
# the/DET/DT <--det-- features/NOUN/NNS
# coolest/ADJ/JJS <--amod-- features/NOUN/NNS
# edge/NOUN/NN <--compound-- features/NOUN/NNS
# features/NOUN/NNS <--dobj-- want/VERB/VBP
# and/CCONJ/CC <--cc-- features/NOUN/NNS
# the/DET/DT <--det-- assistant/NOUN/NN
# assistant/NOUN/NN <--conj-- features/NOUN/NNS
# and/CCONJ/CC <--cc-- assistant/NOUN/NN
# all/DET/PDT <--conj-- assistant/NOUN/NN
# that/PRON/WDT <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--relcl-- all/DET/PDT
# the/DET/DT <--det-- phone/NOUN/NN
# phone/NOUN/NN <--attr-- is/AUX/VBZ
# again/ADV/RB <--advmod-- is/AUX/VBZ
# so/SCONJ/IN <--advmod-- overall/ADV/RB
# overall/ADV/RB <--advmod-- many/ADJ/JJ
# many/ADJ/JJ <--nsubj-- are/AUX/VBP
# of/ADP/IN <--prep-- many/ADJ/JJ
# the/DET/DT <--det-- conclusions/NOUN/NNS
# conclusions/NOUN/NNS <--pobj-- of/ADP/IN
# about/ADP/IN <--prep-- many/ADJ/JJ
# pixel/NOUN/NN <--pobj-- about/ADP/IN
# 4/NUM/CD <--nummod-- pixel/NOUN/NN
# are/AUX/VBP <--ROOT-- are/AUX/VBP
# of/ADP/IN <--prep-- are/AUX/VBP
# course/NOUN/NN <--pobj-- of/ADP/IN
# about/ADP/IN <--prep-- are/AUX/VBP
# how/ADV/WRB <--advmod-- disappointing/ADJ/JJ
# disappointing/ADJ/JJ <--acomp-- is/AUX/VBZ
# it/PRON/PRP <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--pcomp-- about/ADP/IN
# which/PRON/WDT <--nsubj-- is/AUX/VBZ
# i/PRON/PRP <--nsubj-- think/VERB/VBP
# think/VERB/VBP <--ccomp-- is/AUX/VBZ
# is/AUX/VBZ <--ccomp-- think/VERB/VBP
# an/DET/DT <--det-- conclusion/NOUN/NN
# easy/ADJ/JJ <--amod-- conclusion/NOUN/NN
# conclusion/NOUN/NN <--attr-- is/AUX/VBZ
# to/PART/TO <--aux-- reach/VERB/VB
# reach/VERB/VB <--acl-- conclusion/NOUN/NN
# if/SCONJ/IN <--mark-- followed/VERB/VBN
# you/PRON/PRP <--nsubj-- followed/VERB/VBN
# have/AUX/VBP <--aux-- followed/VERB/VBN
# followed/VERB/VBN <--advcl-- reach/VERB/VB
# all/DET/PDT <--predet-- leaks/NOUN/NNS
# the/DET/DT <--det-- leaks/NOUN/NNS
# leaks/NOUN/NNS <--dobj-- followed/VERB/VBN
# and/CCONJ/CC <--cc-- leaks/NOUN/NNS
# nothing/PRON/NN <--conj-- leaks/NOUN/NNS
# really/ADV/RB <--advmod-- surprised/VERB/VBD
# surprised/VERB/VBD <--acl-- leaks/NOUN/NNS
# you/PRON/PRP <--dobj-- surprised/VERB/VBD
# and/CCONJ/CC <--cc-- followed/VERB/VBN
# are/AUX/VBP <--conj-- followed/VERB/VBN
# things/NOUN/NNS <--attr-- are/AUX/VBP
# that/PRON/WDT <--nsubjpass-- let/VERB/VBN
# are/AUX/VBP <--auxpass-- let/VERB/VBN
# let/VERB/VBN <--relcl-- things/NOUN/NNS
# down/ADP/RP <--prt-- let/VERB/VBN
# I/PRON/PRP <--nsubj-- enjoyed/VERB/VBD
# personally/ADV/RB <--advmod-- enjoyed/VERB/VBD
# really/ADV/RB <--advmod-- enjoyed/VERB/VBD
# enjoyed/VERB/VBD <--relcl-- things/NOUN/NNS
# using/VERB/VBG <--xcomp-- enjoyed/VERB/VBD
# pixel/NOUN/NN <--dobj-- using/VERB/VBG
# because/SCONJ/IN <--prep-- enjoyed/VERB/VBD
# of/ADP/IN <--pcomp-- because/SCONJ/IN
# the/DET/DT <--det-- camera/NOUN/NN
# punchy/ADJ/JJ <--nmod-- camera/NOUN/NN
# confident/ADJ/JJ <--amod-- camera/NOUN/NN
# excellent/ADJ/JJ <--amod-- camera/NOUN/NN
# camera/NOUN/NN <--pobj-- because/SCONJ/IN
# for/ADP/IN <--prep-- camera/NOUN/NN
# still/ADV/RB <--advmod-- photos/NOUN/NNS
# photos/NOUN/NNS <--pobj-- for/ADP/IN
# and/CCONJ/CC <--cc-- photos/NOUN/NNS
# the/DET/DT <--det-- display/NOUN/NN
# 90/NUM/CD <--nummod-- Hertz/PROPN/NNP
# Hertz/PROPN/NNP <--compound-- display/NOUN/NN
# display/NOUN/NN <--conj-- photos/NOUN/NNS
# which/PRON/WDT <--dobj-- have/AUX/VB
# a/DET/DT <--det-- lot/NOUN/NN
# lot/NOUN/NN <--nsubj-- have/AUX/VB
# of/ADP/IN <--prep-- lot/NOUN/NN
# phones/NOUN/NNS <--pobj-- of/ADP/IN
# do/AUX/VBP <--aux-- have/AUX/VB
# not/PART/RB <--neg-- have/AUX/VB
# have/AUX/VB <--relcl-- camera/NOUN/NN
# yet/ADV/RB <--advmod-- have/AUX/VB
# and/CCONJ/CC <--ROOT-- and/CCONJ/CC
# ./PUNCT/. <--punct-- and/CCONJ/CC
# of/ADV/RB <--advmod-- course/ADV/RB
# course/ADV/RB <--advmod-- phone/NOUN/NN
# the/DET/DT <--det-- RAM/NOUN/NN
# extra/ADJ/JJ <--amod-- RAM/NOUN/NN
# RAM/NOUN/NN <--nsubj-- phone/NOUN/NN
# finally/ADV/RB <--advmod-- phone/NOUN/NN
# a/DET/DT <--det-- phone/NOUN/NN
# smooth/ADJ/JJ <--amod-- phone/NOUN/NN
# pixel/NOUN/NN <--compound-- phone/NOUN/NN
# phone/NOUN/NN <--ROOT-- phone/NOUN/NN
# ./PUNCT/. <--punct-- phone/NOUN/NN
# but/CCONJ/CC <--cc-- is/AUX/VBZ
# this/DET/DT <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--ROOT-- is/AUX/VBZ
# not/PART/RB <--neg-- is/AUX/VBZ
# a/DET/DT <--det-- phone/NOUN/NN
# phone/NOUN/NN <--attr-- is/AUX/VBZ
# I/PRON/PRP <--nsubj-- gon/VERB/VBG
# 'm/AUX/VBP <--aux-- gon/VERB/VBG
# gon/VERB/VBG <--relcl-- phone/NOUN/NN
# na/PART/TO <--aux-- go/VERB/VB
# go/VERB/VB <--xcomp-- gon/VERB/VBG
# around/ADV/RB <--advmod-- go/VERB/VB
# recommending/VERB/VBG <--advcl-- go/VERB/VB
# to/ADP/IN <--prep-- recommending/VERB/VBG
# everyone/PRON/NN <--pobj-- to/ADP/IN
# it/PRON/PRP <--nsubj-- needs/VERB/VBZ
# still/ADV/RB <--advmod-- needs/VERB/VBZ
# needs/VERB/VBZ <--relcl-- phone/NOUN/NN
# a/DET/DT <--det-- battery/NOUN/NN
# bigger/ADJ/JJR <--amod-- battery/NOUN/NN
# battery/NOUN/NN <--dobj-- needs/VERB/VBZ
# ./PUNCT/. <--punct-- is/AUX/VBZ
# still/ADV/RB <--advmod-- needs/VERB/VBZ
# needs/VERB/VBZ <--ROOT-- needs/VERB/VBZ
# more/ADJ/JJR <--amod-- storage/NOUN/NN
# storage/NOUN/NN <--dobj-- needs/VERB/VBZ
# ./PUNCT/. <--punct-- needs/VERB/VBZ
# and/CCONJ/CC <--cc-- is/AUX/VBZ
# it/PRON/PRP <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--ROOT-- is/AUX/VBZ
# just/ADV/RB <--advmod-- is/AUX/VBZ
# generally/ADV/RB <--advmod-- is/AUX/VBZ
# not/PART/RB <--neg-- is/AUX/VBZ
# complete/ADJ/JJ <--acomp-- is/AUX/VBZ
# for/ADP/IN <--prep-- complete/ADJ/JJ
# most/ADJ/JJS <--amod-- people/NOUN/NNS
# people/NOUN/NNS <--pobj-- for/ADP/IN
# ./PUNCT/. <--punct-- is/AUX/VBZ
# so/ADV/RB <--advmod-- guess/VERB/VBP
# I/PRON/PRP <--nsubj-- guess/VERB/VBP
# guess/VERB/VBP <--ROOT-- guess/VERB/VBP
# if/SCONJ/IN <--mark-- 're/AUX/VBP
# you/PRON/PRP <--nsubj-- 're/AUX/VBP
# 're/AUX/VBP <--advcl-- value/NOUN/NN
# like/SCONJ/IN <--prep-- 're/AUX/VBP
# me/PRON/PRP <--pobj-- like/SCONJ/IN
# which/PRON/WDT <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--relcl-- me/PRON/PRP
# in/ADP/IN <--prep-- is/AUX/VBZ
# a/DET/DT <--det-- group/NOUN/NN
# tiny/ADJ/JJ <--amod-- group/NOUN/NN
# group/NOUN/NN <--pobj-- in/ADP/IN
# of/ADP/IN <--prep-- group/NOUN/NN
# people/NOUN/NNS <--pobj-- of/ADP/IN
# who/PRON/WP <--nsubj-- like/VERB/VBP
# really/ADV/RB <--advmod-- like/VERB/VBP
# like/VERB/VBP <--relcl-- group/NOUN/NN
# high/ADJ/JJ <--amod-- refresh/NOUN/NN
# refresh/NOUN/NN <--compound-- rate/NOUN/NN
# rate/NOUN/NN <--compound-- screens/NOUN/NNS
# screens/NOUN/NNS <--dobj-- like/VERB/VBP
# of/ADP/IN <--prep-- screens/NOUN/NNS
# course/NOUN/NN <--pobj-- of/ADP/IN
# value/NOUN/NN <--ccomp-- guess/VERB/VBP
# the/DET/DT <--det-- camera/NOUN/NN
# camera/NOUN/NN <--dobj-- value/NOUN/NN
# and/CCONJ/CC <--cc-- value/NOUN/NN
# want/VERB/VBP <--conj-- value/NOUN/NN
# the/DET/DT <--det-- version/NOUN/NN
# latest/ADJ/JJS <--amod-- version/NOUN/NN
# version/NOUN/NN <--dobj-- want/VERB/VBP
# of/ADP/IN <--prep-- version/NOUN/NN
# Android/PROPN/NNP <--pobj-- of/ADP/IN
# and/CCONJ/CC <--cc-- Android/PROPN/NNP
# these/DET/DT <--conj-- Android/PROPN/NNP
# clicked/VERB/VBD <--acl-- these/DET/DT
# up/ADP/RP <--prt-- clicked/VERB/VBD
# to/ADP/IN <--prep-- up/ADP/RP
# and/CCONJ/CC <--cc-- version/NOUN/NN
# things/NOUN/NNS <--conj-- version/NOUN/NN
# like/SCONJ/IN <--prep-- things/NOUN/NNS
# that/DET/DT <--pobj-- like/SCONJ/IN
# ./PUNCT/. <--punct-- guess/VERB/VBP
# and/CCONJ/CC <--cc-- 're/AUX/VBP
# you/PRON/PRP <--nsubj-- 're/AUX/VBP
# 're/AUX/VBP <--ROOT-- 're/AUX/VBP
# willing/ADJ/JJ <--acomp-- 're/AUX/VBP
# to/PART/TO <--aux-- overpay/VERB/VB
# overpay/VERB/VB <--xcomp-- willing/ADJ/JJ
# because/SCONJ/IN <--mark-- know/VERB/VBP
# we/PRON/PRP <--nsubj-- know/VERB/VBP
# all/DET/DT <--appos-- we/PRON/PRP
# know/VERB/VBP <--advcl-- 're/AUX/VBP
# the/DET/DT <--det-- pixel/NOUN/NN
# pixel/NOUN/NN <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--ccomp-- know/VERB/VBP
# a/DET/DT <--det-- bit/NOUN/NN
# bit/NOUN/NN <--npadvmod-- overpriced/ADJ/JJ
# overpriced/ADJ/JJ <--acomp-- is/AUX/VBZ
# for/ADP/IN <--prep-- overpriced/ADJ/JJ
# the/DET/DT <--det-- storage/NOUN/NN
# storage/NOUN/NN <--pobj-- for/ADP/IN
# you/PRON/PRP <--nsubj-- get/AUX/VB
# do/AUX/VBP <--aux-- get/AUX/VB
# not/PART/RB <--neg-- get/AUX/VB
# get/AUX/VB <--relcl-- storage/NOUN/NN
# then/ADV/RB <--advmod-- get/AUX/VB
# sure/ADJ/JJ <--ccomp-- know/VERB/VBP
# I/PRON/PRP <--nsubj-- recommend/VERB/VBP
# recommend/VERB/VBP <--ccomp-- sure/ADJ/JJ
# the/DET/DT <--det-- pixel/NOUN/NN
# pixel/NOUN/NN <--dobj-- recommend/VERB/VBP
# ./PUNCT/. <--punct-- 're/AUX/VBP
# it/PRON/PRP <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--ROOT-- is/AUX/VBZ
# great/ADJ/JJ <--acomp-- is/AUX/VBZ
# for/ADP/IN <--prep-- is/AUX/VBZ
# people/NOUN/NNS <--pobj-- for/ADP/IN
# like/SCONJ/IN <--prep-- people/NOUN/NNS
# that/DET/DT <--pobj-- like/SCONJ/IN
# but/CCONJ/CC <--ROOT-- but/CCONJ/CC
# ./PUNCT/. <--punct-- but/CCONJ/CC
# for/ADP/IN <--prep-- gon/VERB/VBG
# most/ADJ/JJS <--amod-- people/NOUN/NNS
# people/NOUN/NNS <--pobj-- for/ADP/IN
# I/PRON/PRP <--nsubj-- gon/VERB/VBG
# 'm/AUX/VBP <--aux-- gon/VERB/VBG
# not/PART/RB <--neg-- gon/VERB/VBG
# gon/VERB/VBG <--ROOT-- gon/VERB/VBG
# na/PART/TO <--aux-- end/VERB/VB
# end/VERB/VB <--xcomp-- gon/VERB/VBG
# up/ADP/RP <--prt-- end/VERB/VB
# recommending/VERB/VBG <--xcomp-- end/VERB/VB
# the/DET/DT <--det-- pixel/NOUN/NN
# pixel/NOUN/NN <--dobj-- recommending/VERB/VBG
# for/ADP/IN <--prep-- recommending/VERB/VBG
# mainly/ADV/RB <--advmod-- because/SCONJ/IN
# because/SCONJ/IN <--prep-- end/VERB/VB
# of/ADP/IN <--pcomp-- because/SCONJ/IN
# the/DET/DT <--det-- battery/NOUN/NN
# battery/NOUN/NN <--pobj-- because/SCONJ/IN
# but/CCONJ/CC <--cc-- gon/VERB/VBG
# also/ADV/RB <--advmod-- but/CCONJ/CC
# because/SCONJ/IN <--mark-- are/AUX/VBP
# there/PRON/EX <--expl-- are/AUX/VBP
# are/AUX/VBP <--advcl-- gon/VERB/VBG
# just/ADV/RB <--advmod-- better/ADJ/JJR
# better/ADJ/JJR <--amod-- deals/NOUN/NNS
# deals/NOUN/NNS <--attr-- are/AUX/VBP
# out/ADV/RB <--advmod-- there/ADV/RB
# there/ADV/RB <--advmod-- deals/NOUN/NNS
# right/ADV/RB <--advmod-- now/ADV/RB
# now/ADV/RB <--advmod-- are/AUX/VBP
# including/VERB/VBG <--prep-- are/AUX/VBP
# the/DET/DT <--det-- iPhone/PROPN/NNP
# cheaper/ADJ/JJR <--amod-- iPhone/PROPN/NNP
# iPhone/PROPN/NNP <--pobj-- including/VERB/VBG
# 11/NUM/CD <--nummod-- iPhone/PROPN/NNP
# weird/ADJ/JJ <--amod-- 11/NUM/CD
# to/PART/TO <--aux-- say/VERB/VB
# say/VERB/VB <--relcl-- iPhone/PROPN/NNP
# ./PUNCT/. <--punct-- gon/VERB/VBG
# but/CCONJ/CC <--cc-- hits/VERB/VBZ
# it/PRON/PRP <--nsubj-- hits/VERB/VBZ
# kind/ADV/RB <--advmod-- of/ADV/RB
# of/ADV/RB <--advmod-- hits/VERB/VBZ
# hits/VERB/VBZ <--ROOT-- hits/VERB/VBZ
# the/DET/DT <--det-- funny/ADJ/JJ
# ear/NOUN/NN <--compound-- funny/ADJ/JJ
# funny/ADJ/JJ <--dobj-- hits/VERB/VBZ
# ./PUNCT/. <--punct-- hits/VERB/VBZ
# but/CCONJ/CC <--cc-- is/AUX/VBZ
# it/PRON/PRP <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--ROOT-- is/AUX/VBZ
# true/ADJ/JJ <--acomp-- is/AUX/VBZ
# ./PUNCT/. <--punct-- is/AUX/VBZ
# so/ADV/RB <--advmod-- have/AUX/VBP
# there/ADV/RB <--advmod-- have/AUX/VBP
# you/PRON/PRP <--nsubj-- have/AUX/VBP
# have/AUX/VBP <--ROOT-- have/AUX/VBP
# it/PRON/PRP <--dative-- have/AUX/VBP
# the/DET/DT <--det-- pixel/NOUN/NN
# pixel/NOUN/NN <--dobj-- have/AUX/VBP
# for/ADP/IN <--prep-- pixel/NOUN/NN
# possibly/ADV/RB <--advmod-- victim/NOUN/NN
# a/DET/DT <--det-- victim/NOUN/NN
# victim/NOUN/NN <--pobj-- for/ADP/IN
# of/ADP/IN <--prep-- victim/NOUN/NN
# the/DET/DT <--det-- machine/NOUN/NN
# hype/NOUN/NN <--compound-- machine/NOUN/NN
# machine/NOUN/NN <--pobj-- of/ADP/IN
# of/ADP/IN <--prep-- machine/NOUN/NN
# being/AUX/VBG <--pcomp-- of/ADP/IN
# the/DET/DT <--det-- phone/NOUN/NN
# most/ADV/RBS <--advmod-- leaked/ADJ/JJ
# leaked/ADJ/JJ <--amod-- phone/NOUN/NN
# phone/NOUN/NN <--attr-- being/AUX/VBG
# of/ADP/IN <--prep-- phone/NOUN/NN
# all/DET/DT <--det-- time/NOUN/NN
# time/NOUN/NN <--pobj-- of/ADP/IN
# ./PUNCT/. <--punct-- have/AUX/VBP
# I/PRON/PRP <--nsubj-- be/AUX/VB
# kind/ADV/RB <--advmod-- of/ADV/RB
# of/ADV/RB <--advmod-- be/AUX/VB
# would/AUX/MD <--aux-- be/AUX/VB
# not/PART/RB <--neg-- be/AUX/VB
# be/AUX/VB <--ROOT-- be/AUX/VB
# surprised/ADJ/JJ <--acomp-- be/AUX/VB
# if/SCONJ/IN <--mark-- happens/VERB/VBZ
# it/PRON/PRP <--nsubj-- happens/VERB/VBZ
# happens/VERB/VBZ <--advcl-- be/AUX/VB
# again/ADV/RB <--advmod-- happens/VERB/VBZ
# next/ADJ/JJ <--amod-- year/NOUN/NN
# year/NOUN/NN <--npadvmod-- happens/VERB/VBZ
# but/CCONJ/CC <--cc-- be/AUX/VB
# ./PUNCT/. <--punct-- be/AUX/VB
# either/DET/DT <--det-- way/NOUN/NN
# way/NOUN/NN <--npadvmod-- know/VERB/VBP
# now/ADV/RB <--advmod-- know/VERB/VBP
# you/PRON/PRP <--nsubj-- know/VERB/VBP
# know/VERB/VBP <--ROOT-- know/VERB/VBP
# what/PRON/WP <--pobj-- like/SCONJ/IN
# it/PRON/PRP <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--ccomp-- know/VERB/VBP
# like/SCONJ/IN <--prep-- is/AUX/VBZ
# to/PART/TO <--aux-- own/VERB/VB
# own/VERB/VB <--xcomp-- is/AUX/VBZ
# it/PRON/PRP <--dobj-- own/VERB/VB
# ./PUNCT/. <--punct-- know/VERB/VBP
# and/CCONJ/CC <--cc-- 'm/AUX/VBP
# I/PRON/PRP <--nsubj-- 'm/AUX/VBP
# 'm/AUX/VBP <--ROOT-- 'm/AUX/VBP
# curious/ADJ/JJ <--acomp-- 'm/AUX/VBP
# ./PUNCT/. <--punct-- 'm/AUX/VBP
# are/AUX/VBP <--ROOT-- are/AUX/VBP
# you/PRON/PRP <--nsubj-- are/AUX/VBP
# in/ADP/IN <--prep-- are/AUX/VBP
# this/DET/DT <--det-- group/NOUN/NN
# tiny/ADJ/JJ <--amod-- group/NOUN/NN
# group/NOUN/NN <--pobj-- in/ADP/IN
# of/ADP/IN <--prep-- group/NOUN/NN
# people/NOUN/NNS <--pobj-- of/ADP/IN
# who/PRON/WP <--nsubj-- like/VERB/VB
# would/AUX/MD <--aux-- like/VERB/VB
# like/VERB/VB <--relcl-- group/NOUN/NN
# this/DET/DT <--det-- experience/NOUN/NN
# pixel/NOUN/NN <--compound-- experience/NOUN/NN
# experience/NOUN/NN <--dobj-- like/VERB/VB
# ./PUNCT/. <--punct-- are/AUX/VBP
# let/VERB/VB <--ROOT-- let/VERB/VB
# me/PRON/PRP <--nsubj-- know/VERB/VB
# know/VERB/VB <--ccomp-- let/VERB/VB
# either/DET/DT <--det-- way/NOUN/NN
# way/NOUN/NN <--dobj-- know/VERB/VB
# thanks/NOUN/NNS <--ccomp-- know/VERB/VB
# for/ADP/IN <--prep-- thanks/NOUN/NNS
# watching/VERB/VBG <--pcomp-- for/ADP/IN
# catch/NOUN/NN <--dobj-- watching/VERB/VBG
# you/PRON/PRP <--nmod-- guys/NOUN/NNS
# guys/NOUN/NNS <--dobj-- catch/NOUN/NN
# in/ADP/IN <--prep-- watching/VERB/VBG
# the/DET/DT <--det-- peace/NOUN/NN
# next/ADJ/JJ <--amod-- peace/NOUN/NN
# one/NUM/CD <--nummod-- peace/NOUN/NN
# peace/NOUN/NN <--pobj-- in/ADP/IN
# ./PUNCT/. <--punct-- let/VERB/VB

# %%
from Evaluation import usefulnessScore

file = open("EvaluationText/mkbhdPixel.txt")
a = file.readlines()
file.close()
file = open("EvaluationText/unboxPixel.txt")
b = file.readlines()
file.close()
file = open("EvaluationText/Chromebook.txt")
c = file.readlines()
file.close()
file = open("EvaluationText/GoPro.txt")
d = file.readlines()
file.close()
file = open("EvaluationText/Airpods.txt")
e = file.readlines()
file.close()
file = open("EvaluationText/iphone11.txt")
f = file.readlines()
file.close()
evaluation = [a,b,c,d,e,f]

# %%
usefulnessScore(statements,evaluation[0])
# Out:
# (0.6056338028169014, 68, 43, 25, 46)

# %%
from nltk.translate.bleu_score import sentence_bleu

# %%
sentence_bleu()
